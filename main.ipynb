# %%
import cv2
import json
import trt_pose.coco
import torch
import time
import numpy as np
import pyrealsense2 as rs
from torch2trt import TRTModule
from trt_pose.draw_objects import DrawObjects
from trt_pose.parse_objects import ParseObjects

OPTIMIZED_MODEL = 'pose_detection/resnet18_baseline_att_224x224_A_epoch_249_trt.pth'
HUMAN = 'pose_detection/human_pose.json'

# %%
def preprocess(image):
    mean = torch.Tensor([0.485, 0.456, 0.406]).to(device).view(1, 3, 1, 1)
    std = torch.Tensor([0.229, 0.224, 0.225]).to(device).view(1, 3, 1, 1)
    image = cv2.cvtColor(image, cv2.COLOR_BGR2RGB)
    image = cv2.resize(image, (224, 224))
    image = torch.from_numpy(image).permute(2, 0, 1).unsqueeze(0).float().to(device)
    image = image.div(255.0)
    image = (image - mean) / std
    return image

# Load model and topology
with open(HUMAN, 'r') as f:
    human_pose = json.load(f)
topology = trt_pose.coco.coco_category_to_topology(human_pose)

# Instantiate TensorRT
model_trt = TRTModule()
model_trt.load_state_dict(torch.load(OPTIMIZED_MODEL))

# Doing stuff (tbd)
parse_objects = ParseObjects(topology)
draw_objects = DrawObjects(topology)

device = torch.device('cuda')

class PIDController:
    def __init__(self, kp, ki, kd, set_point):
        self.kp = kp
        self.ki = ki
        self.kd = kd
        self.set_point = set_point
        self.last_error = 0.0
        self.integral = 0.0

    def update(self, current_value):
        error = self.set_point - current_value
        self.integral += error
        derivative = error - self.last_error
        self.last_error = error
        return self.kp * error + self.ki * self.integral + self.kd * derivative

# %%
from rover.controls import *
rover = Controls()
# Out:
# Initializing Servos
# Initializing ServoKit
# Done initializing

# %%
from pose_detection.pose_detection import *


WIDTH = 640
HEIGHT = 480
BRAKE_DISTANCE = 1269

# Initialize RealSense camera
pipeline = rs.pipeline()
config = rs.config()
config.enable_stream(rs.stream.color, WIDTH, HEIGHT, rs.format.bgr8, 30)
config.enable_stream(rs.stream.depth, 640, 480, rs.format.z16, 30)
pipeline.start(config)

body = Body()
speed = 0
pose_change = False

prev_pose = "No Pose"
center = [WIDTH/2, HEIGHT/2]
current_angle = 90
started = False

#DESIRED_DISTANCE = 1200
#pid = PIDController(kp=0.1, ki=0.01, kd=0.05, set_point=DESIRED_DISTANCE)

prev_frame_time = time.time()

try:
    while True:
        frames = pipeline.wait_for_frames()
        color_frame = frames.get_color_frame()
        depth_frame = frames.get_depth_frame()

        # Convert depth frame to numpy array
        depth_image = np.asanyarray(depth_frame.get_data())

        if not color_frame or not depth_frame:
            continue

        # Convert images to numpy arrays
        color_image = np.asanyarray(color_frame.get_data())

        # Process the image for pose estimation                # TODO: Think about speed being 1 and incrementing by 1
        data = preprocess(color_image)
        cmap, paf = model_trt(data)
        cmap, paf = cmap.detach().cpu(), paf.detach().cpu()
        counts, objects, peaks = parse_objects(cmap, paf)
        
        # Classify the pose and display it
        pose_classification, chest_in_frame = classify_pose(peaks, counts, objects, topology, body)
        cv2.putText(color_image, pose_classification, (50, 50), cv2.FONT_HERSHEY_SIMPLEX, 1, (255, 255, 255), 2, cv2.LINE_AA)
        
        if pose_classification == "T-Pose":
            started = True
            speed = 1
            rover.forward(speed)
        elif pose_classification == "S-Pose":
            started = False
            rover.brake()
        
        if started == True:
            # Access depth data (in millimeters)
            depth_value_at_pixel = depth_image[int(body.chest[1]), int(body.chest[0])]
            print(f"Depth value at {body.chest[0]}, {body.chest[1]} pixel: {depth_value_at_pixel}")

            if depth_value_at_pixel < BRAKE_DISTANCE:
                rover.brake()
                speed = 1
            else:
                if chest_in_frame:
                    rover.forward(speed)

                x_diff = body.chest[0] - center[0]
                x_diff = (0.28125 * x_diff) + 90
                current_angle = x_diff
                print(current_angle)
                rover.turn(current_angle)
            
                prev_chest = body.chest

        
        # Draw poses and display them
        #draw_objects(color_image, 
        # 
        # counts, objects, peaks)
        draw_keypoints_and_values(color_image, counts, objects, peaks, topology)

        # Calculate FPS and display it
        current_frame_time = time.time()
        fps = (1 / (current_frame_time - prev_frame_time))
        prev_frame_time = current_frame_time
        fps_text = f'FPS: {fps:.0f}'
        cv2.putText(color_image, fps_text, (color_image.shape[1] - 150, color_image.shape[0] - 10), cv2.FONT_HERSHEY_SIMPLEX, 0.5, (255, 255, 255), 2)



        # Display the image
        cv2.imshow('Pose Estimation', color_image)
        if cv2.waitKey(1) & 0xFF == ord('q'):
            break

finally:
    
    rover.brake()
    pipeline.stop()
    cv2.destroyAllWindows()
# Out:
# Speeding up to 36
#
# Depth value at 558, 218 pixel: 2981
# Speeding up to 36
#
# 156.9375
# Speeding up to 36
#
# Depth value at 582, 237 pixel: 3163
# Speeding up to 36
#
# 163.6875
# Depth value at 582, 237 pixel: 3131
# 163.6875
# Depth value at 582, 237 pixel: 3423
# 163.6875
# Depth value at 582, 237 pixel: 4153
# 163.6875
# Depth value at 582, 237 pixel: 0
# Braking
#
# Depth value at 582, 237 pixel: 3520
# 163.6875
# Depth value at 582, 237 pixel: 3368
# Speeding up to 36
#
# 163.6875
# Depth value at 582, 237 pixel: 3163
# 163.6875
# Depth value at 582, 237 pixel: 3069
# 163.6875
# Depth value at 582, 237 pixel: 2925
# 163.6875
# Depth value at 582, 237 pixel: 2925
# 163.6875
# Depth value at 582, 237 pixel: 2898
# 163.6875
# Depth value at 582, 237 pixel: 2745
# 163.6875
# Depth value at 582, 237 pixel: 2745
# 163.6875
# Depth value at 582, 237 pixel: 2757
# 163.6875
# Depth value at 582, 237 pixel: 2733
# 163.6875
# Depth value at 582, 237 pixel: 2845
# 163.6875
# Depth value at 582, 237 pixel: 2685
# 163.6875
# Depth value at 582, 237 pixel: 2685
# 163.6875
# Depth value at 582, 237 pixel: 2522
# 163.6875
# Depth value at 582, 237 pixel: 2543
# 163.6875
# Depth value at 582, 237 pixel: 2674
# 163.6875
# Depth value at 582, 237 pixel: 2674
# 163.6875
# Depth value at 582, 237 pixel: 2757
# 163.6875
# Depth value at 582, 237 pixel: 2745
# 163.6875
# Depth value at 582, 237 pixel: 2733
# 163.6875
# Depth value at 582, 237 pixel: 2733
# 163.6875
# Depth value at 582, 237 pixel: 2757
# 163.6875
# Depth value at 582, 237 pixel: 2898
# 163.6875
# Depth value at 582, 237 pixel: 2953
# 163.6875
# Depth value at 582, 237 pixel: 2953
# 163.6875
# Depth value at 582, 237 pixel: 2995
# 163.6875
# Depth value at 582, 237 pixel: 2911
# 163.6875
# Depth value at 582, 237 pixel: 2953
# 163.6875
# Depth value at 582, 237 pixel: 2953
# 163.6875
# Depth value at 582, 237 pixel: 2995
# 163.6875
# Depth value at 582, 237 pixel: 3179
# 163.6875
# Depth value at 582, 237 pixel: 3069
# 163.6875
# Depth value at 582, 237 pixel: 3069
# 163.6875
# Depth value at 582, 237 pixel: 3228
# 163.6875
# Depth value at 582, 237 pixel: 3054
# Speeding up to 36
#
# 163.6875
# Depth value at 582, 237 pixel: 2967
# 163.6875
# Depth value at 582, 237 pixel: 2981
# 163.6875
# Depth value at 582, 237 pixel: 2806
# 163.6875
# Depth value at 582, 237 pixel: 2806
# 163.6875
# Depth value at 582, 237 pixel: 2745
# 163.6875
# Depth value at 582, 237 pixel: 2806
# 163.6875
# Depth value at 582, 237 pixel: 2898
# 163.6875
# Depth value at 582, 237 pixel: 2832
# 163.6875
# Depth value at 582, 237 pixel: 2845
# 163.6875
# Depth value at 582, 237 pixel: 2769
# 163.6875
# Depth value at 582, 237 pixel: 2769
# 163.6875
# Depth value at 582, 237 pixel: 2819
# 163.6875
# Depth value at 582, 237 pixel: 2662
# 163.6875
# Depth value at 582, 237 pixel: 2819
# 163.6875
# Depth value at 582, 237 pixel: 2685
# Speeding up to 36
#
# 163.6875
# Depth value at 582, 237 pixel: 2564
# 163.6875
# Depth value at 582, 237 pixel: 2564
# Speeding up to 36
#
# 163.6875
# Depth value at 582, 237 pixel: 2502
# Speeding up to 36
#
# 163.6875
# Depth value at 582, 237 pixel: 2415
# Speeding up to 36
#
# 163.6875
# Depth value at 582, 237 pixel: 2325
# 163.6875
# Depth value at 582, 237 pixel: 2307
# Speeding up to 36
#
# 163.6875
# Depth value at 582, 237 pixel: 2463
# 163.6875
# Depth value at 582, 237 pixel: 2257
# 163.6875
# Depth value at 582, 237 pixel: 2522
# Speeding up to 36
#
# 163.6875
# Depth value at 582, 237 pixel: 2618
# Speeding up to 36
#
# 163.6875
# Depth value at 582, 237 pixel: 2618
# Speeding up to 36
#
# 163.6875
# Depth value at 582, 237 pixel: 2662
# Speeding up to 36
#
# 163.6875
# Depth value at 582, 237 pixel: 2662
# Speeding up to 36
#
# 163.6875
# Depth value at 582, 237 pixel: 2733
# Speeding up to 36
#
# 163.6875
# Depth value at 582, 237 pixel: 2697
# Speeding up to 36
#
# 163.6875
# Depth value at 582, 237 pixel: 2745
# Speeding up to 36
#
# 163.6875
# Depth value at 582, 237 pixel: 2871
# Speeding up to 36
#
# 163.6875
# Depth value at 582, 237 pixel: 2871
# Speeding up to 36
#
# 163.6875
# Depth value at 582, 237 pixel: 3262
# Speeding up to 36
#
# 163.6875
# Depth value at 582, 237 pixel: 3228
# Speeding up to 36
#
# 163.6875
# Depth value at 582, 237 pixel: 3386
# Speeding up to 36
#
# 163.6875
# Depth value at 582, 237 pixel: 3386
# Speeding up to 36
#
# 163.6875
# Depth value at 582, 237 pixel: 3332
# Speeding up to 36
#
# 163.6875
# Depth value at 582, 237 pixel: 3314
# Speeding up to 36
#
# 163.6875
# Depth value at 582, 237 pixel: 3314
# Speeding up to 36
#
# 163.6875
# Depth value at 582, 237 pixel: 3211
# Speeding up to 36
#
# 163.6875
# Depth value at 582, 237 pixel: 3024
# Speeding up to 36
#
# 163.6875
# Depth value at 582, 237 pixel: 3147
# Speeding up to 36
#
# 163.6875
# Depth value at 582, 237 pixel: 3163
# Speeding up to 36
#
# 163.6875
# Depth value at 582, 237 pixel: 3163
# Speeding up to 36
#
# 163.6875
# Depth value at 582, 237 pixel: 3024
# Speeding up to 36
#
# 163.6875
# Depth value at 582, 237 pixel: 2967
# Speeding up to 36
#
# 163.6875
# Depth value at 582, 237 pixel: 2981
# Speeding up to 36
#
# 163.6875
# Depth value at 582, 237 pixel: 2898
# Speeding up to 36
#
# 163.6875
# Depth value at 582, 237 pixel: 2781
# Speeding up to 36
#
# 163.6875
# Depth value at 582, 237 pixel: 2858
# Speeding up to 36
#
# 163.6875
# Depth value at 582, 237 pixel: 2858
# Speeding up to 36
#
# 163.6875
# Depth value at 582, 237 pixel: 2794
# Speeding up to 36
#
# 163.6875
# Depth value at 582, 237 pixel: 2697
# Speeding up to 36
#
# 163.6875
# Depth value at 582, 237 pixel: 2674
# Speeding up to 36
#
# 163.6875
# Depth value at 582, 237 pixel: 2651
# 163.6875
# Depth value at 582, 237 pixel: 2662
# 163.6875
# Depth value at 582, 237 pixel: 2662
# 163.6875
# Depth value at 582, 237 pixel: 2662
# 163.6875
# Depth value at 582, 237 pixel: 2629
# 163.6875
# Depth value at 582, 237 pixel: 2685
# 163.6875
# Depth value at 582, 237 pixel: 2721
# 163.6875
# Depth value at 582, 237 pixel: 2674
# 163.6875
# Depth value at 582, 237 pixel: 2574
# 163.6875
# Depth value at 582, 237 pixel: 2607
# 163.6875
# Depth value at 582, 237 pixel: 2640
# 163.6875
# Depth value at 582, 237 pixel: 2662
# 163.6875
# Depth value at 582, 237 pixel: 2651
# 163.6875
# Depth value at 582, 237 pixel: 2564
# 163.6875
# Depth value at 582, 237 pixel: 2574
# 163.6875
# Depth value at 582, 237 pixel: 2482
# 163.6875
# Depth value at 582, 237 pixel: 2482
# 163.6875
# Depth value at 582, 237 pixel: 2553
# 163.6875
# Depth value at 582, 237 pixel: 2585
# 163.6875
# Depth value at 582, 237 pixel: 2629
# 163.6875
# Depth value at 582, 237 pixel: 2697
# 163.6875
# Depth value at 582, 237 pixel: 2697
# 163.6875
# Depth value at 582, 237 pixel: 2674
# 163.6875
# Depth value at 582, 237 pixel: 2709
# 163.6875
# Depth value at 582, 237 pixel: 0
# Braking
#
# Depth value at 582, 237 pixel: 551
# Braking
#
# Depth value at 582, 237 pixel: 551
# Braking
#
# Depth value at 582, 237 pixel: 514
# Braking
#
# Depth value at 582, 237 pixel: 487
# Braking
#
# Depth value at 582, 237 pixel: 498
# Braking
#
# Depth value at 582, 237 pixel: 485
# Braking
#
# Depth value at 582, 237 pixel: 469
# Braking
#
# Depth value at 582, 237 pixel: 466
# Braking
#
# Depth value at 582, 237 pixel: 451
# Braking
#
# Depth value at 582, 237 pixel: 439
# Braking
#
# Depth value at 582, 237 pixel: 439
# Braking
#
# Depth value at 582, 237 pixel: 463
# Braking
#
# Depth value at 582, 237 pixel: 476
# Braking
#
# Depth value at 582, 237 pixel: 493
# Braking
#
# Depth value at 582, 237 pixel: 2845
# Speeding up to 36
#
# 163.6875
# Depth value at 582, 237 pixel: 2794
# Speeding up to 36
#
# 163.6875
# Depth value at 582, 237 pixel: 2685
# Speeding up to 36
#
# 163.6875
# Depth value at 582, 237 pixel: 2618
# Speeding up to 36
#
# 163.6875
# Depth value at 582, 237 pixel: 2553
# Speeding up to 36
#
# 163.6875
# Depth value at 582, 237 pixel: 2697
# Speeding up to 36
#
# 163.6875
# Depth value at 582, 237 pixel: 2745
# Speeding up to 36
#
# 163.6875
# Depth value at 582, 237 pixel: 2911
# Speeding up to 36
#
# 163.6875
# Depth value at 582, 237 pixel: 2911
# Speeding up to 36
#
# 163.6875
# Depth value at 582, 237 pixel: 2953
# Speeding up to 36
#
# 163.6875
# Depth value at 582, 237 pixel: 2925
# Speeding up to 36
#
# 163.6875
# Depth value at 582, 237 pixel: 2884
# Speeding up to 36
#
# 163.6875
# Depth value at 582, 237 pixel: 2884
# Speeding up to 36
#
# 163.6875
# Depth value at 582, 237 pixel: 2832
# Speeding up to 36
#
# 163.6875
# Depth value at 582, 237 pixel: 2733
# Speeding up to 36
#
# 163.6875
# Depth value at 582, 237 pixel: 2697
# Speeding up to 36
#
# 163.6875
# Depth value at 582, 237 pixel: 2709
# Speeding up to 36
#
# 163.6875
# Depth value at 582, 237 pixel: 2640
# Speeding up to 36
#
# 163.6875
# Depth value at 582, 237 pixel: 2574
# Speeding up to 36
#
# 163.6875
# Depth value at 582, 237 pixel: 2845
# Speeding up to 36
#
# 163.6875
# Depth value at 582, 237 pixel: 2858
# Speeding up to 36
#
# 163.6875
# Depth value at 582, 237 pixel: 2925
# Speeding up to 36
#
# 163.6875
# Depth value at 582, 237 pixel: 2819
# Speeding up to 36
#
# 163.6875
# Depth value at 582, 237 pixel: 2925
# Speeding up to 36
#
# 163.6875
# Depth value at 582, 237 pixel: 2953
# Speeding up to 36
#
# 163.6875
# Depth value at 582, 237 pixel: 3069
# Speeding up to 36
#
# 163.6875
# Depth value at 582, 237 pixel: 3228
# Speeding up to 36
#
# 163.6875
# Depth value at 582, 237 pixel: 3228
# Speeding up to 36
#
# 163.6875
# Depth value at 582, 237 pixel: 3179
# Speeding up to 36
#
# 163.6875
# Depth value at 582, 237 pixel: 3279
# Speeding up to 36
#
# 163.6875
# Depth value at 582, 237 pixel: 3163
# Speeding up to 36
#
# 163.6875
# Depth value at 582, 237 pixel: 3163
# Speeding up to 36
#
# 163.6875
# Depth value at 582, 237 pixel: 3163
# Speeding up to 36
#
# 163.6875
# Depth value at 582, 237 pixel: 3195
# Speeding up to 36
#
# 163.6875
# Depth value at 582, 237 pixel: 3314
# Speeding up to 36
#
# 163.6875
# Depth value at 582, 237 pixel: 3179
# Speeding up to 36
#
# 163.6875
# Depth value at 582, 237 pixel: 3147
# Speeding up to 36
#
# 163.6875
# Depth value at 582, 237 pixel: 3245
# Speeding up to 36
#
# 163.6875
# Depth value at 582, 237 pixel: 3084
# Speeding up to 36
#
# 163.6875
# Depth value at 582, 237 pixel: 3147
# Speeding up to 36
#
# 163.6875
# Depth value at 582, 237 pixel: 3147
# Speeding up to 36
#
# 163.6875
# Depth value at 582, 237 pixel: 3115
# Speeding up to 36
#
# 163.6875
# Depth value at 582, 237 pixel: 3147
# Speeding up to 36
#
# 163.6875
# Depth value at 582, 237 pixel: 3163
# Speeding up to 36
#
# 163.6875
# Depth value at 582, 237 pixel: 3179
# Speeding up to 36
#
# 163.6875
# Depth value at 582, 237 pixel: 3262
# Speeding up to 36
#
# 163.6875
# Depth value at 582, 237 pixel: 3115
# Speeding up to 36
#
# 163.6875
# Depth value at 582, 237 pixel: 3332
# Speeding up to 36
#
# 163.6875
# Depth value at 582, 237 pixel: 3262
# Speeding up to 36
#
# 163.6875
# Depth value at 582, 237 pixel: 3211
# Speeding up to 36
#
# 163.6875
# Depth value at 582, 237 pixel: 3245
# Speeding up to 36
#
# 163.6875
# Depth value at 582, 237 pixel: 3147
# Speeding up to 36
#
# 163.6875
# Depth value at 582, 237 pixel: 3131
# Speeding up to 36
#
# 163.6875
# Depth value at 582, 237 pixel: 3211
# Speeding up to 36
#
# 163.6875
# Speeding up to 36
#
# Depth value at 355, 450 pixel: 1378
# Speeding up to 36
#
# 99.84375
# Depth value at 355, 450 pixel: 1384
# Speeding up to 36
#
# 99.84375
# Depth value at 355, 450 pixel: 1388
# Speeding up to 36
#
# 99.84375
# Depth value at 355, 450 pixel: 1413
# Speeding up to 36
#
# 99.84375
# Depth value at 355, 450 pixel: 1422
# Speeding up to 36
#
# 99.84375
# Depth value at 355, 450 pixel: 1480
# Speeding up to 36
#
# 99.84375
# Depth value at 355, 450 pixel: 2333
# Speeding up to 36
#
# 99.84375
# Depth value at 355, 450 pixel: 2378
# Speeding up to 36
#
# 99.84375
# Depth value at 355, 450 pixel: 2360
# Speeding up to 36
#
# 99.84375
# Depth value at 274, 433 pixel: 1381
# Speeding up to 36
#
# 77.0625
# Depth value at 274, 433 pixel: 1375
# Speeding up to 36
#
# 77.0625
# Depth value at 274, 433 pixel: 1378
# Speeding up to 36
#
# 77.0625
# Depth value at 274, 433 pixel: 1375
# Speeding up to 36
#
# 77.0625
# Depth value at 274, 433 pixel: 1375
# Speeding up to 36
#
# 77.0625
# Depth value at 274, 433 pixel: 1372
# Speeding up to 36
#
# 77.0625
# Depth value at 274, 433 pixel: 1375
# Speeding up to 36
#
# 77.0625
# Depth value at 274, 433 pixel: 1375
# Speeding up to 36
#
# 77.0625
# Depth value at 274, 433 pixel: 1384
# Speeding up to 36
#
# 77.0625
# Depth value at 274, 433 pixel: 1416
# Speeding up to 36
#
# 77.0625
# Depth value at 274, 433 pixel: 1490
# Speeding up to 36
#
# 77.0625
# Depth value at 274, 433 pixel: 1483
# Speeding up to 36
#
# 77.0625
# Depth value at 274, 433 pixel: 1490
# Speeding up to 36
#
# 77.0625
# Depth value at 274, 433 pixel: 1505
# Speeding up to 36
#
# 77.0625
# Depth value at 274, 433 pixel: 1516
# Speeding up to 36
#
# 77.0625
# Depth value at 274, 433 pixel: 1512
# Speeding up to 36
#
# 77.0625
# Depth value at 274, 433 pixel: 1516
# Speeding up to 36
#
# 77.0625
# Depth value at 274, 433 pixel: 1520
# Speeding up to 36
#
# 77.0625
# Depth value at 274, 433 pixel: 1527
# Speeding up to 36
#
# 77.0625
# Depth value at 274, 433 pixel: 1550
# Speeding up to 36
#
# 77.0625
# Depth value at 274, 433 pixel: 1501
# Speeding up to 36
#
# 77.0625
# Depth value at 274, 433 pixel: 1501
# Speeding up to 36
#
# 77.0625
# Depth value at 274, 433 pixel: 2201
# Speeding up to 36
#
# 77.0625
# Depth value at 274, 433 pixel: 2316
# Speeding up to 36
#
# 77.0625
# Depth value at 274, 433 pixel: 2249
# Speeding up to 36
#
# 77.0625
# Depth value at 274, 433 pixel: 2225
# Speeding up to 36
#
# 77.0625
# Depth value at 564, 418 pixel: 2415
# Speeding up to 36
#
# 158.625
# Braking
#
# Braking
#
# Braking
#
# Braking
#
# Braking
#
# Braking
#
# Braking
#
# Braking
#
# Braking
#
# Braking
#
# Braking
#
# Braking
#
# Braking
#
# Braking
#
# Braking
#
# Braking
#
# Braking
#
# Speeding up to 36
#
# Depth value at 381, 259 pixel: 3332
# Speeding up to 36
#
# 107.15625
# Speeding up to 36
#
# Depth value at 378, 257 pixel: 3332
# Speeding up to 36
#
# 106.3125
# Speeding up to 36
#
# Depth value at 375, 257 pixel: 3368
# Speeding up to 36
#
# 105.46875
# Speeding up to 36
#
# Depth value at 375, 261 pixel: 3296
# Speeding up to 36
#
# 105.46875
# Speeding up to 36
#
# Depth value at 367, 258 pixel: 3245
# Speeding up to 36
#
# 103.21875
# Depth value at 367, 258 pixel: 3296
# Speeding up to 36
#
# 103.21875
# Speeding up to 36
#
# Depth value at 354, 258 pixel: 3296
# Speeding up to 36
#
# 99.5625
# Speeding up to 36
#
# Depth value at 346, 258 pixel: 3296
# Speeding up to 36
#
# 97.3125
# Speeding up to 36
#
# Depth value at 336, 258 pixel: 3245
# Speeding up to 36
#
# 94.5
# Speeding up to 36
#
# Depth value at 328, 262 pixel: 3245
# Speeding up to 36
#
# 92.25
# Speeding up to 36
#
# Depth value at 321, 262 pixel: 3211
# Speeding up to 36
#
# 90.28125
# Speeding up to 36
#
# Depth value at 314, 263 pixel: 3195
# Speeding up to 36
#
# 88.3125
# Depth value at 307, 266 pixel: 3179
# Speeding up to 36
#
# 86.34375
# Depth value at 300, 268 pixel: 3179
# Speeding up to 36
#
# 84.375
# Depth value at 290, 274 pixel: 3163
# Speeding up to 36
#
# 81.5625
# Depth value at 276, 279 pixel: 3163
# Speeding up to 36
#
# 77.625
# Depth value at 263, 283 pixel: 3179
# Speeding up to 36
#
# 73.96875
# Depth value at 252, 287 pixel: 3163
# Speeding up to 36
#
# 70.875
# Depth value at 248, 293 pixel: 3163
# Speeding up to 36
#
# 69.75
# Depth value at 244, 298 pixel: 3228
# Speeding up to 36
#
# 68.625
# Depth value at 244, 308 pixel: 3084
# Speeding up to 36
#
# 68.625
# Depth value at 250, 315 pixel: 3100
# Speeding up to 36
#
# 70.3125
# Depth value at 260, 321 pixel: 3054
# Speeding up to 36
#
# 73.125
# Depth value at 269, 330 pixel: 2967
# Speeding up to 36
#
# 75.65625
# Depth value at 280, 333 pixel: 3039
# Speeding up to 36
#
# 78.75
# Depth value at 295, 331 pixel: 3115
# Speeding up to 36
#
# 82.96875
# Depth value at 309, 330 pixel: 3131
# Speeding up to 36
#
# 86.90625
# Depth value at 318, 330 pixel: 3084
# Speeding up to 36
#
# 89.4375
# Depth value at 326, 330 pixel: 3100
# Speeding up to 36
#
# 91.6875
# Depth value at 334, 331 pixel: 3100
# Speeding up to 36
#
# 93.9375
# Depth value at 335, 338 pixel: 3147
# Speeding up to 36
#
# 94.21875
# Depth value at 333, 342 pixel: 3131
# Speeding up to 36
#
# 93.65625
# Depth value at 329, 341 pixel: 3211
# Speeding up to 36
#
# 92.53125
# Depth value at 325, 345 pixel: 3147
# Speeding up to 36
#
# 91.40625
# Depth value at 317, 340 pixel: 3163
# Speeding up to 36
#
# 89.15625
# Depth value at 315, 342 pixel: 3147
# Speeding up to 36
#
# 88.59375
# Depth value at 310, 345 pixel: 3115
# Speeding up to 36
#
# 87.1875
# Depth value at 304, 346 pixel: 3163
# Speeding up to 36
#
# 85.5
# Depth value at 302, 345 pixel: 3163
# Speeding up to 36
#
# 84.9375
# Depth value at 300, 349 pixel: 3163
# Speeding up to 36
#
# 84.375
# Depth value at 297, 348 pixel: 3262
# Speeding up to 36
#
# 83.53125
# Depth value at 296, 351 pixel: 3296
# Speeding up to 36
#
# 83.25
# Depth value at 291, 350 pixel: 3211
# Speeding up to 36
#
# 81.84375
# Depth value at 289, 349 pixel: 3262
# Speeding up to 36
#
# 81.28125
# Depth value at 288, 350 pixel: 3228
# Speeding up to 36
#
# 81.0
# Depth value at 284, 351 pixel: 3195
# Speeding up to 36
#
# 79.875
# Depth value at 283, 359 pixel: 3228
# Speeding up to 36
#
# 79.59375
# Depth value at 279, 362 pixel: 3179
# Speeding up to 36
#
# 78.46875
# Depth value at 277, 364 pixel: 3195
# Speeding up to 36
#
# 77.90625
# Depth value at 279, 356 pixel: 3245
# Speeding up to 36
#
# 78.46875
# Depth value at 280, 356 pixel: 3296
# Speeding up to 36
#
# 78.75
# Depth value at 285, 354 pixel: 3314
# Speeding up to 36
#
# 80.15625
# Depth value at 294, 361 pixel: 3296
# Speeding up to 36
#
# 82.6875
# Depth value at 301, 352 pixel: 3332
# Speeding up to 36
#
# 84.65625
# Depth value at 307, 362 pixel: 3279
# Speeding up to 36
#
# 86.34375
# Depth value at 315, 364 pixel: 3279
# Speeding up to 36
#
# 88.59375
# Depth value at 315, 364 pixel: 3245
# Speeding up to 36
#
# 88.59375
# Depth value at 315, 364 pixel: 3279
# Speeding up to 36
#
# 88.59375
# Depth value at 315, 364 pixel: 3368
# Speeding up to 36
#
# 88.59375
# Depth value at 315, 364 pixel: 3350
# Speeding up to 36
#
# 88.59375
# Depth value at 315, 364 pixel: 3368
# Speeding up to 36
#
# 88.59375
# Depth value at 315, 364 pixel: 3350
# Speeding up to 36
#
# 88.59375
# Depth value at 345, 375 pixel: 3368
# Speeding up to 36
#
# 97.03125
# Depth value at 351, 372 pixel: 3350
# Speeding up to 36
#
# 98.71875
# Depth value at 357, 378 pixel: 3386
# Speeding up to 36
#
# 100.40625
# Depth value at 360, 378 pixel: 3581
# Speeding up to 36
#
# 101.25
# Depth value at 353, 378 pixel: 3461
# Speeding up to 36
#
# 99.28125
# Depth value at 340, 378 pixel: 3481
# Speeding up to 36
#
# 95.625
# Depth value at 330, 370 pixel: 3404
# Speeding up to 36
#
# 92.8125
# Depth value at 315, 369 pixel: 3500
# Speeding up to 36
#
# 88.59375
# Depth value at 309, 366 pixel: 3581
# Speeding up to 36
#
# 86.90625
# Depth value at 284, 376 pixel: 3500
# Speeding up to 36
#
# 79.875
# Depth value at 278, 376 pixel: 3481
# Speeding up to 36
#
# 78.1875
# Depth value at 263, 372 pixel: 3581
# Speeding up to 36
#
# 73.96875
# Depth value at 256, 368 pixel: 3731
# Speeding up to 36
#
# 72.0
# Depth value at 254, 374 pixel: 3643
# Speeding up to 36
#
# 71.4375
# Depth value at 256, 373 pixel: 3581
# Speeding up to 36
#
# 72.0
# Depth value at 265, 372 pixel: 3560
# Speeding up to 36
#
# 74.53125
# Depth value at 275, 382 pixel: 3643
# Speeding up to 36
#
# 77.34375
# Depth value at 290, 381 pixel: 3581
# Speeding up to 36
#
# 81.5625
# Depth value at 305, 390 pixel: 3687
# Speeding up to 36
#
# 85.78125
# Depth value at 322, 385 pixel: 3731
# Speeding up to 36
#
# 90.5625
# Depth value at 329, 386 pixel: 3846
# Speeding up to 36
#
# 92.53125
# Depth value at 342, 379 pixel: 3846
# Speeding up to 36
#
# 96.1875
# Depth value at 348, 375 pixel: 3822
# Speeding up to 36
#
# 97.875
# Depth value at 351, 377 pixel: 3846
# Speeding up to 36
#
# 98.71875
# Depth value at 350, 380 pixel: 3799
# Speeding up to 36
#
# 98.4375
# Depth value at 346, 386 pixel: 3822
# Speeding up to 36
#
# 97.3125
# Depth value at 336, 383 pixel: 3708
# Speeding up to 36
#
# 94.5
# Depth value at 323, 386 pixel: 3822
# Speeding up to 36
#
# 90.84375
# Depth value at 308, 390 pixel: 3708
# Speeding up to 36
#
# 86.625
# Depth value at 293, 383 pixel: 3822
# Speeding up to 36
#
# 82.40625
# Depth value at 285, 386 pixel: 3799
# Speeding up to 36
#
# 80.15625
# Depth value at 267, 384 pixel: 3731
# Speeding up to 36
#
# 75.09375
# Depth value at 260, 379 pixel: 3776
# Speeding up to 36
#
# 73.125
# Depth value at 256, 388 pixel: 3918
# Speeding up to 36
#
# 72.0
# Depth value at 257, 391 pixel: 3665
# Speeding up to 36
#
# 72.28125
# Depth value at 266, 391 pixel: 3665
# Speeding up to 36
#
# 74.8125
# Depth value at 275, 390 pixel: 3665
# Speeding up to 36
#
# 77.34375
# Depth value at 287, 393 pixel: 3994
# Speeding up to 36
#
# 80.71875
# Depth value at 299, 387 pixel: 3870
# Speeding up to 36
#
# 84.09375
# Depth value at 312, 388 pixel: 3968
# Speeding up to 36
#
# 87.75
# Depth value at 322, 390 pixel: 3943
# Speeding up to 36
#
# 90.5625
# Depth value at 326, 386 pixel: 3894
# Speeding up to 36
#
# 91.6875
# Depth value at 335, 392 pixel: 4019
# Speeding up to 36
#
# 94.21875
# Depth value at 335, 394 pixel: 3822
# Speeding up to 36
#
# 94.21875
# Depth value at 333, 390 pixel: 3846
# Speeding up to 36
#
# 93.65625
# Depth value at 326, 391 pixel: 3994
# Speeding up to 36
#
# 91.6875
# Depth value at 318, 398 pixel: 3968
# Speeding up to 36
#
# 89.4375
# Depth value at 308, 393 pixel: 3894
# Speeding up to 36
#
# 86.625
# Depth value at 300, 392 pixel: 4099
# Speeding up to 36
#
# 84.375
# Depth value at 288, 395 pixel: 3894
# Speeding up to 36
#
# 81.0
# Depth value at 281, 399 pixel: 3943
# Speeding up to 36
#
# 79.03125
# Depth value at 275, 399 pixel: 3846
# Speeding up to 36
#
# 77.34375
# Depth value at 272, 402 pixel: 3776
# Speeding up to 36
#
# 76.5
# Depth value at 273, 401 pixel: 3943
# Speeding up to 36
#
# 76.78125
# Depth value at 276, 395 pixel: 4019
# Speeding up to 36
#
# 77.625
# Depth value at 278, 399 pixel: 4046
# Speeding up to 36
#
# 78.1875
# Depth value at 283, 394 pixel: 4019
# Speeding up to 36
#
# 79.59375
# Depth value at 288, 394 pixel: 4046
# Speeding up to 36
#
# 81.0
# Depth value at 292, 397 pixel: 3994
# Speeding up to 36
#
# 82.125
# Depth value at 298, 409 pixel: 4019
# Speeding up to 36
#
# 83.8125
# Depth value at 301, 407 pixel: 3968
# Speeding up to 36
#
# 84.65625
# Depth value at 302, 402 pixel: 3994
# Speeding up to 36
#
# 84.9375
# Depth value at 303, 403 pixel: 4072
# Speeding up to 36
#
# 85.21875
# Depth value at 304, 401 pixel: 4072
# Speeding up to 36
#
# 85.5
# Depth value at 305, 397 pixel: 4099
# Speeding up to 36
#
# 85.78125
# Depth value at 307, 399 pixel: 4099
# Speeding up to 36
#
# 86.34375
# Depth value at 309, 400 pixel: 4019
# Speeding up to 36
#
# 86.90625
# Depth value at 312, 400 pixel: 4126
# Speeding up to 36
#
# 87.75
# Depth value at 314, 403 pixel: 3994
# Speeding up to 36
#
# 88.3125
# Depth value at 316, 408 pixel: 3994
# Speeding up to 36
#
# 88.875
# Depth value at 318, 400 pixel: 4099
# Speeding up to 36
#
# 89.4375
# Depth value at 319, 399 pixel: 4267
# Speeding up to 36
#
# 89.71875
# Depth value at 320, 408 pixel: 4046
# Speeding up to 36
#
# 90.0
# Depth value at 317, 402 pixel: 4046
# Speeding up to 36
#
# 89.15625
# Depth value at 317, 405 pixel: 4072
# Speeding up to 36
#
# 89.15625
# Depth value at 313, 402 pixel: 4072
# Speeding up to 36
#
# 88.03125
# Depth value at 308, 408 pixel: 3894
# Speeding up to 36
#
# 86.625
# Depth value at 301, 404 pixel: 4099
# Speeding up to 36
#
# 84.65625
# Depth value at 296, 407 pixel: 3968
# Speeding up to 36
#
# 83.25
# Depth value at 289, 408 pixel: 4046
# Speeding up to 36
#
# 81.28125
# Depth value at 286, 407 pixel: 4072
# Speeding up to 36
#
# 80.4375
# Depth value at 281, 409 pixel: 4019
# Speeding up to 36
#
# 79.03125
# Depth value at 277, 408 pixel: 4099
# Speeding up to 36
#
# 77.90625
# Depth value at 278, 405 pixel: 4046
# Speeding up to 36
#
# 78.1875
# Depth value at 279, 399 pixel: 4046
# Speeding up to 36
#
# 78.46875
# Depth value at 284, 408 pixel: 3918
# Speeding up to 36
#
# 79.875
# Depth value at 290, 404 pixel: 4099
# Speeding up to 36
#
# 81.5625
# Depth value at 297, 402 pixel: 4181
# Speeding up to 36
#
# 83.53125
# Depth value at 304, 405 pixel: 4153
# Speeding up to 36
#
# 85.5
# Depth value at 321, 396 pixel: 4210
# Speeding up to 36
#
# 90.28125
# Depth value at 324, 400 pixel: 4238
# Speeding up to 36
#
# 91.125
# Depth value at 333, 400 pixel: 4297
# Speeding up to 36
#
# 93.65625
# Depth value at 338, 403 pixel: 4548
# Speeding up to 36
#
# 95.0625
# Depth value at 337, 409 pixel: 4072
# Speeding up to 36
#
# 94.78125
# Depth value at 336, 407 pixel: 4046
# Speeding up to 36
#
# 94.5
# Depth value at 331, 405 pixel: 4450
# Speeding up to 36
#
# 93.09375
# Depth value at 326, 403 pixel: 4210
# Speeding up to 36
#
# 91.6875
# Depth value at 320, 410 pixel: 4238
# Speeding up to 36
#
# 90.0
# Depth value at 313, 406 pixel: 4357
# Speeding up to 36
#
# 88.03125
# Depth value at 306, 400 pixel: 4387
# Speeding up to 36
#
# 86.0625
# Depth value at 303, 406 pixel: 4153
# Speeding up to 36
#
# 85.21875
# Depth value at 298, 415 pixel: 4072
# Speeding up to 36
#
# 83.8125
# Depth value at 295, 412 pixel: 4019
# Speeding up to 36
#
# 82.96875
# Depth value at 295, 415 pixel: 4046
# Speeding up to 36
#
# 82.96875
# Depth value at 296, 411 pixel: 4072
# Speeding up to 36
#
# 83.25
# Depth value at 300, 408 pixel: 4126
# Speeding up to 36
#
# 84.375
# Depth value at 302, 406 pixel: 4126
# Speeding up to 36
#
# 84.9375
# Depth value at 303, 404 pixel: 4153
# Speeding up to 36
#
# 85.21875
# Depth value at 302, 405 pixel: 4046
# Speeding up to 36
#
# 84.9375
# Depth value at 303, 403 pixel: 4126
# Speeding up to 36
#
# 85.21875
# Depth value at 303, 413 pixel: 4019
# Speeding up to 36
#
# 85.21875
# Depth value at 304, 409 pixel: 4046
# Speeding up to 36
#
# 85.5
# Depth value at 303, 410 pixel: 4153
# Speeding up to 36
#
# 85.21875
# Depth value at 303, 411 pixel: 4126
# Speeding up to 36
#
# 85.21875
# Depth value at 305, 413 pixel: 4046
# Speeding up to 36
#
# 85.78125
# Depth value at 305, 410 pixel: 4181
# Speeding up to 36
#
# 85.78125
# Depth value at 308, 410 pixel: 4072
# Speeding up to 36
#
# 86.625
# Depth value at 310, 404 pixel: 4072
# Speeding up to 36
#
# 87.1875
# Depth value at 310, 404 pixel: 4072
# Speeding up to 36
#
# 87.1875
# Depth value at 312, 408 pixel: 4126
# Speeding up to 36
#
# 87.75
# Depth value at 313, 402 pixel: 4072
# Speeding up to 36
#
# 88.03125
# Depth value at 314, 402 pixel: 4072
# Speeding up to 36
#
# 88.3125
# Depth value at 314, 404 pixel: 4099
# Speeding up to 36
#
# 88.3125
# Depth value at 316, 404 pixel: 4238
# Speeding up to 36
#
# 88.875
# Depth value at 316, 402 pixel: 4210
# Speeding up to 36
#
# 88.875
# Depth value at 316, 401 pixel: 4238
# Speeding up to 36
#
# 88.875
# Depth value at 315, 404 pixel: 4153
# Speeding up to 36
#
# 88.59375
# Depth value at 314, 406 pixel: 4099
# Speeding up to 36
#
# 88.3125
# Depth value at 309, 405 pixel: 4153
# Speeding up to 36
#
# 86.90625
# Depth value at 305, 404 pixel: 4072
# Speeding up to 36
#
# 85.78125
# Depth value at 300, 404 pixel: 4153
# Speeding up to 36
#
# 84.375
# Depth value at 296, 400 pixel: 4099
# Speeding up to 36
#
# 83.25
# Depth value at 290, 406 pixel: 4126
# Speeding up to 36
#
# 81.5625
# Depth value at 286, 402 pixel: 4099
# Speeding up to 36
#
# 80.4375
# Depth value at 282, 402 pixel: 4099
# Speeding up to 36
#
# 79.3125
# Depth value at 280, 402 pixel: 4046
# Speeding up to 36
#
# 78.75
# Depth value at 279, 414 pixel: 3994
# Speeding up to 36
#
# 78.46875
# Depth value at 281, 412 pixel: 3870
# Speeding up to 36
#
# 79.03125
# Depth value at 283, 407 pixel: 3994
# Speeding up to 36
#
# 79.59375
# Depth value at 284, 406 pixel: 4046
# Speeding up to 36
#
# 79.875
# Depth value at 288, 407 pixel: 4099
# Speeding up to 36
#
# 81.0
# Depth value at 290, 402 pixel: 4126
# Speeding up to 36
#
# 81.5625
# Depth value at 294, 400 pixel: 4072
# Speeding up to 36
#
# 82.6875
# Depth value at 295, 404 pixel: 4019
# Speeding up to 36
#
# 82.96875
# Depth value at 299, 405 pixel: 4019
# Speeding up to 36
#
# 84.09375
# Depth value at 298, 410 pixel: 4072
# Speeding up to 36
#
# 83.8125
# Depth value at 299, 408 pixel: 4046
# Speeding up to 36
#
# 84.09375
# Depth value at 301, 404 pixel: 4046
# Speeding up to 36
#
# 84.65625
# Depth value at 302, 403 pixel: 4072
# Speeding up to 36
#
# 84.9375
# Depth value at 303, 396 pixel: 4072
# Speeding up to 36
#
# 85.21875
# Depth value at 306, 398 pixel: 4019
# Speeding up to 36
#
# 86.0625
# Depth value at 310, 399 pixel: 3994
# Speeding up to 36
#
# 87.1875
# Depth value at 315, 406 pixel: 4153
# Speeding up to 36
#
# 88.59375
# Depth value at 320, 406 pixel: 4181
# Speeding up to 36
#
# 90.0
# Depth value at 322, 404 pixel: 4238
# Speeding up to 36
#
# 90.5625
# Depth value at 325, 400 pixel: 4450
# Speeding up to 36
#
# 91.40625
# Depth value at 326, 404 pixel: 4267
# Speeding up to 36
#
# 91.6875
# Depth value at 325, 400 pixel: 4297
# Speeding up to 36
#
# 91.40625
# Depth value at 326, 404 pixel: 4181
# Speeding up to 36
#
# 91.6875
# Depth value at 322, 403 pixel: 4099
# Speeding up to 36
#
# 90.5625
# Depth value at 314, 410 pixel: 3822
# Speeding up to 36
#
# 88.3125
# Depth value at 310, 402 pixel: 4126
# Speeding up to 36
#
# 87.1875
# Depth value at 303, 399 pixel: 4046
# Speeding up to 36
#
# 85.21875
# Depth value at 299, 399 pixel: 3968
# Speeding up to 36
#
# 84.09375
# Depth value at 297, 398 pixel: 4099
# Speeding up to 36
#
# 83.53125
# Depth value at 289, 404 pixel: 3994
# Speeding up to 36
#
# 81.28125
# Depth value at 288, 401 pixel: 3822
# Speeding up to 36
#
# 81.0
# Depth value at 285, 400 pixel: 4181
# Speeding up to 36
#
# 80.15625
# Depth value at 285, 399 pixel: 4072
# Speeding up to 36
#
# 80.15625
# Depth value at 286, 400 pixel: 4046
# Speeding up to 36
#
# 80.4375
# Depth value at 290, 402 pixel: 4046
# Speeding up to 36
#
# 81.5625
# Depth value at 296, 398 pixel: 4019
# Speeding up to 36
#
# 83.25
# Depth value at 301, 397 pixel: 4019
# Speeding up to 36
#
# 84.65625
# Depth value at 304, 397 pixel: 4046
# Speeding up to 36
#
# 85.5
# Depth value at 311, 400 pixel: 4126
# Speeding up to 36
#
# 87.46875
# Depth value at 314, 398 pixel: 4099
# Speeding up to 36
#
# 88.3125
# Depth value at 316, 399 pixel: 4099
# Speeding up to 36
#
# 88.875
# Depth value at 322, 399 pixel: 3968
# Speeding up to 36
#
# 90.5625
# Depth value at 325, 405 pixel: 4072
# Speeding up to 36
#
# 91.40625
# Depth value at 325, 400 pixel: 4019
# Speeding up to 36
#
# 91.40625
# Depth value at 328, 401 pixel: 4126
# Speeding up to 36
#
# 92.25
# Depth value at 325, 397 pixel: 4210
# Speeding up to 36
#
# 91.40625
# Depth value at 325, 397 pixel: 4153
# Speeding up to 36
#
# 91.40625
# Depth value at 317, 397 pixel: 4099
# Speeding up to 36
#
# 89.15625
# Depth value at 317, 397 pixel: 4126
# Speeding up to 36
#
# 89.15625
# Depth value at 305, 401 pixel: 3968
# Speeding up to 36
#
# 85.78125
# Depth value at 304, 401 pixel: 3968
# Speeding up to 36
#
# 85.5
# Depth value at 301, 408 pixel: 4099
# Speeding up to 36
#
# 84.65625
# Depth value at 299, 407 pixel: 3994
# Speeding up to 36
#
# 84.09375
# Depth value at 295, 405 pixel: 3968
# Speeding up to 36
#
# 82.96875
# Depth value at 295, 405 pixel: 4046
# Speeding up to 36
#
# 82.96875
# Depth value at 294, 402 pixel: 4072
# Speeding up to 36
#
# 82.6875
# Depth value at 294, 398 pixel: 3943
# Speeding up to 36
#
# 82.6875
# Depth value at 294, 395 pixel: 3994
# Speeding up to 36
#
# 82.6875
# Depth value at 295, 394 pixel: 3943
# Speeding up to 36
#
# 82.96875
# Depth value at 296, 398 pixel: 4072
# Speeding up to 36
#
# 83.25
# Depth value at 296, 398 pixel: 4072
# Speeding up to 36
#
# 83.25
# Depth value at 297, 395 pixel: 4019
# Speeding up to 36
#
# 83.53125
# Depth value at 299, 396 pixel: 3943
# Speeding up to 36
#
# 84.09375
# Depth value at 301, 395 pixel: 4072
# Speeding up to 36
#
# 84.65625
# Depth value at 302, 398 pixel: 4181
# Speeding up to 36
#
# 84.9375
# Depth value at 305, 397 pixel: 4046
# Speeding up to 36
#
# 85.78125
# Depth value at 307, 399 pixel: 3870
# Speeding up to 36
#
# 86.34375
# Depth value at 307, 399 pixel: 4099
# Speeding up to 36
#
# 86.34375
# Depth value at 315, 405 pixel: 3994
# Speeding up to 36
#
# 88.59375
# Depth value at 322, 403 pixel: 3994
# Speeding up to 36
#
# 90.5625
# Depth value at 324, 400 pixel: 4072
# Speeding up to 36
#
# 91.125
# Depth value at 328, 397 pixel: 4126
# Speeding up to 36
#
# 92.25
# Depth value at 331, 395 pixel: 4181
# Speeding up to 36
#
# 93.09375
# Depth value at 333, 397 pixel: 4019
# Speeding up to 36
#
# 93.65625
# Depth value at 330, 397 pixel: 3846
# Speeding up to 36
#
# 92.8125
# Depth value at 325, 399 pixel: 3870
# Speeding up to 36
#
# 91.40625
# Depth value at 319, 399 pixel: 4153
# Speeding up to 36
#
# 89.71875
# Depth value at 319, 399 pixel: 3943
# Speeding up to 36
#
# 89.71875
# Depth value at 308, 402 pixel: 3943
# Speeding up to 36
#
# 86.625
# Depth value at 296, 395 pixel: 3870
# Speeding up to 36
#
# 83.25
# Depth value at 294, 395 pixel: 3918
# Speeding up to 36
#
# 82.6875
# Depth value at 288, 392 pixel: 4153
# Speeding up to 36
#
# 81.0
# Depth value at 283, 395 pixel: 3822
# Speeding up to 36
#
# 79.59375
# Depth value at 281, 389 pixel: 3918
# Speeding up to 36
#
# 79.03125
# Depth value at 279, 388 pixel: 3846
# Speeding up to 36
#
# 78.46875
# Depth value at 278, 394 pixel: 3918
# Speeding up to 36
#
# 78.1875
# Depth value at 283, 406 pixel: 3708
# Speeding up to 36
#
# 79.59375
# Depth value at 287, 396 pixel: 4019
# Speeding up to 36
#
# 80.71875
# Depth value at 294, 368 pixel: 3846
# Speeding up to 36
#
# 82.6875
# Depth value at 302, 373 pixel: 4126
# Speeding up to 36
#
# 84.9375
# Depth value at 302, 370 pixel: 4099
# Speeding up to 36
#
# 84.9375
# Depth value at 303, 375 pixel: 4297
# Speeding up to 36
#
# 85.21875
# Depth value at 304, 384 pixel: 4210
# Speeding up to 36
#
# 85.5
# Depth value at 309, 386 pixel: 4515
# Speeding up to 36
#
# 86.90625
# Depth value at 308, 387 pixel: 4450
# Speeding up to 36
#
# 86.625
# Depth value at 307, 392 pixel: 4357
# Speeding up to 36
#
# 86.34375
# Depth value at 308, 394 pixel: 4581
# Speeding up to 36
#
# 86.625
# Depth value at 309, 393 pixel: 4615
# Speeding up to 36
#
# 86.90625
# Depth value at 312, 394 pixel: 4548
# Speeding up to 36
#
# 87.75
# Depth value at 312, 394 pixel: 4984
# Speeding up to 36
#
# 87.75
# Depth value at 312, 394 pixel: 4792
# Speeding up to 36
#
# 87.75
# Depth value at 312, 394 pixel: 5024
# Speeding up to 36
#
# 87.75
# Speeding up to 36
#
# Depth value at 315, 413 pixel: 4830
# Speeding up to 36
#
# 88.59375
# Braking
#
# Braking
#
# Braking
#
# Speeding up to 36
#
# Depth value at 361, 282 pixel: 3115
# Speeding up to 36
#
# 101.53125
# Speeding up to 36
#
# Depth value at 361, 281 pixel: 3147
# Speeding up to 36
#
# 101.53125
# Speeding up to 36
#
# Depth value at 360, 281 pixel: 3131
# Speeding up to 36
#
# 101.25
# Speeding up to 36
#
# Depth value at 357, 283 pixel: 3147
# Speeding up to 36
#
# 100.40625
# Speeding up to 36
#
# Depth value at 353, 293 pixel: 3115
# Speeding up to 36
#
# 99.28125
# Speeding up to 36
#
# Depth value at 353, 294 pixel: 3147
# Speeding up to 36
#
# 99.28125
# Speeding up to 36
#
# Depth value at 350, 294 pixel: 3163
# Speeding up to 36
#
# 98.4375
# Speeding up to 36
#
# Depth value at 346, 293 pixel: 3147
# Speeding up to 36
#
# 97.3125
# Depth value at 346, 293 pixel: 3179
# Speeding up to 36
#
# 97.3125
# Depth value at 339, 289 pixel: 3147
# Speeding up to 36
#
# 95.34375
# Depth value at 335, 290 pixel: 3100
# Speeding up to 36
#
# 94.21875
# Depth value at 334, 290 pixel: 3010
# Speeding up to 36
#
# 93.9375
# Depth value at 334, 288 pixel: 2981
# Speeding up to 36
#
# 93.9375
# Depth value at 336, 287 pixel: 2953
# Speeding up to 36
#
# 94.5
# Depth value at 337, 285 pixel: 2871
# Speeding up to 36
#
# 94.78125
# Depth value at 337, 285 pixel: 2832
# Speeding up to 36
#
# 94.78125
# Depth value at 337, 285 pixel: 2745
# Speeding up to 36
#
# 94.78125
# Depth value at 350, 264 pixel: 2806
# Speeding up to 36
#
# 98.4375
# Depth value at 350, 264 pixel: 2769
# Speeding up to 36
#
# 98.4375
# Depth value at 355, 255 pixel: 2794
# Speeding up to 36
#
# 99.84375
# Depth value at 360, 252 pixel: 2806
# Speeding up to 36
#
# 101.25
# Depth value at 360, 252 pixel: 2697
# Speeding up to 36
#
# 101.25
# Depth value at 360, 252 pixel: 2564
# Speeding up to 36
#
# 101.25
# Depth value at 360, 252 pixel: 2482
# Speeding up to 36
#
# 101.25
# Depth value at 360, 252 pixel: 2387
# Speeding up to 36
#
# 101.25
# Depth value at 360, 252 pixel: 2360
# Speeding up to 36
#
# 101.25
# Depth value at 360, 252 pixel: 2249
# Speeding up to 36
#
# 101.25
# Depth value at 360, 252 pixel: 2178
# Speeding up to 36
#
# 101.25
# Depth value at 390, 199 pixel: 2585
# Speeding up to 36
#
# 109.6875
# Depth value at 395, 193 pixel: 2674
# Speeding up to 36
#
# 111.09375
# Depth value at 404, 196 pixel: 2995
# Speeding up to 36
#
# 113.625
# Depth value at 412, 188 pixel: 3100
# Speeding up to 36
#
# 115.875
# Depth value at 412, 188 pixel: 2939
# Speeding up to 36
#
# 115.875
# Depth value at 417, 175 pixel: 3131
# Speeding up to 36
#
# 117.28125
# Depth value at 417, 175 pixel: 3332
# Speeding up to 36
#
# 117.28125
# Depth value at 417, 175 pixel: 3560
# Speeding up to 36
#
# 117.28125
# Depth value at 417, 175 pixel: 3581
# Speeding up to 36
#
# 117.28125
# Depth value at 417, 175 pixel: 3601
# Speeding up to 36
#
# 117.28125
# Depth value at 417, 175 pixel: 3601
# Speeding up to 36
#
# 117.28125
# Depth value at 417, 175 pixel: 3870
# Speeding up to 36
#
# 117.28125
# Depth value at 417, 175 pixel: 3665
# Speeding up to 36
#
# 117.28125
# Depth value at 417, 175 pixel: 3968
# Speeding up to 36
#
# 117.28125
# Depth value at 417, 175 pixel: 4181
# Speeding up to 36
#
# 117.28125
# Depth value at 417, 175 pixel: 4267
# Speeding up to 36
#
# 117.28125
# Depth value at 417, 175 pixel: 4267
# Speeding up to 36
#
# 117.28125
# Depth value at 417, 175 pixel: 4210
# Speeding up to 36
#
# 117.28125
# Depth value at 417, 175 pixel: 4181
# Speeding up to 36
#
# 117.28125
# Depth value at 417, 175 pixel: 4387
# Speeding up to 36
#
# 117.28125
# Depth value at 417, 175 pixel: 4297
# Speeding up to 36
#
# 117.28125
# Depth value at 417, 175 pixel: 4327
# Speeding up to 36
#
# 117.28125
# Depth value at 417, 175 pixel: 4387
# Speeding up to 36
#
# 117.28125
# Depth value at 417, 175 pixel: 4046
# Speeding up to 36
#
# 117.28125
# Depth value at 417, 175 pixel: 4297
# Speeding up to 36
#
# 117.28125
# Depth value at 417, 175 pixel: 4099
# Speeding up to 36
#
# 117.28125
# Depth value at 417, 175 pixel: 4387
# Speeding up to 36
#
# 117.28125
# Depth value at 417, 175 pixel: 4267
# Speeding up to 36
#
# 117.28125
# Depth value at 417, 175 pixel: 4238
# Speeding up to 36
#
# 117.28125
# Depth value at 417, 175 pixel: 4387
# Speeding up to 36
#
# 117.28125
# Depth value at 417, 175 pixel: 3279
# Speeding up to 36
#
# 117.28125
# Depth value at 417, 175 pixel: 3100
# Speeding up to 36
#
# 117.28125
# Depth value at 417, 175 pixel: 1959
# 117.28125
# Depth value at 417, 175 pixel: 1811
# 117.28125
# Depth value at 417, 175 pixel: 1366
# 117.28125
# Depth value at 417, 175 pixel: 1366
# 117.28125
# Depth value at 417, 175 pixel: 1217
# Braking
#
# Depth value at 417, 175 pixel: 1205
# Braking
#
# Depth value at 417, 175 pixel: 1054
# Braking
#
# Depth value at 417, 175 pixel: 934
# Braking
#
# Depth value at 417, 175 pixel: 934
# Braking
#
# Depth value at 417, 175 pixel: 791
# Braking
#
# Depth value at 417, 175 pixel: 694
# Braking
#
# Depth value at 417, 175 pixel: 611
# Braking
#
# Depth value at 417, 175 pixel: 525
# Braking
#
# Depth value at 417, 175 pixel: 467
# Braking
#
# Depth value at 417, 175 pixel: 467
# Braking
#
# Depth value at 417, 175 pixel: 413
# Braking
#
# Depth value at 417, 175 pixel: 363
# Braking
#
# Depth value at 417, 175 pixel: 323
# Braking
#
# Depth value at 417, 175 pixel: 290
# Braking
#
# Depth value at 417, 175 pixel: 262
# Braking
#
# Depth value at 417, 175 pixel: 260
# Braking
#
# Depth value at 417, 175 pixel: 260
# Braking
#
# Depth value at 417, 175 pixel: 270
# Braking
#
# Depth value at 417, 175 pixel: 277
# Braking
#
# Depth value at 417, 175 pixel: 282
# Braking
#
# Depth value at 417, 175 pixel: 282
# Braking
#
# Depth value at 417, 175 pixel: 283
# Braking
#
# Depth value at 417, 175 pixel: 283
# Braking
#
# Depth value at 417, 175 pixel: 278
# Braking
#
# Depth value at 417, 175 pixel: 278
# Braking
#
# Depth value at 417, 175 pixel: 279
# Braking
#
# Depth value at 417, 175 pixel: 280
# Braking
#
# Depth value at 417, 175 pixel: 281
# Braking
#
# Depth value at 417, 175 pixel: 279
# Braking
#
# Depth value at 417, 175 pixel: 279
# Braking
#
# Depth value at 417, 175 pixel: 279
# Braking
#
# Depth value at 417, 175 pixel: 279
# Braking
#
# Depth value at 417, 175 pixel: 280
# Braking
#
# Depth value at 417, 175 pixel: 279
# Braking
#
# Depth value at 417, 175 pixel: 279
# Braking
#
# Depth value at 417, 175 pixel: 279
# Braking
#
# Depth value at 417, 175 pixel: 280
# Braking
#
# Depth value at 417, 175 pixel: 280
# Braking
#
# Depth value at 417, 175 pixel: 280
# Braking
#
# Depth value at 417, 175 pixel: 279
# Braking
#
# Depth value at 417, 175 pixel: 279
# Braking
#
# Depth value at 417, 175 pixel: 280
# Braking
#
# Depth value at 417, 175 pixel: 279
# Braking
#
# Depth value at 417, 175 pixel: 280
# Braking
#
# Depth value at 417, 175 pixel: 279
# Braking
#
# Depth value at 417, 175 pixel: 279
# Braking
#
# Depth value at 417, 175 pixel: 279
# Braking
#
# Depth value at 417, 175 pixel: 280
# Braking
#
# Depth value at 417, 175 pixel: 279
# Braking
#
# Depth value at 417, 175 pixel: 279
# Braking
#
# Depth value at 417, 175 pixel: 280
# Braking
#
# Depth value at 417, 175 pixel: 280
# Braking
#
# Depth value at 417, 175 pixel: 280
# Braking
#
# Depth value at 417, 175 pixel: 280
# Braking
#
# Depth value at 417, 175 pixel: 279
# Braking
#
# Depth value at 417, 175 pixel: 279
# Braking
#
# Depth value at 417, 175 pixel: 279
# Braking
#
# Depth value at 417, 175 pixel: 280
# Braking
#
# Depth value at 417, 175 pixel: 279
# Braking
#
# Depth value at 417, 175 pixel: 279
# Braking
#
# Depth value at 417, 175 pixel: 279
# Braking
#
# Depth value at 417, 175 pixel: 280
# Braking
#
# Depth value at 417, 175 pixel: 280
# Braking
#
# Depth value at 417, 175 pixel: 280
# Braking
#
# Depth value at 417, 175 pixel: 280
# Braking
#
# Depth value at 417, 175 pixel: 279
# Braking
#
# Depth value at 417, 175 pixel: 279
# Braking
#
# Depth value at 417, 175 pixel: 279
# Braking
#
# Depth value at 417, 175 pixel: 280
# Braking
#
# Depth value at 417, 175 pixel: 280
# Braking
#
# Depth value at 417, 175 pixel: 280
# Braking
#
# Depth value at 417, 175 pixel: 280
# Braking
#
# Depth value at 417, 175 pixel: 279
# Braking
#
# Depth value at 417, 175 pixel: 279
# Braking
#
# Depth value at 417, 175 pixel: 279
# Braking
#
# Depth value at 417, 175 pixel: 279
# Braking
#
# Depth value at 417, 175 pixel: 279
# Braking
#
# Depth value at 417, 175 pixel: 279
# Braking
#
# Depth value at 417, 175 pixel: 280
# Braking
#
# Depth value at 417, 175 pixel: 280
# Braking
#
# Depth value at 417, 175 pixel: 279
# Braking
#
# Depth value at 417, 175 pixel: 279
# Braking
#
# Depth value at 417, 175 pixel: 279
# Braking
#
# Depth value at 417, 175 pixel: 280
# Braking
#
# Depth value at 417, 175 pixel: 280
# Braking
#
# Depth value at 417, 175 pixel: 280
# Braking
#
# Depth value at 417, 175 pixel: 280
# Braking
#
# Depth value at 417, 175 pixel: 280
# Braking
#
# Depth value at 417, 175 pixel: 280
# Braking
#
# Depth value at 417, 175 pixel: 280
# Braking
#
# Depth value at 417, 175 pixel: 280
# Braking
#
# Depth value at 417, 175 pixel: 280
# Braking
#
# Depth value at 417, 175 pixel: 280
# Braking
#
# Depth value at 417, 175 pixel: 279
# Braking
#
# Depth value at 417, 175 pixel: 279
# Braking
#
# Depth value at 417, 175 pixel: 279
# Braking
#
# Depth value at 417, 175 pixel: 279
# Braking
#
# Depth value at 417, 175 pixel: 279
# Braking
#
# Depth value at 417, 175 pixel: 280
# Braking
#
# Depth value at 417, 175 pixel: 280
# Braking
#
# Depth value at 417, 175 pixel: 279
# Braking
#
# Depth value at 417, 175 pixel: 279
# Braking
#
# Depth value at 417, 175 pixel: 279
# Braking
#
# Depth value at 417, 175 pixel: 279
# Braking
#
# Depth value at 417, 175 pixel: 280
# Braking
#
# Depth value at 417, 175 pixel: 280
# Braking
#
# Depth value at 417, 175 pixel: 280
# Braking
#
# Depth value at 417, 175 pixel: 279
# Braking
#
# Depth value at 417, 175 pixel: 279
# Braking
#
# Depth value at 417, 175 pixel: 280
# Braking
#
# Depth value at 417, 175 pixel: 280
# Braking
#
# Depth value at 417, 175 pixel: 280
# Braking
#
# Depth value at 417, 175 pixel: 280
# Braking
#
# Depth value at 417, 175 pixel: 280
# Braking
#
# Depth value at 417, 175 pixel: 280
# Braking
#
# Depth value at 417, 175 pixel: 280
# Braking
#
# Depth value at 417, 175 pixel: 280
# Braking
#
# Depth value at 417, 175 pixel: 280
# Braking
#
# Depth value at 417, 175 pixel: 280
# Braking
#
# Depth value at 417, 175 pixel: 280
# Braking
#
# Depth value at 417, 175 pixel: 279
# Braking
#
# Depth value at 417, 175 pixel: 280
# Braking
#
# Depth value at 417, 175 pixel: 280
# Braking
#
# Depth value at 417, 175 pixel: 280
# Braking
#
# Depth value at 417, 175 pixel: 282
# Braking
#
# Depth value at 417, 175 pixel: 287
# Braking
#
# Depth value at 417, 175 pixel: 307
# Braking
#
# Depth value at 417, 175 pixel: 307
# Braking
#
# Depth value at 417, 175 pixel: 343
# Braking
#
# Depth value at 417, 175 pixel: 400
# Braking
#
# Depth value at 417, 175 pixel: 503
# Braking
#
# Depth value at 417, 175 pixel: 670
# Braking
#
# Depth value at 417, 175 pixel: 670
# Braking
#
# Depth value at 417, 175 pixel: 927
# Braking
#
# Depth value at 417, 175 pixel: 1210
# Braking
#
# Depth value at 417, 175 pixel: 1210
# Braking
#
# Depth value at 417, 175 pixel: 1854
# 117.28125
# Depth value at 417, 175 pixel: 2564
# 117.28125
# Depth value at 417, 175 pixel: 671
# Braking
#
# Depth value at 417, 175 pixel: 555
# Braking
#
# Depth value at 417, 175 pixel: 502
# Braking
#
# Depth value at 417, 175 pixel: 494
# Braking
#
# Depth value at 417, 175 pixel: 497
# Braking
#
# Depth value at 417, 175 pixel: 497
# Braking
#
# Depth value at 417, 175 pixel: 502
# Braking
#
# Depth value at 417, 175 pixel: 501
# Braking
#
# Depth value at 417, 175 pixel: 505
# Braking
#
# Depth value at 417, 175 pixel: 508
# Braking
#
# Depth value at 417, 175 pixel: 506
# Braking
#
# Depth value at 417, 175 pixel: 506
# Braking
#
# Depth value at 417, 175 pixel: 509
# Braking
#
# Depth value at 417, 175 pixel: 515
# Braking
#
# Depth value at 417, 175 pixel: 526
# Braking
#
# Depth value at 417, 175 pixel: 526
# Braking
#
# Depth value at 417, 175 pixel: 407
# Braking
#
# Depth value at 417, 175 pixel: 505
# Braking
#
# Depth value at 417, 175 pixel: 505
# Braking
#
# Depth value at 417, 175 pixel: 0
# Braking
#
# Depth value at 417, 175 pixel: 915
# Braking
#
# Depth value at 417, 175 pixel: 915
# Braking
#
# Depth value at 417, 175 pixel: 0
# Braking
#
# Depth value at 417, 175 pixel: 0
# Braking
#
# Depth value at 417, 175 pixel: 0
# Braking
#
# Depth value at 348, 22 pixel: 1446
# Speeding up to 36
#
# 97.875
# Depth value at 348, 22 pixel: 0
# Braking
#
# Depth value at 348, 22 pixel: 2733
# Speeding up to 36
#
# 97.875
# Depth value at 348, 22 pixel: 2685
# Speeding up to 36
#
# 97.875
# Depth value at 348, 114 pixel: 1755
# Speeding up to 36
#
# 97.875
# Depth value at 342, 135 pixel: 1702
# Speeding up to 36
#
# 96.1875
# Depth value at 334, 154 pixel: 1801
# Speeding up to 36
#
# 93.9375
# Depth value at 334, 157 pixel: 1911
# Speeding up to 36
#
# 93.9375
# Depth value at 330, 166 pixel: 1947
# Speeding up to 36
#
# 92.8125
# Depth value at 330, 166 pixel: 1972
# Speeding up to 36
#
# 92.8125
# Depth value at 331, 188 pixel: 2098
# Speeding up to 36
#
# 93.09375
# Depth value at 333, 193 pixel: 2119
# Speeding up to 36
#
# 93.65625
# Depth value at 337, 201 pixel: 2148
# Speeding up to 36
#
# 94.78125
# Depth value at 339, 204 pixel: 2194
# Speeding up to 36
#
# 95.34375
# Depth value at 334, 204 pixel: 2233
# Speeding up to 36
#
# 93.9375
# Depth value at 326, 203 pixel: 2225
# Speeding up to 36
#
# 91.6875
# Depth value at 320, 206 pixel: 2274
# Speeding up to 36
#
# 90.0
# Depth value at 311, 204 pixel: 2316
# Speeding up to 36
#
# 87.46875
# Depth value at 299, 206 pixel: 2360
# Speeding up to 36
#
# 84.09375
# Depth value at 281, 211 pixel: 2325
# Speeding up to 36
#
# 79.03125
# Depth value at 266, 213 pixel: 2342
# Speeding up to 36
#
# 74.8125
# Depth value at 249, 213 pixel: 2342
# Speeding up to 36
#
# 70.03125
# Depth value at 230, 214 pixel: 3894
# Speeding up to 36
#
# 64.6875
# Depth value at 218, 207 pixel: 4792
# Speeding up to 36
#
# 61.3125
# Depth value at 212, 206 pixel: 4720
# Speeding up to 36
#
# 59.625
# Depth value at 203, 200 pixel: 4581
# Speeding up to 36
#
# 57.09375
# Depth value at 201, 199 pixel: 4357
# Speeding up to 36
#
# 56.53125
# Depth value at 202, 196 pixel: 4210
# Speeding up to 36
#
# 56.8125
# Depth value at 205, 192 pixel: 4072
# Speeding up to 36
#
# 57.65625
# Depth value at 209, 188 pixel: 3994
# Speeding up to 36
#
# 58.78125
# Depth value at 211, 177 pixel: 3894
# Speeding up to 36
#
# 59.34375
# Depth value at 222, 159 pixel: 3461
# Speeding up to 36
#
# 62.4375
# Depth value at 226, 149 pixel: 3461
# Speeding up to 36
#
# 63.5625
# Depth value at 231, 132 pixel: 3279
# Speeding up to 36
#
# 64.96875
# Depth value at 231, 132 pixel: 3228
# Speeding up to 36
#
# 64.96875
# Depth value at 237, 115 pixel: 2871
# Speeding up to 36
#
# 66.65625
# Depth value at 248, 101 pixel: 0
# Braking
#
# Depth value at 259, 86 pixel: 0
# Braking
#
# Depth value at 270, 73 pixel: 1494
# Speeding up to 36
#
# 75.9375
# Depth value at 279, 59 pixel: 1426
# Speeding up to 36
#
# 78.46875
# Depth value at 279, 59 pixel: 0
# Braking
#
# Depth value at 279, 59 pixel: 1337
# Speeding up to 36
#
# 78.46875
# Depth value at 279, 59 pixel: 1309
# Speeding up to 36
#
# 78.46875
# Depth value at 292, 4 pixel: 1154
# Braking
#
# Depth value at 292, 4 pixel: 1117
# Braking
#
# Depth value at 292, 4 pixel: 1105
# Braking
#
# Depth value at 292, 4 pixel: 0
# Braking
#
# Depth value at 292, 4 pixel: 1060
# Braking
#
# Depth value at 292, 4 pixel: 1015
# Braking
#
# Depth value at 292, 4 pixel: 978
# Braking
#
# Depth value at 292, 4 pixel: 938
# Braking
#
# Depth value at 292, 4 pixel: 910
# Braking
#
# Depth value at 292, 4 pixel: 867
# Braking
#
# Depth value at 292, 4 pixel: 0
# Braking
#
# Depth value at 292, 4 pixel: 323
# Braking
#
# Depth value at 292, 4 pixel: 323
# Braking
#
# Depth value at 292, 4 pixel: 844
# Braking
#
# Depth value at 292, 4 pixel: 851
# Braking
#
# Depth value at 292, 4 pixel: 867
# Braking
#
# Depth value at 292, 4 pixel: 879
# Braking
#
# Depth value at 292, 4 pixel: 889
# Braking
#
# Depth value at 292, 4 pixel: 898
# Braking
#
# Depth value at 292, 4 pixel: 891
# Braking
#
# Depth value at 292, 4 pixel: 891
# Braking
#
# Depth value at 292, 4 pixel: 900
# Braking
#
# Depth value at 292, 4 pixel: 899
# Braking
#
# Depth value at 292, 4 pixel: 882
# Braking
#
# Depth value at 292, 4 pixel: 853
# Braking
#
# Depth value at 292, 4 pixel: 853
# Braking
#
# Depth value at 292, 4 pixel: 807
# Braking
#
# ...
#
# Depth value at 317, 337 pixel: 6049
# Speeding up to 36
#
# 89.15625
# Speeding up to 36
#
# Depth value at 311, 335 pixel: 5563
# Speeding up to 36
#
# 87.46875
# Speeding up to 36
#
# Depth value at 309, 337 pixel: 5563
# Speeding up to 36
#
# 86.90625
# Braking
#
# Braking
#
# Braking
#
# Speeding up to 36
#
# Depth value at 274, 322 pixel: 5192
# Speeding up to 36
#
# 77.0625
# Depth value at 274, 322 pixel: 5280
# Speeding up to 36
#
# 77.0625
# Speeding up to 36
#
# Depth value at 274, 321 pixel: 4548
# Speeding up to 36
#
# 77.0625
# Speeding up to 36
#
# Depth value at 275, 321 pixel: 4684
# Speeding up to 36
#
# 77.34375
# Speeding up to 36
#
# Depth value at 278, 327 pixel: 4615
# Speeding up to 36
#
# 78.1875
# Speeding up to 36
#
# Depth value at 277, 329 pixel: 4867
# Speeding up to 36
#
# 77.90625
# Speeding up to 36
#
# Depth value at 278, 327 pixel: 4720
# Speeding up to 36
#
# 78.1875
# Speeding up to 36
#
# Depth value at 278, 329 pixel: 4482
# Speeding up to 36
#
# 78.1875
# Speeding up to 36
#
# Depth value at 279, 329 pixel: 4615
# Speeding up to 36
#
# 78.46875
# Speeding up to 36
#
# Depth value at 280, 330 pixel: 4581
# Speeding up to 36
#
# 78.75
# Speeding up to 36
#
# Depth value at 282, 329 pixel: 4548
# Speeding up to 36
#
# 79.3125
# Speeding up to 36
#
# Depth value at 285, 330 pixel: 4482
# Speeding up to 36
#
# 80.15625
# Speeding up to 36
#
# Depth value at 287, 330 pixel: 4615
# Speeding up to 36
#
# 80.71875
# Speeding up to 36
#
# Depth value at 289, 329 pixel: 4548
# Speeding up to 36
#
# 81.28125
# Speeding up to 36
#
# Depth value at 290, 327 pixel: 4548
# Speeding up to 36
#
# 81.5625
# Speeding up to 36
#
# Depth value at 292, 325 pixel: 4581
# Speeding up to 36
#
# 82.125
# Speeding up to 36
#
# Depth value at 295, 325 pixel: 4581
# Speeding up to 36
#
# 82.96875
# Speeding up to 36
#
# Depth value at 298, 323 pixel: 4756
# Speeding up to 36
#
# 83.8125
# Speeding up to 36
#
# Depth value at 300, 325 pixel: 4756
# Speeding up to 36
#
# 84.375
# Depth value at 248, 352 pixel: 5991
# Speeding up to 36
#
# 69.75
# Depth value at 307, 323 pixel: 4548
# Speeding up to 36
#
# 86.34375
# Depth value at 310, 323 pixel: 4387
# Speeding up to 36
#
# 87.1875
# Depth value at 324, 318 pixel: 4548
# Speeding up to 36
#
# 91.125
# Depth value at 324, 318 pixel: 4072
# Speeding up to 36
#
# 91.125
# Depth value at 331, 316 pixel: 4267
# Speeding up to 36
#
# 93.09375
# Depth value at 333, 311 pixel: 4099
# Speeding up to 36
#
# 93.65625
# Depth value at 330, 311 pixel: 4046
# Speeding up to 36
#
# 92.8125
# Depth value at 327, 307 pixel: 4019
# Speeding up to 36
#
# 91.96875
# Depth value at 325, 306 pixel: 4046
# Speeding up to 36
#
# 91.40625
# Depth value at 318, 303 pixel: 4072
# Speeding up to 36
#
# 89.4375
# Depth value at 311, 307 pixel: 3918
# Speeding up to 36
#
# 87.46875
# Depth value at 311, 307 pixel: 3918
# Speeding up to 36
#
# 87.46875
# Depth value at 311, 307 pixel: 3799
# Speeding up to 36
#
# 87.46875
# Depth value at 311, 307 pixel: 3894
# Speeding up to 36
#
# 87.46875
# Depth value at 290, 295 pixel: 3846
# Speeding up to 36
#
# 81.5625
# Depth value at 284, 288 pixel: 3799
# Speeding up to 36
#
# 79.875
# Depth value at 284, 288 pixel: 3776
# Speeding up to 36
#
# 79.875
# Depth value at 275, 283 pixel: 3687
# Speeding up to 36
#
# 77.34375
# Depth value at 271, 283 pixel: 3423
# Speeding up to 36
#
# 76.21875
# Depth value at 273, 280 pixel: 3423
# Speeding up to 36
#
# 76.78125
# Depth value at 276, 278 pixel: 3404
# Speeding up to 36
#
# 77.625
# Depth value at 277, 277 pixel: 3350
# Speeding up to 36
#
# 77.90625
# Depth value at 281, 273 pixel: 3279
# Speeding up to 36
#
# 79.03125
# Depth value at 286, 273 pixel: 3211
# Speeding up to 36
#
# 80.4375
# Depth value at 292, 263 pixel: 3195
# Speeding up to 36
#
# 82.125
# Depth value at 299, 253 pixel: 3163
# Speeding up to 36
#
# 84.09375
# Depth value at 302, 251 pixel: 3100
# Speeding up to 36
#
# 84.9375
# Depth value at 302, 251 pixel: 3069
# Speeding up to 36
#
# 84.9375
# Depth value at 314, 245 pixel: 2995
# Speeding up to 36
#
# 88.3125
# Depth value at 319, 238 pixel: 2871
# Speeding up to 36
#
# 89.71875
# Depth value at 323, 233 pixel: 2806
# Speeding up to 36
#
# 90.84375
# Depth value at 324, 232 pixel: 2757
# Speeding up to 36
#
# 91.125
# Depth value at 324, 225 pixel: 2709
# Speeding up to 36
#
# 91.125
# Depth value at 323, 216 pixel: 2709
# Speeding up to 36
#
# 90.84375
# Depth value at 323, 216 pixel: 2618
# Speeding up to 36
#
# 90.84375
# Depth value at 316, 201 pixel: 2564
# Speeding up to 36
#
# 88.875
# Depth value at 316, 201 pixel: 2463
# Speeding up to 36
#
# 88.875
# Depth value at 316, 201 pixel: 2396
# Speeding up to 36
#
# 88.875
# Depth value at 303, 180 pixel: 2415
# Speeding up to 36
#
# 85.21875
# Depth value at 299, 172 pixel: 2369
# Speeding up to 36
#
# 84.09375
# Depth value at 290, 166 pixel: 2342
# Speeding up to 36
#
# 81.5625
# Depth value at 290, 166 pixel: 2233
# Speeding up to 36
#
# 81.5625
# Depth value at 277, 156 pixel: 2463
# Speeding up to 36
#
# 77.90625
# Depth value at 274, 148 pixel: 0
# Braking
#
# Depth value at 274, 148 pixel: 2023
# Speeding up to 36
#
# 77.0625
# Depth value at 274, 148 pixel: 1941
# Speeding up to 36
#
# 77.0625
# Depth value at 267, 109 pixel: 2098
# Speeding up to 36
#
# 75.09375
# Depth value at 267, 109 pixel: 0
# Braking
#
# Depth value at 267, 109 pixel: 1760
# Speeding up to 36
#
# 75.09375
# Depth value at 277, 61 pixel: 1780
# Speeding up to 36
#
# 77.90625
# Depth value at 277, 61 pixel: 1693
# Speeding up to 36
#
# 77.90625
# Depth value at 285, 17 pixel: 1644
# Speeding up to 36
#
# 80.15625
# Depth value at 289, 6 pixel: 1610
# Speeding up to 36
#
# 81.28125
# Depth value at 295, 4 pixel: 1531
# Speeding up to 36
#
# 82.96875
# Depth value at 295, 4 pixel: 1462
# 82.96875
# Depth value at 295, 4 pixel: 1391
# 82.96875
# Depth value at 295, 4 pixel: 1429
# 82.96875
# Depth value at 295, 4 pixel: 1372
# 82.96875
# Depth value at 295, 4 pixel: 1372
# 82.96875
# Depth value at 295, 4 pixel: 1115
# Braking
#
# Depth value at 295, 4 pixel: 1006
# Braking
#
# Depth value at 295, 4 pixel: 821
# Braking
#
# Depth value at 295, 4 pixel: 740
# Braking
#
# Depth value at 295, 4 pixel: 740
# Braking
#
# Depth value at 295, 4 pixel: 649
# Braking
#
# Depth value at 295, 4 pixel: 582
# Braking
#
# Depth value at 295, 4 pixel: 582
# Braking
#
# Depth value at 295, 4 pixel: 520
# Braking
#
# Depth value at 295, 4 pixel: 484
# Braking
#
# Depth value at 295, 4 pixel: 444
# Braking
#
# Depth value at 295, 4 pixel: 444
# Braking
#
# Depth value at 295, 4 pixel: 0
# Braking
#
# Depth value at 295, 4 pixel: 363
# Braking
#
# Depth value at 295, 4 pixel: 327
# Braking
#
# Depth value at 295, 4 pixel: 301
# Braking
#
# Depth value at 295, 4 pixel: 301
# Braking
#
# Depth value at 295, 4 pixel: 0
# Braking
#
# Depth value at 295, 4 pixel: 0
# Braking
#
# Depth value at 295, 4 pixel: 360
# Braking
#
# Depth value at 295, 4 pixel: 360
# Braking
#
# Depth value at 295, 4 pixel: 0
# Braking
#
# Depth value at 295, 4 pixel: 0
# Braking
#
# Depth value at 295, 4 pixel: 0
# Braking
#
# Depth value at 295, 4 pixel: 0
# Braking
#
# Depth value at 295, 4 pixel: 354
# Braking
#
# Depth value at 295, 4 pixel: 364
# Braking
#
# Depth value at 295, 4 pixel: 364
# Braking
#
# Depth value at 295, 4 pixel: 367
# Braking
#
# Depth value at 295, 4 pixel: 367
# Braking
#
# Depth value at 295, 4 pixel: 369
# Braking
#
# Depth value at 295, 4 pixel: 368
# Braking
#
# Depth value at 295, 4 pixel: 367
# Braking
#
# Depth value at 295, 4 pixel: 363
# Braking
#
# Depth value at 295, 4 pixel: 363
# Braking
#
# Depth value at 295, 4 pixel: 361
# Braking
#
# Depth value at 295, 4 pixel: 355
# Braking
#
# Depth value at 295, 4 pixel: 355
# Braking
#
# Depth value at 295, 4 pixel: 351
# Braking
#
# Depth value at 295, 4 pixel: 352
# Braking
#
# Depth value at 295, 4 pixel: 351
# Braking
#
# Depth value at 295, 4 pixel: 351
# Braking
#
# Depth value at 295, 4 pixel: 350
# Braking
#
# Depth value at 295, 4 pixel: 345
# Braking
#
# Depth value at 295, 4 pixel: 345
# Braking
#
# Depth value at 295, 4 pixel: 341
# Braking
#
# Depth value at 295, 4 pixel: 338
# Braking
#
# Depth value at 295, 4 pixel: 338
# Braking
#
# Depth value at 295, 4 pixel: 332
# Braking
#
# Depth value at 295, 4 pixel: 331
# Braking
#
# Depth value at 295, 4 pixel: 331
# Braking
#
# Depth value at 295, 4 pixel: 333
# Braking
#
# Depth value at 295, 4 pixel: 329
# Braking
#
# Depth value at 295, 4 pixel: 324
# Braking
#
# Depth value at 295, 4 pixel: 324
# Braking
#
# Depth value at 295, 4 pixel: 320
# Braking
#
# Depth value at 295, 4 pixel: 314
# Braking
#
# Depth value at 295, 4 pixel: 314
# Braking
#
# Depth value at 295, 4 pixel: 311
# Braking
#
# Depth value at 295, 4 pixel: 309
# Braking
#
# Depth value at 295, 4 pixel: 310
# Braking
#
# Depth value at 295, 4 pixel: 310
# Braking
#
# Depth value at 295, 4 pixel: 314
# Braking
#
# Depth value at 295, 4 pixel: 314
# Braking
#
# Depth value at 295, 4 pixel: 313
# Braking
#
# Depth value at 295, 4 pixel: 313
# Braking
#
# Depth value at 295, 4 pixel: 311
# Braking
#
# Depth value at 295, 4 pixel: 314
# Braking
#
# Depth value at 295, 4 pixel: 314
# Braking
#
# Depth value at 295, 4 pixel: 321
# Braking
#
# Depth value at 295, 4 pixel: 324
# Braking
#
# Depth value at 295, 4 pixel: 324
# Braking
#
# Depth value at 295, 4 pixel: 319
# Braking
#
# Depth value at 295, 4 pixel: 319
# Braking
#
# Depth value at 295, 4 pixel: 325
# Braking
#
# Depth value at 295, 4 pixel: 325
# Braking
#
# Depth value at 295, 4 pixel: 333
# Braking
#
# Depth value at 295, 4 pixel: 337
# Braking
#
# Depth value at 295, 4 pixel: 341
# Braking
#
# Depth value at 295, 4 pixel: 341
# Braking
#
# Depth value at 295, 4 pixel: 344
# Braking
#
# Depth value at 295, 4 pixel: 340
# Braking
#
# Depth value at 295, 4 pixel: 324
# Braking
#
# Depth value at 295, 4 pixel: 324
# Braking
#
# Depth value at 295, 4 pixel: 332
# Braking
#
# Depth value at 295, 4 pixel: 356
# Braking
#
# Depth value at 295, 4 pixel: 356
# Braking
#
# Depth value at 295, 4 pixel: 386
# Braking
#
# Depth value at 295, 4 pixel: 399
# Braking
#
# Depth value at 295, 4 pixel: 427
# Braking
#
# Depth value at 295, 4 pixel: 427
# Braking
#
# Depth value at 295, 4 pixel: 437
# Braking
#
# Depth value at 295, 4 pixel: 0
# Braking
#
# Depth value at 295, 4 pixel: 0
# Braking
#
# Depth value at 295, 4 pixel: 0
# Braking
#
# Depth value at 295, 4 pixel: 215
# Braking
#
# Depth value at 295, 4 pixel: 215
# Braking
#
# Depth value at 295, 4 pixel: 194
# Braking
#
# Depth value at 295, 4 pixel: 188
# Braking
#
# Depth value at 295, 4 pixel: 188
# Braking
#
# Depth value at 295, 4 pixel: 186
# Braking
#
# Depth value at 295, 4 pixel: 186
# Braking
#
# Depth value at 295, 4 pixel: 177
# Braking
#
# Depth value at 295, 4 pixel: 174
# Braking
#
# Depth value at 295, 4 pixel: 174
# Braking
#
# Depth value at 295, 4 pixel: 189
# Braking
#
# Depth value at 295, 4 pixel: 0
# Braking
#
# Depth value at 295, 4 pixel: 0
# Braking
#
# Depth value at 295, 4 pixel: 0
# Braking
#
# Depth value at 295, 4 pixel: 0
# Braking
#
# Depth value at 295, 4 pixel: 0
# Braking
#
# Depth value at 295, 4 pixel: 2241
# 82.96875
# Depth value at 295, 4 pixel: 2209
# 82.96875
# Depth value at 295, 4 pixel: 2126
# 82.96875
# Depth value at 295, 4 pixel: 2091
# 82.96875
# Depth value at 295, 4 pixel: 2091
# 82.96875
# Depth value at 295, 4 pixel: 1675
# 82.96875
# Depth value at 295, 4 pixel: 1606
# 82.96875
# Depth value at 295, 4 pixel: 1606
# 82.96875
# Depth value at 295, 4 pixel: 1597
# 82.96875
# Depth value at 295, 4 pixel: 1610
# 82.96875
# Depth value at 295, 4 pixel: 1593
# 82.96875
# Depth value at 295, 4 pixel: 1593
# 82.96875
# Depth value at 295, 4 pixel: 1565
# 82.96875
# Depth value at 295, 4 pixel: 1523
# 82.96875
# Depth value at 295, 4 pixel: 1505
# 82.96875
# Depth value at 295, 4 pixel: 1483
# 82.96875
# Depth value at 295, 4 pixel: 1473
# 82.96875
# Depth value at 295, 4 pixel: 1473
# 82.96875
# Depth value at 295, 4 pixel: 1501
# 82.96875
# Depth value at 295, 4 pixel: 1498
# 82.96875
# Depth value at 295, 4 pixel: 1494
# 82.96875
# Depth value at 295, 4 pixel: 1494
# 82.96875
# Depth value at 295, 4 pixel: 1527
# 82.96875
# Depth value at 295, 4 pixel: 1520
# 82.96875
# Depth value at 295, 4 pixel: 1520
# 82.96875
# Depth value at 295, 4 pixel: 1505
# 82.96875
# Depth value at 295, 4 pixel: 1498
# 82.96875
# Depth value at 295, 4 pixel: 1476
# 82.96875
# Depth value at 295, 4 pixel: 1476
# 82.96875
# Depth value at 295, 4 pixel: 1384
# 82.96875
# Depth value at 295, 4 pixel: 1384
# 82.96875
# Depth value at 295, 4 pixel: 1312
# 82.96875
# Depth value at 295, 4 pixel: 1236
# Braking
#
# Depth value at 295, 4 pixel: 1236
# Braking
#
# Depth value at 295, 4 pixel: 1212
# Braking
#
# Depth value at 295, 4 pixel: 1154
# Braking
#
# Depth value at 295, 4 pixel: 1154
# Braking
#
# Depth value at 295, 4 pixel: 1109
# Braking
#
# Depth value at 295, 4 pixel: 1084
# Braking
#
# Depth value at 295, 4 pixel: 1031
# Braking
#
# Depth value at 295, 4 pixel: 1031
# Braking
#
# Depth value at 295, 4 pixel: 994
# Braking
#
# Depth value at 295, 4 pixel: 967
# Braking
#
# Depth value at 295, 4 pixel: 967
# Braking
#
# Depth value at 295, 4 pixel: 977
# Braking
#
# Depth value at 295, 4 pixel: 977
# Braking
#
# Depth value at 295, 4 pixel: 978
# Braking
#
# Depth value at 295, 4 pixel: 966
# Braking
#
# Depth value at 295, 4 pixel: 966
# Braking
#
# Depth value at 295, 4 pixel: 967
# Braking
#
# Depth value at 295, 4 pixel: 967
# Braking
#
# Depth value at 295, 4 pixel: 973
# Braking
#
# Depth value at 295, 4 pixel: 975
# Braking
#
# Depth value at 295, 4 pixel: 990
# Braking
#
# Depth value at 295, 4 pixel: 990
# Braking
#
# Depth value at 295, 4 pixel: 1006
# Braking
#
# Depth value at 295, 4 pixel: 1042
# Braking
#
# Depth value at 295, 4 pixel: 1042
# Braking
#
# Depth value at 295, 4 pixel: 1056
# Braking
#
# Depth value at 295, 4 pixel: 1042
# Braking
#
# Depth value at 295, 4 pixel: 1187
# Braking
#
# Depth value at 295, 4 pixel: 1187
# Braking
#
# Depth value at 295, 4 pixel: 1516
# Speeding up to 36
#
# 82.96875
# Depth value at 295, 4 pixel: 1965
# Speeding up to 36
#
# 82.96875
# Depth value at 295, 4 pixel: 1929
# Speeding up to 36
#
# 82.96875
# Depth value at 295, 4 pixel: 1894
# Speeding up to 36
#
# 82.96875
# Depth value at 568, 367 pixel: 1569
# Speeding up to 36
#
# 159.75
# Depth value at 568, 367 pixel: 1476
# Speeding up to 36
#
# 159.75
# Depth value at 568, 367 pixel: 1466
# Speeding up to 36
#
# 159.75
# Depth value at 568, 367 pixel: 1466
# Speeding up to 36
#
# 159.75
# Depth value at 568, 367 pixel: 0
# Braking
#
# Depth value at 568, 367 pixel: 11537
# Speeding up to 36
#
# 159.75
# Depth value at 86, 294 pixel: 910
# Braking
#
# Depth value at 86, 294 pixel: 928
# Braking
#
# Depth value at 86, 294 pixel: 0
# Braking
#
# Depth value at 86, 294 pixel: 1602
# Speeding up to 36
#
# 24.1875
# Depth value at 86, 294 pixel: 4238
# Speeding up to 36
#
# 24.1875
# Depth value at 86, 294 pixel: 4581
# Speeding up to 36
#
# 24.1875
# Depth value at 86, 294 pixel: 4615
# Speeding up to 36
#
# 24.1875
# Depth value at 401, 243 pixel: 1293
# Speeding up to 36
#
# 112.78125
# Depth value at 393, 238 pixel: 1301
# Speeding up to 36
#
# 110.53125
# Depth value at 387, 224 pixel: 1326
# Speeding up to 36
#
# 108.84375
# Depth value at 394, 210 pixel: 1360
# Speeding up to 36
#
# 110.8125
# Depth value at 409, 171 pixel: 1422
# Speeding up to 36
#
# 115.03125
# Depth value at 409, 171 pixel: 1391
# Speeding up to 36
#
# 115.03125
# Depth value at 409, 171 pixel: 1378
# Speeding up to 36
#
# 115.03125
# Depth value at 409, 171 pixel: 1381
# Speeding up to 36
#
# 115.03125
# Depth value at 409, 171 pixel: 1363
# Speeding up to 36
#
# 115.03125
# Depth value at 409, 171 pixel: 1328
# 115.03125
# Depth value at 409, 171 pixel: 0
# Braking
#
# Depth value at 409, 171 pixel: 0
# Braking
#
# Depth value at 409, 171 pixel: 0
# Braking
#
# Depth value at 409, 171 pixel: 0
# Braking
#
# Depth value at 409, 171 pixel: 0
# Braking
#
# Depth value at 409, 171 pixel: 0
# Braking
#
# Depth value at 409, 171 pixel: 2387
# 115.03125
# Depth value at 409, 171 pixel: 2415
# 115.03125
# Depth value at 409, 171 pixel: 2482
# 115.03125
# Depth value at 409, 171 pixel: 2482
# 115.03125
# Depth value at 409, 171 pixel: 2512
# 115.03125
# Depth value at 409, 171 pixel: 2463
# 115.03125
# Depth value at 409, 171 pixel: 2492
# 115.03125
# Depth value at 269, 4 pixel: 1585
# Speeding up to 36
#
# 75.65625
# Depth value at 271, 4 pixel: 1589
# Speeding up to 36
#
# 76.21875
# Depth value at 272, 4 pixel: 1610
# Speeding up to 36
#
# 76.5
# Depth value at 277, 9 pixel: 1618
# Speeding up to 36
#
# 77.90625
# Depth value at 285, 10 pixel: 1610
# Speeding up to 36
#
# 80.15625
# Depth value at 297, 17 pixel: 1581
# Speeding up to 36
#
# 83.53125
# Braking
#
# Braking
#
# Braking
#
# Braking
#
# Braking
#
# Braking
#
# Braking
#
# Braking
#
# Braking
#
# Braking
#
# Braking
#
# Braking
#
# Braking
#
# Braking
#
# Braking
#
# Braking
#
# Braking
#
# Braking
#
# Braking
#
# Braking
#
# Braking
#
# Braking
#
# Braking
#
# Braking
#
# Braking
#
# Braking
#
# Braking
#
# Braking
#
# Braking
#
# Braking
#
# Braking
#
# Braking
#
# Braking
#
# Braking
#
# Braking
#
# Braking
#
# Braking
#
# Braking
#
# Braking
#
# Braking
#
# Braking
#
# Braking
#
# Braking
#
# Braking
