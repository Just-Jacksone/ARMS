# %%
import cv2
import json
import trt_pose.coco
import torch
import time
import numpy as np
import pyrealsense2 as rs
from torch2trt import TRTModule
from trt_pose.draw_objects import DrawObjects
from trt_pose.parse_objects import ParseObjects

OPTIMIZED_MODEL = 'pose_detection/resnet18_baseline_att_224x224_A_epoch_249_trt.pth'
HUMAN = 'pose_detection/human_pose.json'

# %%
def preprocess(image):
    mean = torch.Tensor([0.485, 0.456, 0.406]).to(device).view(1, 3, 1, 1)
    std = torch.Tensor([0.229, 0.224, 0.225]).to(device).view(1, 3, 1, 1)
    image = cv2.cvtColor(image, cv2.COLOR_BGR2RGB)
    image = cv2.resize(image, (224, 224))
    image = torch.from_numpy(image).permute(2, 0, 1).unsqueeze(0).float().to(device)
    image = image.div(255.0)
    image = (image - mean) / std
    return image

# Load model and topology
with open(HUMAN, 'r') as f:
    human_pose = json.load(f)
topology = trt_pose.coco.coco_category_to_topology(human_pose)

# Instantiate TensorRT
model_trt = TRTModule()
model_trt.load_state_dict(torch.load(OPTIMIZED_MODEL))

# Doing stuff (tbd)
parse_objects = ParseObjects(topology)
draw_objects = DrawObjects(topology)

device = torch.device('cuda')

# %%
from rover.controls import *
rover = Controls()
# Out:
# Initializing Servos
# Initializing ServoKit
# Done initializing

# %%
from pose_detection.pose_detection import *

WIDTH = 640
HEIGHT = 480
CLOSE_BRAKE_DISTANCE = 1300
FAR_BRAKE_DISTANCE = 4000
MID_BRAKE_DISTANCE = 2500


# Initialize RealSense camera
pipeline = rs.pipeline()
config = rs.config()
config.enable_stream(rs.stream.color, WIDTH, HEIGHT, rs.format.bgr8, 30)
config.enable_stream(rs.stream.depth, 640, 480, rs.format.z16, 30)
pipeline.start(config)

body = Body()
speed = 0
pose_change = False
prev_pose = "No Pose"
center = [WIDTH/2, HEIGHT/2]
current_angle = 90
started = False
cur_brake_distance = 2000
count = 0

prev_frame_time = time.time()
pose_classification = "No-Pose"
chest_in_frame = False

try:
    while True:
        frames = pipeline.wait_for_frames()
        color_frame = frames.get_color_frame()
        depth_frame = frames.get_depth_frame()

        # Convert depth frame to numpy array
        depth_image = np.asanyarray(depth_frame.get_data())


        if not color_frame or not depth_frame:
            continue

        # Convert images to numpy arrays
        color_image = np.asanyarray(color_frame.get_data())

        # Process the image for pose estimation
        data = preprocess(color_image)
        cmap, paf = model_trt(data)
        cmap, paf = cmap.detach().cpu(), paf.detach().cpu()
        counts, objects, peaks = parse_objects(cmap, paf)
        
        pose_classification, chest_in_frame = classify_pose(peaks, counts, objects, topology, body)

        cv2.putText(color_image, pose_classification, (50, 50), cv2.FONT_HERSHEY_SIMPLEX, 1, (255, 255, 255), 2, cv2.LINE_AA)
        
        if pose_classification == "T-Pose":
            started = True
            cur_brake_distance = MID_BRAKE_DISTANCE
            speed = 1
            #rover.forward(speed)
        elif pose_classification == "S-Pose":
            started = False
            rover.brake()

        
        
        if started == True:
            # Access depth data at body(in millimeters)
            if depth_image[int(body.chest[1]), int(body.chest[0])] != 0:
                depth_value_at_pixel = depth_image[int(body.chest[1]), int(body.chest[0])]

            print(f"Depth value at {body.chest[0]}, {body.chest[1]} pixel: {depth_value_at_pixel}")
            #print(f"Depth Values: {depth_image}")

            if depth_value_at_pixel < cur_brake_distance:
                rover.brake()
                speed = 1
            else:
                if chest_in_frame:
                    speed = max(1 + depth_value_at_pixel / cur_brake_distance, 1)
                    rover.forward(speed)
                    print(f"Speed: {speed}")

                x_diff = body.chest[0] - center[0]
                x_diff = (0.28125 * x_diff) + 90
                current_angle = x_diff
                rover.turn(current_angle)

        
                if pose_classification == "M-Pose" and speed >= 10:
                    cur_brake_distance = FAR_BRAKE_DISTANCE
                elif pose_classification == "W-Pose" and speed < MAX_THROTTLE - 10:
                    cur_brake_distance = CLOSE_BRAKE_DISTANCE

                prev_chest = body.chest
        
        # Draw poses and display them
        #draw_objects(color_image, counts, objects, peaks)
        draw_keypoints_and_values(color_image, counts, objects, peaks, topology)

        # Calculate FPS and display it
        current_frame_time = time.time()
        fps = (1 / (current_frame_time - prev_frame_time))
        prev_frame_time = current_frame_time
        fps_text = f'FPS: {fps:.0f}'
        cv2.putText(color_image, fps_text, (color_image.shape[1] - 150, color_image.shape[0] - 10), cv2.FONT_HERSHEY_SIMPLEX, 0.5, (255, 255, 255), 2)



        # Display the image
        cv2.imshow('Pose Estimation', color_image)
        if cv2.waitKey(1) & 0xFF == ord('q'):
            break

finally:
    rover.brake()
    pipeline.stop()
    cv2.destroyAllWindows()
# Out:
# Depth value at 331, 214 pixel: 1972
# Depth value at 330, 212 pixel: 1972
# Depth value at 329, 211 pixel: 1972
# Depth value at 328, 212 pixel: 1972
# Depth value at 327, 211 pixel: 1972
# Depth value at 327, 213 pixel: 1972
# Depth value at 327, 214 pixel: 1972
# Depth value at 328, 214 pixel: 1972
# Depth value at 328, 213 pixel: 1972
# Depth value at 328, 213 pixel: 1972
# Depth value at 328, 213 pixel: 1972
# Depth value at 328, 214 pixel: 1972
# Depth value at 329, 213 pixel: 1972
# Depth value at 330, 213 pixel: 1972
# Depth value at 331, 214 pixel: 1972
# Depth value at 332, 214 pixel: 1972
# Depth value at 332, 215 pixel: 1972
# Depth value at 334, 215 pixel: 1972
# Depth value at 334, 215 pixel: 1972
# Depth value at 334, 215 pixel: 1972
# Depth value at 333, 215 pixel: 1972
# Depth value at 334, 214 pixel: 1972
# Depth value at 335, 215 pixel: 1972
# Depth value at 335, 215 pixel: 1972
# Depth value at 335, 215 pixel: 1972
# Depth value at 335, 215 pixel: 1972
# Depth value at 335, 215 pixel: 1972
# Depth value at 335, 215 pixel: 1972
# Depth value at 335, 214 pixel: 1972
# Depth value at 335, 213 pixel: 1972
# Depth value at 335, 214 pixel: 1972
# Depth value at 335, 215 pixel: 1972
# Depth value at 335, 215 pixel: 1972
# Depth value at 335, 214 pixel: 1972
# Depth value at 335, 214 pixel: 1972
# Depth value at 335, 214 pixel: 1972
# Depth value at 335, 214 pixel: 1972
# Depth value at 335, 215 pixel: 1972
# Depth value at 335, 215 pixel: 1972
# Depth value at 335, 215 pixel: 1972
# Depth value at 335, 215 pixel: 1972
# Depth value at 335, 215 pixel: 1972
# Depth value at 335, 215 pixel: 1972
# Depth value at 335, 214 pixel: 1972
# Depth value at 335, 215 pixel: 1972
# Depth value at 335, 215 pixel: 1972
# Depth value at 336, 214 pixel: 1972
# Depth value at 336, 215 pixel: 1972
# Depth value at 336, 215 pixel: 1972
# Depth value at 336, 214 pixel: 1972
# Depth value at 335, 215 pixel: 1972
# Depth value at 335, 215 pixel: 1972
# Depth value at 335, 215 pixel: 1972
# Depth value at 335, 214 pixel: 1972
# Depth value at 334, 215 pixel: 1972
# Depth value at 334, 215 pixel: 1972
# Depth value at 333, 214 pixel: 1972
# Depth value at 332, 215 pixel: 1972
# Depth value at 333, 215 pixel: 1972
# Depth value at 332, 216 pixel: 1972
# Depth value at 332, 216 pixel: 1972
# Depth value at 332, 216 pixel: 1972
# Depth value at 332, 216 pixel: 1972
# Depth value at 333, 216 pixel: 1972
# Depth value at 333, 217 pixel: 1972
# Depth value at 332, 216 pixel: 1972
# Depth value at 332, 217 pixel: 1972
# Depth value at 333, 217 pixel: 1972
# Depth value at 333, 216 pixel: 1972
# Depth value at 332, 216 pixel: 1972
# Depth value at 333, 216 pixel: 1972
# Depth value at 333, 216 pixel: 1972
# Depth value at 332, 216 pixel: 1972
# Depth value at 333, 216 pixel: 1972
# Depth value at 333, 217 pixel: 1972
# Depth value at 333, 216 pixel: 1972
# Depth value at 333, 216 pixel: 1972
# Depth value at 333, 217 pixel: 1972
# Depth value at 333, 216 pixel: 1972
# Depth value at 333, 217 pixel: 1972
# Depth value at 333, 216 pixel: 1972
# Depth value at 333, 216 pixel: 1972
# Depth value at 333, 217 pixel: 1972
# Depth value at 334, 216 pixel: 1972
# Depth value at 334, 216 pixel: 1972
# Depth value at 334, 216 pixel: 1972
# Depth value at 334, 217 pixel: 1972
# Depth value at 334, 216 pixel: 1972
# Depth value at 333, 216 pixel: 1972
# Depth value at 333, 216 pixel: 1972
# Depth value at 333, 216 pixel: 1972
# Depth value at 334, 216 pixel: 1972
# Depth value at 333, 216 pixel: 1972
# Depth value at 333, 216 pixel: 1972
# Depth value at 334, 216 pixel: 1972
# Depth value at 334, 217 pixel: 1972
# Depth value at 334, 216 pixel: 1972
# Depth value at 334, 216 pixel: 1972
# Depth value at 334, 216 pixel: 1972
# Depth value at 334, 217 pixel: 1972
# Depth value at 334, 216 pixel: 1972
# Depth value at 334, 217 pixel: 1972
# Depth value at 334, 216 pixel: 1972
# Depth value at 334, 216 pixel: 1972
# Depth value at 334, 216 pixel: 1972
# Depth value at 334, 216 pixel: 1972
# Depth value at 334, 216 pixel: 1972
# Depth value at 334, 216 pixel: 1972
# Depth value at 334, 216 pixel: 1972
# Depth value at 334, 216 pixel: 1972
# Depth value at 334, 216 pixel: 1972
# Depth value at 334, 216 pixel: 1972
# Depth value at 335, 216 pixel: 1972
# Depth value at 334, 216 pixel: 1972
# Depth value at 334, 216 pixel: 1972
# Depth value at 334, 216 pixel: 1972
# Depth value at 334, 216 pixel: 1972
# Depth value at 334, 216 pixel: 1972
# Depth value at 334, 216 pixel: 1972
# Depth value at 334, 216 pixel: 1972
# Depth value at 334, 216 pixel: 1972
# Depth value at 334, 216 pixel: 1972
# Depth value at 334, 216 pixel: 1972
# Depth value at 334, 216 pixel: 1972
# Depth value at 335, 216 pixel: 1972
# Depth value at 334, 216 pixel: 1972
# Depth value at 334, 216 pixel: 1972
# Depth value at 334, 216 pixel: 1972
# Depth value at 334, 215 pixel: 1972
# Depth value at 334, 215 pixel: 1972
# Depth value at 334, 215 pixel: 1972
# Depth value at 333, 215 pixel: 1972
# Depth value at 334, 215 pixel: 1972
# Depth value at 332, 215 pixel: 1972
# Depth value at 333, 215 pixel: 1972
# Depth value at 333, 214 pixel: 1972
# Depth value at 333, 215 pixel: 1972
# Depth value at 334, 215 pixel: 1972
# Depth value at 334, 216 pixel: 1972
# Depth value at 333, 216 pixel: 1972
# Depth value at 334, 216 pixel: 1972
# Depth value at 334, 215 pixel: 1972
# Depth value at 334, 216 pixel: 1972
# Depth value at 334, 215 pixel: 1972
# Depth value at 334, 216 pixel: 1972
# Depth value at 334, 215 pixel: 1972
# Depth value at 334, 215 pixel: 1972
# Depth value at 334, 215 pixel: 1972
# Depth value at 335, 215 pixel: 1972
# Depth value at 335, 216 pixel: 1972
# Depth value at 335, 215 pixel: 1972
# Depth value at 335, 215 pixel: 1972
# Depth value at 335, 215 pixel: 1972
# Depth value at 336, 215 pixel: 1972
# Depth value at 336, 215 pixel: 1972
# Depth value at 336, 215 pixel: 1972
# Depth value at 336, 214 pixel: 1972
# Depth value at 335, 215 pixel: 1972
# Depth value at 333, 213 pixel: 1972
# Depth value at 332, 213 pixel: 1972
# Depth value at 333, 212 pixel: 1972
# Depth value at 331, 211 pixel: 1972
# Depth value at 331, 211 pixel: 1972
# Depth value at 331, 211 pixel: 1972
# Depth value at 331, 211 pixel: 1972
# Depth value at 331, 211 pixel: 1972
# Depth value at 331, 211 pixel: 1972
# Depth value at 331, 211 pixel: 1972
# Depth value at 331, 211 pixel: 1972
# Depth value at 335, 212 pixel: 1972
# Depth value at 336, 212 pixel: 1972
# Depth value at 336, 212 pixel: 1972
# Depth value at 336, 212 pixel: 1972
# Depth value at 336, 212 pixel: 1972
# Depth value at 336, 212 pixel: 1972
# Depth value at 336, 212 pixel: 1972
# Depth value at 336, 212 pixel: 1972
# Depth value at 336, 212 pixel: 1972
# Depth value at 336, 212 pixel: 1972
# Depth value at 336, 212 pixel: 1972
# Depth value at 336, 212 pixel: 1972
# Depth value at 336, 212 pixel: 1972
# Depth value at 336, 212 pixel: 1972
# Depth value at 336, 212 pixel: 1972
# Depth value at 336, 212 pixel: 1972
# Depth value at 336, 212 pixel: 1972
# Depth value at 336, 212 pixel: 1972
# Depth value at 336, 212 pixel: 1972
# Depth value at 336, 212 pixel: 1972
# Depth value at 336, 212 pixel: 1972
# Depth value at 336, 212 pixel: 1972
# Depth value at 336, 212 pixel: 1972
# Depth value at 336, 212 pixel: 1972
# Depth value at 336, 212 pixel: 1972
# Depth value at 336, 212 pixel: 1972
# Depth value at 338, 220 pixel: 1972
# Depth value at 338, 220 pixel: 1972
# Depth value at 339, 220 pixel: 1972
# Depth value at 340, 221 pixel: 1972
# Depth value at 341, 222 pixel: 1972
# Depth value at 342, 223 pixel: 1972
# Depth value at 343, 224 pixel: 1972
# Depth value at 343, 223 pixel: 1972
# Depth value at 343, 223 pixel: 1972
# Depth value at 342, 222 pixel: 1972
# Depth value at 342, 223 pixel: 1972
# Depth value at 342, 222 pixel: 1972
# Depth value at 341, 223 pixel: 1972
# Depth value at 341, 222 pixel: 1972
# Depth value at 340, 222 pixel: 1972
# Depth value at 340, 223 pixel: 1972
# Depth value at 340, 223 pixel: 1972
# Depth value at 340, 223 pixel: 1972
# Depth value at 340, 223 pixel: 1972
# Depth value at 340, 223 pixel: 1972
# Depth value at 340, 223 pixel: 1972
# Depth value at 340, 223 pixel: 1972
# Depth value at 340, 223 pixel: 1972
# Depth value at 340, 223 pixel: 1972
# Depth value at 340, 223 pixel: 1972
# Depth value at 340, 223 pixel: 1972
# Depth value at 340, 223 pixel: 1972
# Depth value at 340, 223 pixel: 1972
# Depth value at 340, 223 pixel: 1972
# Depth value at 340, 223 pixel: 1972
# Depth value at 340, 223 pixel: 1972
# Depth value at 340, 223 pixel: 1972
# Depth value at 340, 223 pixel: 1972
# Depth value at 340, 223 pixel: 1972
# Depth value at 340, 223 pixel: 1972
# Depth value at 340, 223 pixel: 1972
# Depth value at 340, 223 pixel: 1972
# Depth value at 340, 223 pixel: 1972
# Depth value at 340, 223 pixel: 1972
# Depth value at 340, 223 pixel: 1972
# Depth value at 340, 223 pixel: 1972
# Depth value at 340, 223 pixel: 1972
# Depth value at 340, 223 pixel: 1972
# Depth value at 340, 223 pixel: 1972
# Depth value at 340, 223 pixel: 1972
# Depth value at 340, 223 pixel: 1972
# Depth value at 340, 223 pixel: 1972
# Depth value at 340, 223 pixel: 1972
# Depth value at 340, 223 pixel: 1972
# Depth value at 340, 223 pixel: 1972
# Depth value at 340, 223 pixel: 1972
# Depth value at 340, 223 pixel: 1972
# Depth value at 340, 223 pixel: 1972
# Depth value at 340, 223 pixel: 1972
# Depth value at 340, 223 pixel: 1972
# Depth value at 340, 223 pixel: 1972
# Depth value at 340, 223 pixel: 1972
# Depth value at 340, 223 pixel: 1972
# Depth value at 340, 223 pixel: 1972
# Depth value at 340, 223 pixel: 1972
# Depth value at 340, 223 pixel: 1972
# Depth value at 340, 223 pixel: 1972
# Depth value at 340, 223 pixel: 1972
# Depth value at 340, 223 pixel: 1972
# Depth value at 340, 223 pixel: 1972
# Depth value at 340, 223 pixel: 1972
# Depth value at 340, 223 pixel: 1972
# Depth value at 340, 223 pixel: 1972
# Depth value at 340, 223 pixel: 1972
# Depth value at 340, 223 pixel: 1972
# Depth value at 340, 223 pixel: 1972
# Depth value at 340, 223 pixel: 1972
# Depth value at 340, 223 pixel: 1972
# Depth value at 340, 223 pixel: 1972
# Depth value at 340, 223 pixel: 1972
# Depth value at 340, 223 pixel: 1972
# Depth value at 340, 223 pixel: 1972
# Depth value at 340, 223 pixel: 1972
# Depth value at 340, 223 pixel: 1972
# Depth value at 340, 223 pixel: 1972
# Depth value at 340, 223 pixel: 1972
# Depth value at 340, 223 pixel: 1972
# Depth value at 340, 223 pixel: 1972
# Depth value at 340, 223 pixel: 1972
# Depth value at 340, 223 pixel: 1972
# Depth value at 340, 223 pixel: 1972
# Depth value at 340, 223 pixel: 1972
# Depth value at 340, 223 pixel: 1972
# Depth value at 340, 223 pixel: 1972
# Depth value at 340, 223 pixel: 1972
# Depth value at 340, 223 pixel: 1972
# Depth value at 340, 223 pixel: 1972
# Depth value at 340, 223 pixel: 1972
# Depth value at 340, 223 pixel: 1972
# Depth value at 340, 223 pixel: 1972
# Depth value at 340, 223 pixel: 1972
# Depth value at 340, 223 pixel: 1972
# Depth value at 340, 223 pixel: 1972
# Depth value at 340, 223 pixel: 1972
# Depth value at 340, 223 pixel: 1972
# Depth value at 340, 223 pixel: 1972
# Depth value at 340, 223 pixel: 1972
# Depth value at 340, 223 pixel: 1972
# Depth value at 340, 223 pixel: 1972
# Depth value at 340, 223 pixel: 1972
# Depth value at 340, 223 pixel: 1972
# Depth value at 340, 223 pixel: 1972
# Depth value at 340, 223 pixel: 1972
# Depth value at 340, 223 pixel: 1972
# Depth value at 340, 223 pixel: 1972
# Depth value at 340, 223 pixel: 1972
# Depth value at 340, 223 pixel: 1972
# Depth value at 340, 223 pixel: 1972
# Depth value at 340, 223 pixel: 1972
# Depth value at 340, 223 pixel: 1972
# Depth value at 340, 223 pixel: 1972
# Depth value at 340, 223 pixel: 1972
# Depth value at 340, 223 pixel: 1972
# Depth value at 340, 223 pixel: 1972
# Depth value at 340, 223 pixel: 1972
# Depth value at 340, 223 pixel: 1972
# Depth value at 340, 223 pixel: 1972
# Depth value at 340, 223 pixel: 1972
# Depth value at 340, 223 pixel: 1972
# Depth value at 340, 223 pixel: 1972
# Depth value at 340, 223 pixel: 1972
# Depth value at 340, 223 pixel: 1972
# Depth value at 340, 223 pixel: 1972
# Depth value at 340, 223 pixel: 1972
# Depth value at 340, 223 pixel: 1972
# Depth value at 340, 223 pixel: 1972
# Depth value at 340, 223 pixel: 1972
# Depth value at 340, 223 pixel: 1972
# Depth value at 340, 223 pixel: 1972
# Depth value at 340, 223 pixel: 1972
# Depth value at 340, 223 pixel: 1972
# Depth value at 340, 223 pixel: 1972
# Depth value at 93, 314 pixel: 1775
# Depth value at 74, 264 pixel: 1618
# Depth value at 74, 264 pixel: 1618
# Depth value at 74, 264 pixel: 1679
# Depth value at 74, 264 pixel: 1593
# Depth value at 74, 264 pixel: 1597
# Depth value at 74, 264 pixel: 1597
# Depth value at 74, 264 pixel: 1657
# Depth value at 74, 264 pixel: 1523
# Depth value at 74, 264 pixel: 1523
# Depth value at 74, 264 pixel: 1523
# Depth value at 74, 264 pixel: 1561
# Depth value at 74, 264 pixel: 1627
# Depth value at 74, 264 pixel: 1693
# Depth value at 74, 264 pixel: 1745
# Depth value at 74, 264 pixel: 1726
# Depth value at 74, 264 pixel: 1627
# Depth value at 74, 264 pixel: 1688
# Depth value at 74, 264 pixel: 1707
# Depth value at 74, 264 pixel: 1635
# Depth value at 74, 264 pixel: 1635
# Depth value at 74, 264 pixel: 1726
# Depth value at 74, 264 pixel: 1735
# Depth value at 74, 264 pixel: 1735
# Depth value at 74, 264 pixel: 1640
# Depth value at 74, 264 pixel: 1640
# Depth value at 74, 264 pixel: 1666
# Depth value at 74, 264 pixel: 1666
# Depth value at 74, 264 pixel: 1666
# Depth value at 74, 264 pixel: 1702
# Depth value at 74, 264 pixel: 1627
# Depth value at 74, 264 pixel: 1627
# Depth value at 74, 264 pixel: 1593
# Depth value at 74, 264 pixel: 1593
# Depth value at 74, 264 pixel: 1593
# Depth value at 74, 264 pixel: 1593
# Depth value at 74, 264 pixel: 1702
# Depth value at 74, 264 pixel: 1702
# Depth value at 74, 264 pixel: 1702
# Depth value at 74, 264 pixel: 1702
# Depth value at 74, 264 pixel: 1702
# Depth value at 74, 264 pixel: 1702
# Depth value at 74, 264 pixel: 1702
# Depth value at 74, 264 pixel: 1702
# Depth value at 74, 264 pixel: 1702
# Depth value at 74, 264 pixel: 1702
# Depth value at 74, 264 pixel: 1702
# Depth value at 74, 264 pixel: 1702
# Depth value at 74, 264 pixel: 1702
# Depth value at 74, 264 pixel: 1702
# Depth value at 74, 264 pixel: 1702
# Depth value at 74, 264 pixel: 1702
# Depth value at 74, 264 pixel: 1702
# Depth value at 74, 264 pixel: 1702
# Depth value at 74, 264 pixel: 1843
# Depth value at 74, 264 pixel: 1843
# Depth value at 74, 264 pixel: 1843
# Depth value at 74, 264 pixel: 1843
# Depth value at 74, 264 pixel: 1843
# Depth value at 74, 264 pixel: 1843
# Depth value at 74, 264 pixel: 1843
# Depth value at 74, 264 pixel: 1843
# Depth value at 74, 264 pixel: 1843
# Depth value at 74, 264 pixel: 1843
# Depth value at 74, 264 pixel: 1843
# Depth value at 74, 264 pixel: 1712
# Depth value at 74, 264 pixel: 1712
# Depth value at 74, 264 pixel: 1712
# Depth value at 74, 264 pixel: 1712
# Depth value at 74, 264 pixel: 1712
# Depth value at 74, 264 pixel: 1811
# Depth value at 74, 264 pixel: 1811
# Depth value at 74, 264 pixel: 1811
# Depth value at 74, 264 pixel: 1811
# Depth value at 74, 264 pixel: 1811
# Depth value at 74, 264 pixel: 1811
# Depth value at 74, 264 pixel: 1811
# Depth value at 74, 264 pixel: 1811
# Depth value at 74, 264 pixel: 1811
# Depth value at 74, 264 pixel: 1811
# Depth value at 74, 264 pixel: 1811
# Depth value at 74, 264 pixel: 1811
# Depth value at 74, 264 pixel: 1811
# Depth value at 74, 264 pixel: 1811
# Depth value at 74, 264 pixel: 1811
# Depth value at 74, 264 pixel: 1811
# Depth value at 74, 264 pixel: 1811
# Depth value at 74, 264 pixel: 1811
# Depth value at 74, 264 pixel: 1648
# Depth value at 74, 264 pixel: 1648
# Depth value at 74, 264 pixel: 1693
# Depth value at 74, 264 pixel: 1702
# Depth value at 74, 264 pixel: 1657
# Depth value at 74, 264 pixel: 1565
# Depth value at 74, 264 pixel: 1542
# Depth value at 74, 264 pixel: 1806
# Depth value at 74, 264 pixel: 1806
# Depth value at 74, 264 pixel: 1806
# Depth value at 74, 264 pixel: 3350
# Speed: 2.34
# Depth value at 74, 264 pixel: 3131
# Speed: 2.2523999999999997
# Depth value at 74, 264 pixel: 2745
# Speed: 2.098
# Depth value at 74, 264 pixel: 2745
# Speed: 2.098
# Depth value at 74, 264 pixel: 2745
# Speed: 2.098
# Depth value at 74, 264 pixel: 2745
# Speed: 2.098
# Depth value at 74, 264 pixel: 2745
# Speed: 2.098
# Depth value at 74, 264 pixel: 2745
# Speed: 2.098
# Depth value at 74, 264 pixel: 2721
# Speed: 2.0884
# Depth value at 74, 264 pixel: 2721
# Speed: 2.0884
# Depth value at 74, 264 pixel: 2721
# Speed: 2.0884
# Depth value at 74, 264 pixel: 3039
# Speed: 2.2156000000000002
# Depth value at 74, 264 pixel: 3179
# Speed: 2.2716000000000003
# Depth value at 74, 264 pixel: 3179
# Speed: 2.2716000000000003
# Depth value at 74, 264 pixel: 3179
# Speed: 2.2716000000000003
# Depth value at 74, 264 pixel: 3115
# Speed: 2.246
# Depth value at 74, 264 pixel: 3115
# Speed: 2.246
# Depth value at 74, 264 pixel: 3115
# Speed: 2.246
# Depth value at 74, 264 pixel: 2640
# Speed: 2.056
# Depth value at 74, 264 pixel: 3131
# Speed: 2.2523999999999997
# Depth value at 74, 264 pixel: 2981
# Speed: 2.1924
# Depth value at 74, 264 pixel: 2981
# Speed: 2.1924
# Depth value at 74, 264 pixel: 3039
# Speed: 2.2156000000000002
# Depth value at 74, 264 pixel: 3039
# Speed: 2.2156000000000002
# Depth value at 249, 397 pixel: 3039
# Speed: 2.2156000000000002
# Depth value at 304, 213 pixel: 3039
# Speed: 2.2156000000000002
# Depth value at 298, 217 pixel: 3039
# Speed: 2.2156000000000002
# Depth value at 295, 220 pixel: 3039
# Speed: 2.2156000000000002
# Depth value at 293, 222 pixel: 3039
# Speed: 2.2156000000000002
# Depth value at 292, 221 pixel: 3039
# Speed: 2.2156000000000002
# Depth value at 290, 221 pixel: 3039
# Speed: 2.2156000000000002
# Depth value at 287, 220 pixel: 3039
# Speed: 2.2156000000000002
# Depth value at 284, 219 pixel: 3039
# Speed: 2.2156000000000002
# Depth value at 284, 218 pixel: 3039
# Speed: 2.2156000000000002
# Depth value at 284, 218 pixel: 3039
# Speed: 2.2156000000000002
# Depth value at 283, 219 pixel: 3039
# Speed: 2.2156000000000002
# Depth value at 284, 219 pixel: 3039
# Speed: 2.2156000000000002
# Depth value at 284, 220 pixel: 3039
# Speed: 2.2156000000000002
# Depth value at 286, 220 pixel: 3039
# Speed: 2.2156000000000002
# Depth value at 290, 221 pixel: 3039
# Speed: 2.2156000000000002
# Depth value at 292, 221 pixel: 3039
# Speed: 2.2156000000000002
# Depth value at 294, 220 pixel: 3039
# Speed: 2.2156000000000002
# Depth value at 297, 219 pixel: 3039
# Speed: 2.2156000000000002
# Depth value at 297, 218 pixel: 3039
# Speed: 2.2156000000000002
# Depth value at 299, 216 pixel: 3039
# Speed: 2.2156000000000002
# Depth value at 302, 214 pixel: 3039
# Speed: 2.2156000000000002
# Depth value at 306, 213 pixel: 3039
# Speed: 2.2156000000000002
# Depth value at 310, 214 pixel: 3039
# Speed: 2.2156000000000002
# Depth value at 312, 215 pixel: 3039
# Speed: 2.2156000000000002
# Depth value at 315, 215 pixel: 3039
# Speed: 2.2156000000000002
# Depth value at 316, 215 pixel: 3039
# Speed: 2.2156000000000002
# Depth value at 316, 215 pixel: 3039
# Speed: 2.2156000000000002
# Depth value at 317, 213 pixel: 3039
# Speed: 2.2156000000000002
# Depth value at 316, 213 pixel: 3039
# Speed: 2.2156000000000002
# Depth value at 317, 213 pixel: 3039
# Speed: 2.2156000000000002
# Depth value at 316, 212 pixel: 3039
# Speed: 2.2156000000000002
# Depth value at 315, 212 pixel: 3039
# Speed: 2.2156000000000002
# Depth value at 315, 212 pixel: 3039
# Speed: 2.2156000000000002
# Depth value at 316, 212 pixel: 3039
# Speed: 2.2156000000000002
# Depth value at 316, 212 pixel: 3039
# Speed: 2.2156000000000002
# Depth value at 317, 213 pixel: 3039
# Speed: 2.2156000000000002
# Depth value at 317, 213 pixel: 3039
# Speed: 2.2156000000000002
# Depth value at 318, 213 pixel: 3039
# Speed: 2.2156000000000002
# Depth value at 319, 213 pixel: 3039
# Speed: 2.2156000000000002
# Depth value at 319, 213 pixel: 3039
# Speed: 2.2156000000000002
# Depth value at 318, 213 pixel: 3039
# Speed: 2.2156000000000002
# Depth value at 318, 213 pixel: 3039
# Speed: 2.2156000000000002
# Depth value at 318, 214 pixel: 3039
# Speed: 2.2156000000000002
# Depth value at 317, 214 pixel: 3039
# Speed: 2.2156000000000002
# Depth value at 317, 213 pixel: 3039
# Speed: 2.2156000000000002
# Depth value at 317, 213 pixel: 3039
# Speed: 2.2156000000000002
# Depth value at 317, 213 pixel: 3039
# Speed: 2.2156000000000002
# Depth value at 316, 212 pixel: 3039
# Speed: 2.2156000000000002
# Depth value at 316, 213 pixel: 3039
# Speed: 2.2156000000000002
# Depth value at 316, 212 pixel: 3039
# Speed: 2.2156000000000002
# Depth value at 316, 212 pixel: 3039
# Speed: 2.2156000000000002
# Depth value at 317, 212 pixel: 3039
# Speed: 2.2156000000000002
# Depth value at 317, 212 pixel: 3039
# Speed: 2.2156000000000002
# Depth value at 317, 212 pixel: 3039
# Speed: 2.2156000000000002
# Depth value at 317, 212 pixel: 3039
# Speed: 2.2156000000000002
# Depth value at 316, 212 pixel: 3039
# Speed: 2.2156000000000002
# Depth value at 316, 212 pixel: 3039
# Speed: 2.2156000000000002
# Depth value at 317, 212 pixel: 3039
# Speed: 2.2156000000000002
# Depth value at 316, 211 pixel: 3039
# Speed: 2.2156000000000002
# Depth value at 316, 209 pixel: 3039
# Speed: 2.2156000000000002
# Depth value at 316, 209 pixel: 3039
# Speed: 2.2156000000000002
# Depth value at 317, 205 pixel: 3039
# Speed: 2.2156000000000002
# Depth value at 317, 206 pixel: 3039
# Speed: 2.2156000000000002
# Depth value at 317, 206 pixel: 3039
# Speed: 2.2156000000000002
# Depth value at 317, 207 pixel: 3039
# Speed: 2.2156000000000002
# Depth value at 317, 207 pixel: 3039
# Speed: 2.2156000000000002
# Depth value at 317, 209 pixel: 3039
# Speed: 2.2156000000000002
# Depth value at 316, 208 pixel: 3039
# Speed: 2.2156000000000002
# Depth value at 315, 209 pixel: 3039
# Speed: 2.2156000000000002
# Depth value at 315, 208 pixel: 3039
# Speed: 2.2156000000000002
# Depth value at 314, 208 pixel: 3039
# Speed: 2.2156000000000002
# Depth value at 314, 208 pixel: 3039
# Speed: 2.2156000000000002
# Depth value at 315, 209 pixel: 3039
# Speed: 2.2156000000000002
# Depth value at 314, 208 pixel: 3039
# Speed: 2.2156000000000002
# Depth value at 314, 209 pixel: 3039
# Speed: 2.2156000000000002
# Depth value at 315, 209 pixel: 3039
# Speed: 2.2156000000000002
# Depth value at 316, 208 pixel: 3039
# Speed: 2.2156000000000002
# Depth value at 316, 208 pixel: 3039
# Speed: 2.2156000000000002
# Depth value at 316, 208 pixel: 3039
# Speed: 2.2156000000000002
# Depth value at 315, 207 pixel: 3039
# Speed: 2.2156000000000002
# Depth value at 315, 206 pixel: 3039
# Speed: 2.2156000000000002
# Depth value at 315, 206 pixel: 3039
# Speed: 2.2156000000000002
# Depth value at 315, 207 pixel: 3039
# Speed: 2.2156000000000002
# Depth value at 314, 208 pixel: 3039
# Speed: 2.2156000000000002
# Depth value at 315, 209 pixel: 3039
# Speed: 2.2156000000000002
# Depth value at 314, 211 pixel: 3039
# Speed: 3.3376923076923077
# Depth value at 315, 211 pixel: 3039
# Speed: 3.3376923076923077
# Depth value at 314, 210 pixel: 3039
# Speed: 3.3376923076923077
# Depth value at 314, 210 pixel: 3039
# Speed: 3.3376923076923077
# Depth value at 315, 209 pixel: 3039
# Speed: 3.3376923076923077
# Depth value at 315, 209 pixel: 3039
# Speed: 3.3376923076923077
# Depth value at 314, 209 pixel: 3039
# Speed: 3.3376923076923077
# Depth value at 313, 209 pixel: 3039
# Speed: 3.3376923076923077
# Depth value at 314, 210 pixel: 3039
# Speed: 3.3376923076923077
# Depth value at 314, 209 pixel: 3039
# Speed: 3.3376923076923077
# Depth value at 315, 210 pixel: 3039
# Speed: 3.3376923076923077
# Depth value at 314, 211 pixel: 3039
# Speed: 3.3376923076923077
# Depth value at 315, 211 pixel: 3039
# Speed: 3.3376923076923077
# Depth value at 315, 211 pixel: 3039
# Speed: 3.3376923076923077
# Depth value at 316, 211 pixel: 3039
# Speed: 3.3376923076923077
# Depth value at 315, 212 pixel: 3039
# Speed: 3.3376923076923077
# Depth value at 316, 211 pixel: 3039
# Speed: 3.3376923076923077
# Depth value at 316, 211 pixel: 3039
# Speed: 3.3376923076923077
# Depth value at 316, 212 pixel: 3039
# Speed: 3.3376923076923077
# Depth value at 316, 211 pixel: 3039
# Speed: 3.3376923076923077
# Depth value at 315, 212 pixel: 3039
# Speed: 3.3376923076923077
# Depth value at 315, 212 pixel: 3039
# Speed: 3.3376923076923077
# Depth value at 315, 212 pixel: 3039
# Speed: 3.3376923076923077
# Depth value at 315, 211 pixel: 3039
# Speed: 3.3376923076923077
# Depth value at 315, 211 pixel: 3039
# Speed: 3.3376923076923077
# Depth value at 315, 212 pixel: 3039
# Speed: 3.3376923076923077
# Depth value at 314, 212 pixel: 3039
# Speed: 3.3376923076923077
# Depth value at 315, 211 pixel: 3039
# Speed: 3.3376923076923077
# Depth value at 314, 212 pixel: 3039
# Speed: 3.3376923076923077
# Depth value at 313, 212 pixel: 3039
# Speed: 3.3376923076923077
# Depth value at 315, 212 pixel: 3039
# Speed: 3.3376923076923077
# Depth value at 315, 213 pixel: 3039
# Speed: 3.3376923076923077
# Depth value at 315, 212 pixel: 3039
# Speed: 3.3376923076923077
# Depth value at 316, 212 pixel: 3039
# Speed: 3.3376923076923077
# Depth value at 318, 210 pixel: 3039
# Speed: 3.3376923076923077
# Depth value at 318, 208 pixel: 3039
# Speed: 3.3376923076923077
# Depth value at 317, 208 pixel: 3039
# Speed: 3.3376923076923077
# Depth value at 318, 206 pixel: 3039
# Speed: 3.3376923076923077
# Depth value at 317, 204 pixel: 3039
# Speed: 3.3376923076923077
# Depth value at 319, 203 pixel: 3039
# Speed: 3.3376923076923077
# Depth value at 320, 204 pixel: 3039
# Speed: 3.3376923076923077
# Depth value at 320, 207 pixel: 3039
# Speed: 3.3376923076923077
# Depth value at 323, 209 pixel: 3039
# Speed: 3.3376923076923077
# Depth value at 322, 211 pixel: 3039
# Speed: 3.3376923076923077
# Depth value at 321, 214 pixel: 3039
# Speed: 3.3376923076923077
# Depth value at 321, 214 pixel: 3039
# Speed: 3.3376923076923077
# Depth value at 322, 213 pixel: 3039
# Speed: 3.3376923076923077
# Depth value at 322, 209 pixel: 3039
# Speed: 3.3376923076923077
# Depth value at 322, 209 pixel: 3039
# Speed: 3.3376923076923077
# Depth value at 322, 209 pixel: 3039
# Speed: 3.3376923076923077
# Depth value at 322, 209 pixel: 3039
# Speed: 3.3376923076923077
# Depth value at 322, 209 pixel: 3039
# Speed: 3.3376923076923077
# Depth value at 322, 209 pixel: 3039
# Speed: 3.3376923076923077
# Depth value at 322, 209 pixel: 3039
# Speed: 3.3376923076923077
# Depth value at 324, 209 pixel: 3039
# Speed: 3.3376923076923077
# Depth value at 325, 208 pixel: 3039
# Speed: 3.3376923076923077
# Depth value at 324, 208 pixel: 3039
# Speed: 3.3376923076923077
# Depth value at 325, 210 pixel: 3039
# Speed: 3.3376923076923077
# Depth value at 324, 211 pixel: 3039
# Speed: 3.3376923076923077
# Depth value at 324, 211 pixel: 3039
# Speed: 3.3376923076923077
# Depth value at 324, 211 pixel: 3039
# Speed: 3.3376923076923077
# Depth value at 324, 211 pixel: 3039
# Speed: 3.3376923076923077
# Depth value at 324, 211 pixel: 3039
# Speed: 3.3376923076923077
# Depth value at 324, 211 pixel: 3039
# Speed: 3.3376923076923077
# Depth value at 324, 211 pixel: 3039
# Speed: 3.3376923076923077
# Depth value at 323, 212 pixel: 3039
# Speed: 3.3376923076923077
# Depth value at 322, 212 pixel: 3039
# Speed: 3.3376923076923077
# Depth value at 323, 213 pixel: 3039
# Speed: 3.3376923076923077
# Depth value at 323, 213 pixel: 3039
# Speed: 3.3376923076923077
# Depth value at 324, 214 pixel: 3039
# Speed: 3.3376923076923077
# Depth value at 324, 214 pixel: 3039
# Speed: 3.3376923076923077
# Depth value at 324, 214 pixel: 3039
# Speed: 3.3376923076923077
# Depth value at 324, 213 pixel: 3039
# Speed: 3.3376923076923077
# Depth value at 324, 214 pixel: 3039
# Speed: 3.3376923076923077
# Depth value at 325, 216 pixel: 3039
# Speed: 3.3376923076923077
# Depth value at 325, 216 pixel: 3039
# Speed: 3.3376923076923077
# Depth value at 327, 216 pixel: 3039
# Speed: 3.3376923076923077
# Depth value at 327, 217 pixel: 3039
# Speed: 3.3376923076923077
# Depth value at 328, 217 pixel: 3039
# Speed: 3.3376923076923077
# Depth value at 329, 216 pixel: 3039
# Speed: 3.3376923076923077
# Depth value at 329, 217 pixel: 3039
# Speed: 3.3376923076923077
# Depth value at 332, 216 pixel: 3039
# Speed: 3.3376923076923077
# Depth value at 333, 217 pixel: 3039
# Speed: 3.3376923076923077
# Depth value at 335, 218 pixel: 3039
# Speed: 3.3376923076923077
# Depth value at 335, 218 pixel: 3039
# Speed: 3.3376923076923077
# Depth value at 337, 216 pixel: 3039
# Speed: 3.3376923076923077
# Depth value at 339, 216 pixel: 3039
# Speed: 3.3376923076923077
# Depth value at 340, 218 pixel: 3039
# Speed: 3.3376923076923077
# Depth value at 341, 220 pixel: 3039
# Speed: 3.3376923076923077
# Depth value at 343, 221 pixel: 3039
# Speed: 3.3376923076923077
# Depth value at 346, 219 pixel: 3039
# Speed: 3.3376923076923077
# Depth value at 349, 218 pixel: 3039
# Speed: 3.3376923076923077
# Depth value at 350, 218 pixel: 3039
# Speed: 3.3376923076923077
# Depth value at 351, 216 pixel: 3039
# Speed: 3.3376923076923077
# Depth value at 351, 216 pixel: 3039
# Speed: 3.3376923076923077
# Depth value at 351, 216 pixel: 3039
# Speed: 3.3376923076923077
# Depth value at 350, 217 pixel: 3039
# Speed: 3.3376923076923077
# Depth value at 350, 216 pixel: 3039
# Speed: 3.3376923076923077
# Depth value at 348, 216 pixel: 3039
# Speed: 3.3376923076923077
# Depth value at 347, 216 pixel: 3039
# Speed: 3.3376923076923077
# Depth value at 345, 216 pixel: 3039
# Speed: 3.3376923076923077
# Depth value at 342, 215 pixel: 3039
# Speed: 3.3376923076923077
# Depth value at 339, 215 pixel: 3039
# Speed: 3.3376923076923077
# Depth value at 336, 214 pixel: 3039
# Speed: 3.3376923076923077
# Depth value at 334, 215 pixel: 3039
# Speed: 3.3376923076923077
# Depth value at 330, 215 pixel: 3039
# Speed: 3.3376923076923077
# Depth value at 329, 216 pixel: 3039
# Speed: 3.3376923076923077
# Depth value at 321, 217 pixel: 3039
# Speed: 3.3376923076923077
# Depth value at 317, 217 pixel: 3039
# Speed: 3.3376923076923077
# Depth value at 315, 217 pixel: 3039
# Speed: 3.3376923076923077
# Depth value at 308, 219 pixel: 3039
# Speed: 3.3376923076923077
# Depth value at 307, 220 pixel: 3039
# Speed: 3.3376923076923077
# Depth value at 303, 218 pixel: 3039
# Speed: 3.3376923076923077
# Depth value at 300, 219 pixel: 3039
# Speed: 3.3376923076923077
# Depth value at 298, 219 pixel: 3039
# Speed: 3.3376923076923077
# Depth value at 297, 220 pixel: 3039
# Speed: 3.3376923076923077
# Depth value at 295, 221 pixel: 3039
# Speed: 3.3376923076923077
# Depth value at 295, 220 pixel: 3039
# Speed: 3.3376923076923077
# Depth value at 294, 221 pixel: 3039
# Speed: 3.3376923076923077
# Depth value at 293, 220 pixel: 3039
# Speed: 3.3376923076923077
# Depth value at 294, 220 pixel: 3039
# Speed: 3.3376923076923077
# Depth value at 294, 221 pixel: 3039
# Speed: 3.3376923076923077
# Depth value at 294, 220 pixel: 3039
# Speed: 3.3376923076923077
# Depth value at 295, 221 pixel: 3039
# Speed: 3.3376923076923077
# Depth value at 296, 220 pixel: 3039
# Speed: 3.3376923076923077
# Depth value at 297, 219 pixel: 3039
# Speed: 3.3376923076923077
# Depth value at 298, 219 pixel: 3039
# Speed: 3.3376923076923077
# Depth value at 299, 219 pixel: 3039
# Speed: 3.3376923076923077
# Depth value at 300, 219 pixel: 3039
# Speed: 3.3376923076923077
# Depth value at 301, 219 pixel: 3039
# Speed: 3.3376923076923077
# Depth value at 302, 219 pixel: 3039
# Speed: 3.3376923076923077
# Depth value at 304, 219 pixel: 3039
# Speed: 3.3376923076923077
# Depth value at 305, 219 pixel: 3039
# Speed: 3.3376923076923077
# Depth value at 307, 219 pixel: 3039
# Speed: 3.3376923076923077
# Depth value at 309, 219 pixel: 3039
# Speed: 3.3376923076923077
# Depth value at 309, 220 pixel: 3039
# Speed: 3.3376923076923077
# Depth value at 310, 221 pixel: 3039
# Speed: 3.3376923076923077
# Depth value at 310, 220 pixel: 3039
# Speed: 3.3376923076923077
# Depth value at 311, 218 pixel: 3039
# Speed: 3.3376923076923077
# Depth value at 312, 218 pixel: 3039
# Speed: 3.3376923076923077
# Depth value at 313, 218 pixel: 3039
# Speed: 3.3376923076923077
# Depth value at 313, 219 pixel: 3039
# Speed: 3.3376923076923077
# Depth value at 315, 219 pixel: 3039
# Speed: 3.3376923076923077
# Depth value at 315, 219 pixel: 3039
# Speed: 3.3376923076923077
# Depth value at 313, 219 pixel: 3039
# Speed: 3.3376923076923077
# Depth value at 307, 219 pixel: 3039
# Speed: 3.3376923076923077
# Depth value at 301, 218 pixel: 3039
# Speed: 3.3376923076923077
# Depth value at 292, 220 pixel: 3039
# Speed: 3.3376923076923077
# Depth value at 281, 218 pixel: 3039
# Speed: 3.3376923076923077
# Depth value at 277, 219 pixel: 3039
# Speed: 3.3376923076923077
# Depth value at 265, 220 pixel: 3039
# Speed: 3.3376923076923077
# Depth value at 253, 220 pixel: 3039
# Speed: 3.3376923076923077
# Depth value at 242, 222 pixel: 3039
# Speed: 3.3376923076923077
# Depth value at 227, 221 pixel: 3039
# Speed: 3.3376923076923077
# Depth value at 213, 221 pixel: 3039
# Speed: 3.3376923076923077
# Depth value at 207, 219 pixel: 3039
# Speed: 3.3376923076923077
# Depth value at 199, 221 pixel: 1849
# Speed: 2.422307692307692
# Depth value at 126, 396 pixel: 1849
# Speed: 2.422307692307692
# Depth value at 126, 396 pixel: 1849
# Speed: 2.422307692307692
# Depth value at 126, 396 pixel: 1849
# Speed: 2.422307692307692
# Depth value at 126, 396 pixel: 1849
# Speed: 2.422307692307692
# Depth value at 126, 396 pixel: 1849
# Speed: 2.422307692307692
# Depth value at 126, 396 pixel: 1849
# Speed: 2.422307692307692
# Depth value at 126, 396 pixel: 1849
# Speed: 2.422307692307692
# Depth value at 126, 396 pixel: 1849
# Speed: 2.422307692307692
# Depth value at 126, 396 pixel: 1849
# Speed: 2.422307692307692
# Depth value at 126, 396 pixel: 1849
# Speed: 2.422307692307692
# Depth value at 126, 396 pixel: 1849
# Depth value at 126, 396 pixel: 1849
# Depth value at 126, 396 pixel: 1849
# Depth value at 126, 396 pixel: 1849
# Depth value at 126, 396 pixel: 1849
# Depth value at 126, 396 pixel: 1849
# Depth value at 126, 396 pixel: 1849
# Depth value at 126, 396 pixel: 1849
# Depth value at 126, 396 pixel: 1849
# Depth value at 126, 396 pixel: 1849
# Depth value at 126, 396 pixel: 1849
# Depth value at 126, 396 pixel: 2898
# Depth value at 126, 396 pixel: 3870
# Depth value at 126, 396 pixel: 3870
# Depth value at 126, 396 pixel: 3870
# Depth value at 126, 396 pixel: 3870
# Depth value at 126, 396 pixel: 3870
# Depth value at 126, 396 pixel: 3870
# Depth value at 126, 396 pixel: 3870
# Depth value at 126, 396 pixel: 3870
# Depth value at 126, 396 pixel: 3870
# Depth value at 126, 396 pixel: 3870
# Depth value at 126, 396 pixel: 3870
# Depth value at 126, 396 pixel: 3870
# Depth value at 126, 396 pixel: 3870
# Depth value at 126, 396 pixel: 3870
# Depth value at 126, 396 pixel: 3870
# Depth value at 126, 396 pixel: 1984
# Depth value at 126, 396 pixel: 1984
# Depth value at 126, 396 pixel: 1984
# Depth value at 126, 396 pixel: 1984
# Depth value at 126, 396 pixel: 1984
# Depth value at 126, 396 pixel: 3386
# Depth value at 126, 396 pixel: 3386
# Depth value at 126, 396 pixel: 3386
# Depth value at 126, 396 pixel: 3386
# Depth value at 126, 396 pixel: 3386
# Depth value at 126, 396 pixel: 3386
# Depth value at 126, 396 pixel: 3386
# Depth value at 126, 396 pixel: 3386
# Depth value at 126, 396 pixel: 3386
# Depth value at 126, 396 pixel: 3386
# Depth value at 126, 396 pixel: 3386
# Depth value at 126, 396 pixel: 3386
# Depth value at 126, 396 pixel: 3386
# Depth value at 126, 396 pixel: 3386
# Depth value at 126, 396 pixel: 3386
# Depth value at 126, 396 pixel: 3386
# Depth value at 126, 396 pixel: 3386
# Depth value at 126, 396 pixel: 3386
# Depth value at 126, 396 pixel: 3386
# Depth value at 126, 396 pixel: 3386
# Depth value at 126, 396 pixel: 3386
# Depth value at 126, 396 pixel: 3386
# Depth value at 126, 396 pixel: 3386
# Depth value at 126, 396 pixel: 3386
# Depth value at 126, 396 pixel: 3386
# Depth value at 126, 396 pixel: 3386
# Depth value at 126, 396 pixel: 3386
# Speed: 3.6046153846153848
# Depth value at 126, 396 pixel: 3386
# Speed: 3.6046153846153848
# Depth value at 126, 396 pixel: 3386
# Speed: 3.6046153846153848
# Depth value at 126, 396 pixel: 3386
# Speed: 3.6046153846153848
# Depth value at 126, 396 pixel: 3386
# Speed: 3.6046153846153848
# Depth value at 126, 396 pixel: 3386
# Speed: 3.6046153846153848
# Depth value at 126, 396 pixel: 3386
# Speed: 3.6046153846153848
# Depth value at 126, 396 pixel: 3386
# Speed: 3.6046153846153848
# Depth value at 126, 396 pixel: 3386
# Speed: 3.6046153846153848
# Depth value at 126, 396 pixel: 3386
# Speed: 3.6046153846153848
# Depth value at 126, 396 pixel: 3386
# Speed: 3.6046153846153848
# Depth value at 275, 219 pixel: 3386
# Speed: 3.6046153846153848
# Depth value at 293, 224 pixel: 3386
# Speed: 3.6046153846153848
# Depth value at 308, 228 pixel: 1644
# Speed: 2.264615384615385
# Depth value at 348, 213 pixel: 1644
# Speed: 2.264615384615385
# Depth value at 358, 215 pixel: 1644
# Speed: 2.264615384615385
# Depth value at 369, 214 pixel: 1644
# Speed: 2.264615384615385
# Depth value at 374, 213 pixel: 1644
# Speed: 2.264615384615385
# Depth value at 376, 215 pixel: 1644
# Speed: 2.264615384615385
# Depth value at 374, 214 pixel: 1644
# Speed: 2.264615384615385
# Depth value at 375, 215 pixel: 1644
# Speed: 2.264615384615385
# Depth value at 375, 215 pixel: 1644
# Speed: 2.264615384615385
# Depth value at 374, 215 pixel: 1644
# Speed: 2.264615384615385
# Depth value at 373, 216 pixel: 1644
# Speed: 2.264615384615385
# Depth value at 372, 215 pixel: 1644
# Speed: 2.264615384615385
# Depth value at 370, 214 pixel: 1644
# Speed: 2.264615384615385
# Depth value at 370, 214 pixel: 1644
# Speed: 2.264615384615385
# Depth value at 369, 213 pixel: 1644
# Speed: 2.264615384615385
# Depth value at 369, 213 pixel: 1644
# Speed: 2.264615384615385
# Depth value at 368, 213 pixel: 1644
# Speed: 2.264615384615385
# Depth value at 368, 212 pixel: 1644
# Speed: 2.264615384615385
# Depth value at 368, 214 pixel: 1644
# Speed: 2.264615384615385
# Depth value at 368, 214 pixel: 1644
# Speed: 2.264615384615385
# Depth value at 368, 214 pixel: 1644
# Speed: 2.264615384615385
# Depth value at 368, 215 pixel: 1644
# Speed: 2.264615384615385
# Depth value at 367, 215 pixel: 1644
# Speed: 2.264615384615385
# Depth value at 367, 215 pixel: 1644
# Speed: 2.264615384615385
# Depth value at 364, 215 pixel: 1644
# Speed: 2.264615384615385
# Depth value at 353, 217 pixel: 1644
# Speed: 2.264615384615385
# Depth value at 346, 217 pixel: 1644
# Speed: 2.264615384615385
# Depth value at 337, 225 pixel: 1644
# Speed: 2.264615384615385
# Depth value at 327, 226 pixel: 1644
# Speed: 2.264615384615385
# Depth value at 316, 230 pixel: 1770
# Speed: 2.3615384615384616
# Depth value at 307, 232 pixel: 1770
# Speed: 2.3615384615384616
# Depth value at 299, 234 pixel: 1770
# Speed: 2.3615384615384616
# Depth value at 293, 231 pixel: 1770
# Speed: 2.3615384615384616
# Depth value at 289, 230 pixel: 1770
# Speed: 2.3615384615384616
# Depth value at 285, 231 pixel: 1770
# Speed: 2.3615384615384616
# Depth value at 283, 231 pixel: 1770
# Speed: 2.3615384615384616
# Depth value at 284, 231 pixel: 1770
# Speed: 2.3615384615384616
# Depth value at 287, 231 pixel: 1770
# Speed: 2.3615384615384616
# Depth value at 293, 230 pixel: 1770
# Speed: 2.3615384615384616
# Depth value at 305, 229 pixel: 1770
# Speed: 2.3615384615384616
# Depth value at 311, 229 pixel: 1770
# Speed: 2.3615384615384616
# Depth value at 319, 226 pixel: 1770
# Speed: 2.3615384615384616
# Depth value at 325, 224 pixel: 1770
# Speed: 2.3615384615384616
# Depth value at 331, 226 pixel: 1770
# Speed: 2.3615384615384616
# Depth value at 336, 224 pixel: 1770
# Speed: 2.3615384615384616
# Depth value at 338, 223 pixel: 1770
# Speed: 2.3615384615384616
# Depth value at 339, 222 pixel: 1770
# Speed: 2.3615384615384616
# Depth value at 338, 221 pixel: 1770
# Speed: 2.3615384615384616
# Depth value at 337, 224 pixel: 1770
# Speed: 2.3615384615384616
# Depth value at 331, 225 pixel: 1770
# Speed: 2.3615384615384616
# Depth value at 327, 225 pixel: 1770
# Speed: 2.3615384615384616
# Depth value at 317, 230 pixel: 1765
# Speed: 2.3576923076923078
# Depth value at 314, 230 pixel: 1775
# Speed: 2.3653846153846154
# Depth value at 313, 230 pixel: 1775
# Speed: 2.3653846153846154
# Depth value at 312, 231 pixel: 1775
# Speed: 2.3653846153846154
# Depth value at 314, 230 pixel: 1775
# Speed: 2.3653846153846154
# Depth value at 318, 227 pixel: 1775
# Speed: 2.3653846153846154
# Depth value at 319, 225 pixel: 1775
# Speed: 2.3653846153846154
# Depth value at 324, 222 pixel: 1775
# Speed: 2.3653846153846154
# Depth value at 326, 225 pixel: 1775
# Speed: 2.3653846153846154
# Depth value at 327, 223 pixel: 1775
# Speed: 2.3653846153846154
# Depth value at 330, 220 pixel: 1775
# Speed: 2.3653846153846154
# Depth value at 328, 223 pixel: 1775
# Speed: 2.3653846153846154
# Depth value at 328, 223 pixel: 1775
# Speed: 2.3653846153846154
# Depth value at 323, 225 pixel: 1775
# Speed: 2.3653846153846154
# Depth value at 323, 225 pixel: 1775
# Speed: 2.3653846153846154
# Depth value at 323, 225 pixel: 1775
# Speed: 2.3653846153846154
# Depth value at 323, 225 pixel: 1775
# Speed: 2.3653846153846154
# Depth value at 308, 229 pixel: 1775
# Speed: 2.3653846153846154
# Depth value at 306, 230 pixel: 1775
# Speed: 2.3653846153846154
# Depth value at 306, 225 pixel: 1775
# Speed: 2.3653846153846154
# Depth value at 305, 225 pixel: 1775
# Speed: 2.3653846153846154
# Depth value at 305, 225 pixel: 1775
# Speed: 2.3653846153846154
# Depth value at 315, 222 pixel: 1775
# Speed: 2.3653846153846154
# Depth value at 316, 221 pixel: 1775
# Speed: 2.3653846153846154
# Depth value at 316, 220 pixel: 1775
# Speed: 2.3653846153846154
# Depth value at 316, 225 pixel: 1775
# Speed: 2.3653846153846154
# Depth value at 314, 226 pixel: 1775
# Speed: 2.3653846153846154
# Depth value at 313, 224 pixel: 1775
# Speed: 2.3653846153846154
# Depth value at 311, 223 pixel: 1775
# Speed: 2.3653846153846154
# Depth value at 309, 222 pixel: 1775
# Speed: 2.3653846153846154
# Depth value at 309, 219 pixel: 1775
# Speed: 2.3653846153846154
# Depth value at 310, 221 pixel: 1775
# Speed: 2.3653846153846154
# Depth value at 312, 220 pixel: 1775
# Speed: 2.3653846153846154
# Depth value at 316, 222 pixel: 1775
# Speed: 2.3653846153846154
# Depth value at 322, 226 pixel: 1775
# Speed: 2.3653846153846154
# Depth value at 326, 226 pixel: 1775
# Speed: 2.3653846153846154
# Depth value at 329, 224 pixel: 1775
# Speed: 2.3653846153846154
# Depth value at 334, 224 pixel: 1775
# Speed: 2.3653846153846154
# Depth value at 337, 224 pixel: 1775
# Speed: 2.3653846153846154
# Depth value at 337, 222 pixel: 1775
# Speed: 2.3653846153846154
# Depth value at 339, 221 pixel: 1775
# Speed: 2.3653846153846154
# Depth value at 338, 221 pixel: 1775
# Speed: 2.3653846153846154
# Depth value at 339, 218 pixel: 1775
# Speed: 2.3653846153846154
# Depth value at 336, 220 pixel: 1775
# Speed: 2.3653846153846154
# Depth value at 334, 222 pixel: 1775
# Speed: 2.3653846153846154
# Depth value at 327, 226 pixel: 1775
# Speed: 2.3653846153846154
# Depth value at 324, 228 pixel: 1775
# Speed: 2.3653846153846154
# Depth value at 320, 225 pixel: 1775
# Speed: 2.3653846153846154
# Depth value at 321, 226 pixel: 1775
# Speed: 2.3653846153846154
# Depth value at 318, 224 pixel: 1775
# Speed: 2.3653846153846154
# Depth value at 319, 224 pixel: 1775
# Speed: 2.3653846153846154
# Depth value at 319, 222 pixel: 1775
# Speed: 2.3653846153846154
# Depth value at 320, 223 pixel: 1775
# Speed: 2.3653846153846154
# Depth value at 323, 226 pixel: 1740
# Speed: 2.338461538461538
# Depth value at 325, 225 pixel: 1740
# Speed: 2.338461538461538
# Depth value at 326, 225 pixel: 1740
# Speed: 2.338461538461538
# Depth value at 326, 225 pixel: 1740
# Speed: 2.338461538461538
# Depth value at 326, 225 pixel: 1740
# Speed: 2.338461538461538
# Depth value at 327, 223 pixel: 1740
# Speed: 2.338461538461538
# Depth value at 329, 224 pixel: 1740
# Speed: 2.338461538461538
# Depth value at 329, 222 pixel: 1740
# Speed: 2.338461538461538
# Depth value at 331, 221 pixel: 1740
# Speed: 2.338461538461538
# Depth value at 332, 223 pixel: 1740
# Speed: 2.338461538461538
# Depth value at 332, 223 pixel: 1740
# Speed: 2.338461538461538
# Depth value at 329, 223 pixel: 1740
# Speed: 2.338461538461538
# Depth value at 332, 218 pixel: 1740
# Speed: 2.338461538461538
# Depth value at 333, 219 pixel: 1740
# Speed: 2.338461538461538
# Depth value at 333, 217 pixel: 1740
# Speed: 2.338461538461538
# Depth value at 332, 217 pixel: 1740
# Speed: 2.338461538461538
# Depth value at 333, 217 pixel: 1740
# Speed: 2.338461538461538
# Depth value at 333, 217 pixel: 1740
# Speed: 2.338461538461538
# Depth value at 333, 217 pixel: 1740
# Speed: 2.338461538461538
# Depth value at 333, 217 pixel: 1740
# Speed: 2.338461538461538
# Depth value at 333, 217 pixel: 1740
# Speed: 2.338461538461538
# Depth value at 333, 217 pixel: 1740
# Speed: 2.338461538461538
# Depth value at 333, 217 pixel: 1740
# Speed: 2.338461538461538
# Depth value at 333, 217 pixel: 1740
# Speed: 2.338461538461538
# Depth value at 332, 218 pixel: 1740
# Speed: 2.338461538461538
# Depth value at 329, 219 pixel: 1740
# Speed: 2.338461538461538
# Depth value at 326, 217 pixel: 1740
# Speed: 2.338461538461538
# Depth value at 324, 219 pixel: 1740
# Speed: 2.338461538461538
# Depth value at 323, 218 pixel: 1740
# Speed: 2.338461538461538
# Depth value at 323, 218 pixel: 1740
# Speed: 2.338461538461538
# Depth value at 320, 220 pixel: 1740
# Speed: 2.338461538461538
# Depth value at 321, 219 pixel: 1740
# Speed: 2.338461538461538
# Depth value at 321, 220 pixel: 1740
# Speed: 2.338461538461538
# Depth value at 321, 221 pixel: 1740
# Speed: 2.338461538461538
# Depth value at 321, 221 pixel: 1740
# Speed: 2.338461538461538
# Depth value at 321, 221 pixel: 1740
# Speed: 2.338461538461538
# Depth value at 319, 222 pixel: 1740
# Speed: 2.338461538461538
# Depth value at 321, 220 pixel: 1740
# Speed: 2.338461538461538
# Depth value at 320, 220 pixel: 1740
# Speed: 2.338461538461538
# Depth value at 322, 221 pixel: 1740
# Speed: 2.338461538461538
# Depth value at 322, 220 pixel: 1740
# Speed: 2.338461538461538
# Depth value at 323, 219 pixel: 1740
# Speed: 2.338461538461538
# Depth value at 320, 219 pixel: 1740
# Speed: 2.338461538461538
# Depth value at 318, 220 pixel: 1740
# Speed: 2.338461538461538
# Depth value at 317, 223 pixel: 1740
# Speed: 2.338461538461538
# Depth value at 317, 226 pixel: 1740
# Speed: 2.338461538461538
# Depth value at 315, 228 pixel: 1740
# Speed: 2.338461538461538
# Depth value at 314, 230 pixel: 1740
# Speed: 2.338461538461538
# Depth value at 313, 231 pixel: 1740
# Speed: 2.338461538461538
# Depth value at 312, 232 pixel: 1740
# Speed: 2.338461538461538
# Depth value at 311, 231 pixel: 1740
# Speed: 2.338461538461538
# Depth value at 311, 233 pixel: 1740
# Speed: 2.338461538461538
# Depth value at 310, 232 pixel: 1740
# Speed: 2.338461538461538
# Depth value at 310, 232 pixel: 1740
# Speed: 2.338461538461538
# Depth value at 308, 230 pixel: 1740
# Speed: 2.338461538461538
# Depth value at 307, 230 pixel: 1740
# Speed: 2.338461538461538
# Depth value at 307, 230 pixel: 1740
# Speed: 2.338461538461538
# Depth value at 306, 230 pixel: 1740
# Speed: 2.338461538461538
# Depth value at 306, 230 pixel: 1740
# Speed: 2.338461538461538
# Depth value at 306, 229 pixel: 1740
# Speed: 2.338461538461538
# Depth value at 307, 230 pixel: 1740
# Speed: 2.338461538461538
# Depth value at 308, 229 pixel: 1740
# Speed: 2.338461538461538
# Depth value at 310, 229 pixel: 1740
# Speed: 2.338461538461538
# Depth value at 311, 230 pixel: 1740
# Speed: 2.338461538461538
# Depth value at 314, 228 pixel: 1740
# Speed: 2.338461538461538
# Depth value at 316, 227 pixel: 1740
# Speed: 2.338461538461538
# Depth value at 318, 225 pixel: 1740
# Speed: 2.338461538461538
# Depth value at 321, 225 pixel: 1740
# Speed: 2.338461538461538
# Depth value at 324, 226 pixel: 1740
# Speed: 2.338461538461538
# Depth value at 328, 225 pixel: 1740
# Speed: 2.338461538461538
# Depth value at 332, 226 pixel: 1740
# Speed: 2.338461538461538
# Depth value at 336, 224 pixel: 1740
# Speed: 2.338461538461538
# Depth value at 340, 222 pixel: 1740
# Speed: 2.338461538461538
# Depth value at 345, 221 pixel: 1740
# Speed: 2.338461538461538
# Depth value at 346, 220 pixel: 1740
# Speed: 2.338461538461538
# Depth value at 350, 220 pixel: 1740
# Speed: 2.338461538461538
# Depth value at 352, 222 pixel: 1740
# Speed: 2.338461538461538
# Depth value at 354, 222 pixel: 1740
# Speed: 2.338461538461538
# Depth value at 357, 223 pixel: 1740
# Speed: 2.338461538461538
# Depth value at 358, 223 pixel: 1740
# Speed: 2.338461538461538
# Depth value at 358, 223 pixel: 1740
# Speed: 2.338461538461538
# Depth value at 358, 223 pixel: 1740
# Speed: 2.338461538461538
# Depth value at 358, 223 pixel: 1740
# Speed: 2.338461538461538
# Depth value at 356, 224 pixel: 1740
# Speed: 2.338461538461538
# Depth value at 353, 224 pixel: 1740
# Speed: 2.338461538461538
# Depth value at 351, 222 pixel: 1740
# Speed: 2.338461538461538
# Depth value at 349, 222 pixel: 1740
# Speed: 2.338461538461538
# Depth value at 347, 224 pixel: 1740
# Speed: 2.338461538461538
# Depth value at 346, 224 pixel: 1740
# Speed: 2.338461538461538
# Depth value at 342, 225 pixel: 1740
# Speed: 2.338461538461538
# Depth value at 340, 224 pixel: 1740
# Speed: 2.338461538461538
# Depth value at 340, 224 pixel: 1740
# Speed: 2.338461538461538
# Depth value at 335, 217 pixel: 1740
# Speed: 2.338461538461538
# Depth value at 320, 215 pixel: 1740
# Depth value at 318, 214 pixel: 1740
# Depth value at 318, 215 pixel: 1740
# Depth value at 319, 215 pixel: 1740
# Depth value at 319, 215 pixel: 1740
# Depth value at 319, 215 pixel: 1740
# Depth value at 319, 216 pixel: 1740
# Depth value at 319, 216 pixel: 1740
# Depth value at 320, 215 pixel: 1740
# Depth value at 320, 215 pixel: 1740
# Depth value at 320, 215 pixel: 1740
# Depth value at 320, 215 pixel: 1740
# Depth value at 321, 214 pixel: 1740
# Depth value at 321, 215 pixel: 1740
# Depth value at 321, 215 pixel: 1740
# Depth value at 321, 215 pixel: 1740
# Depth value at 321, 215 pixel: 1740
# Depth value at 320, 215 pixel: 1740
# Depth value at 320, 215 pixel: 1740
# ...
# Depth value at 124, 223 pixel: 1212
# Depth value at 124, 223 pixel: 1212
# Depth value at 124, 223 pixel: 1212
# Depth value at 124, 223 pixel: 1212
# Depth value at 124, 223 pixel: 1212
# Depth value at 124, 223 pixel: 1212
# Depth value at 124, 223 pixel: 1212
# Depth value at 124, 223 pixel: 1212
# Depth value at 124, 223 pixel: 1212
# Depth value at 124, 223 pixel: 1212
# Depth value at 124, 223 pixel: 1212
# Depth value at 124, 223 pixel: 1212
# Depth value at 124, 223 pixel: 1212
# Depth value at 124, 223 pixel: 1212
# Depth value at 124, 223 pixel: 1212
# Depth value at 124, 223 pixel: 1212
# Depth value at 124, 223 pixel: 1212
# Depth value at 124, 223 pixel: 1212
# Depth value at 124, 223 pixel: 1212
# Depth value at 124, 223 pixel: 1212
# Depth value at 124, 223 pixel: 1212
# Depth value at 124, 223 pixel: 1212
# Depth value at 124, 223 pixel: 1212
# Depth value at 124, 223 pixel: 1212
# Depth value at 124, 223 pixel: 1212
# Depth value at 124, 223 pixel: 1212
# Depth value at 124, 223 pixel: 1212
# Depth value at 124, 223 pixel: 1212
# Depth value at 124, 223 pixel: 1212
# Depth value at 124, 223 pixel: 1212
# Depth value at 124, 223 pixel: 1212
# Depth value at 124, 223 pixel: 1212
# Depth value at 124, 223 pixel: 1212
# Depth value at 124, 223 pixel: 1212
# Depth value at 124, 223 pixel: 1212
# Depth value at 124, 223 pixel: 1212
# Depth value at 124, 223 pixel: 1212
# Depth value at 124, 223 pixel: 1212
# Depth value at 124, 223 pixel: 1212
# Depth value at 124, 223 pixel: 1212
# Depth value at 124, 223 pixel: 1212
# Depth value at 124, 223 pixel: 1212
# Depth value at 124, 223 pixel: 1212
# Depth value at 124, 223 pixel: 1212
# Depth value at 124, 223 pixel: 1212
# Depth value at 124, 223 pixel: 1212
# Depth value at 124, 223 pixel: 1212
# Depth value at 124, 223 pixel: 1212
# Depth value at 124, 223 pixel: 1212
# Depth value at 124, 223 pixel: 1212
# Depth value at 124, 223 pixel: 1212
# Depth value at 124, 223 pixel: 1212
# Depth value at 124, 223 pixel: 1212
# Depth value at 124, 223 pixel: 1212
# Depth value at 124, 223 pixel: 1212
# Depth value at 124, 223 pixel: 1212
# Depth value at 124, 223 pixel: 1212
# Depth value at 124, 223 pixel: 1212
# Depth value at 124, 223 pixel: 1212
# Depth value at 124, 223 pixel: 1212
# Depth value at 124, 223 pixel: 1212
# Depth value at 124, 223 pixel: 1212
# Depth value at 124, 223 pixel: 1212
# Depth value at 124, 223 pixel: 1212
# Depth value at 124, 223 pixel: 1212
# Depth value at 124, 223 pixel: 1212
# Depth value at 124, 223 pixel: 1212
# Depth value at 124, 223 pixel: 1212
# Depth value at 124, 223 pixel: 1212
# Depth value at 124, 223 pixel: 1212
# Depth value at 124, 223 pixel: 1212
# Depth value at 124, 223 pixel: 1212
# Depth value at 124, 223 pixel: 1212
# Depth value at 124, 223 pixel: 1212
# Depth value at 124, 223 pixel: 1212
# Depth value at 124, 223 pixel: 1212
# Depth value at 124, 223 pixel: 1212
# Depth value at 124, 223 pixel: 1212
# Depth value at 124, 223 pixel: 1212
# Depth value at 124, 223 pixel: 1212
# Depth value at 124, 223 pixel: 1212
# Depth value at 124, 223 pixel: 1212
# Depth value at 124, 223 pixel: 1212
# Depth value at 124, 223 pixel: 1212
# Depth value at 124, 223 pixel: 1212
# Depth value at 124, 223 pixel: 1212
# Depth value at 124, 223 pixel: 1212
# Depth value at 124, 223 pixel: 1212
# Depth value at 124, 223 pixel: 1212
# Depth value at 124, 223 pixel: 1212
# Depth value at 124, 223 pixel: 1212
# Depth value at 124, 223 pixel: 1212
# Depth value at 124, 223 pixel: 1212
# Depth value at 124, 223 pixel: 1212
# Depth value at 124, 223 pixel: 1212
# Depth value at 124, 223 pixel: 1212
# Depth value at 124, 223 pixel: 1212
# Depth value at 124, 223 pixel: 1212
# Depth value at 124, 223 pixel: 1212
# Depth value at 124, 223 pixel: 1212
# Depth value at 124, 223 pixel: 1212
# Depth value at 124, 223 pixel: 1212
# Depth value at 124, 223 pixel: 1212
# Depth value at 124, 223 pixel: 1212
# Depth value at 124, 223 pixel: 1212
# Depth value at 124, 223 pixel: 1212
# Depth value at 124, 223 pixel: 1212
# Depth value at 124, 223 pixel: 1212
# Depth value at 124, 223 pixel: 1212
# Depth value at 124, 223 pixel: 1212
# Depth value at 124, 223 pixel: 1212
# Depth value at 124, 223 pixel: 1212
# Depth value at 124, 223 pixel: 1212
# Depth value at 124, 223 pixel: 1212
# Depth value at 124, 223 pixel: 1212
# Depth value at 124, 223 pixel: 1212
# Depth value at 124, 223 pixel: 1212
# Depth value at 124, 223 pixel: 1212
# Depth value at 124, 223 pixel: 1212
# Depth value at 124, 223 pixel: 1212
# Depth value at 124, 223 pixel: 1212
# Depth value at 124, 223 pixel: 1212
# Depth value at 124, 223 pixel: 1212
# Depth value at 124, 223 pixel: 1212
# Depth value at 124, 223 pixel: 1212
# Depth value at 124, 223 pixel: 1212
# Depth value at 124, 223 pixel: 1212
# Depth value at 124, 223 pixel: 1212
# Depth value at 124, 223 pixel: 1212
# Depth value at 124, 223 pixel: 1212
# Depth value at 124, 223 pixel: 1212
# Depth value at 124, 223 pixel: 1212
# Depth value at 124, 223 pixel: 1212
# Depth value at 124, 223 pixel: 1212
# Depth value at 124, 223 pixel: 1212
# Depth value at 124, 223 pixel: 1212
# Depth value at 124, 223 pixel: 1212
# Depth value at 124, 223 pixel: 1212
# Depth value at 124, 223 pixel: 1212
# Depth value at 124, 223 pixel: 1212
# Depth value at 124, 223 pixel: 1212
# Depth value at 124, 223 pixel: 1212
# Depth value at 124, 223 pixel: 1212
# Depth value at 124, 223 pixel: 1212
# Depth value at 124, 223 pixel: 1212
# Depth value at 124, 223 pixel: 1212
# Depth value at 124, 223 pixel: 1212
# Depth value at 124, 223 pixel: 1212
# Depth value at 124, 223 pixel: 1212
# Depth value at 124, 223 pixel: 1212
# Depth value at 124, 223 pixel: 1212
# Depth value at 124, 223 pixel: 1212
# Depth value at 124, 223 pixel: 1212
# Depth value at 124, 223 pixel: 1212
# Depth value at 124, 223 pixel: 1212
# Depth value at 124, 223 pixel: 1212
# Depth value at 124, 223 pixel: 1212
# Depth value at 124, 223 pixel: 1212
# Depth value at 124, 223 pixel: 1212
# Depth value at 124, 223 pixel: 1212
# Depth value at 124, 223 pixel: 1212
# Depth value at 124, 223 pixel: 1212
# Depth value at 124, 223 pixel: 1212
# Depth value at 124, 223 pixel: 1212
# Depth value at 124, 223 pixel: 1212
# Depth value at 124, 223 pixel: 1212
# Depth value at 124, 223 pixel: 1212
# Depth value at 124, 223 pixel: 1212
# Depth value at 124, 223 pixel: 1212
# Depth value at 124, 223 pixel: 1212
# Depth value at 124, 223 pixel: 1212
# Depth value at 124, 223 pixel: 1212
# Depth value at 124, 223 pixel: 1212
# Depth value at 124, 223 pixel: 1212
# Depth value at 124, 223 pixel: 1212
# Depth value at 124, 223 pixel: 1212
# Depth value at 124, 223 pixel: 1212
# Depth value at 124, 223 pixel: 1212
# Depth value at 124, 223 pixel: 1212
# Depth value at 124, 223 pixel: 1212
# Depth value at 124, 223 pixel: 1212
# Depth value at 124, 223 pixel: 1212
# Depth value at 124, 223 pixel: 1212
# Depth value at 124, 223 pixel: 1212
# Depth value at 124, 223 pixel: 1212
# Depth value at 124, 223 pixel: 1212
# Depth value at 124, 223 pixel: 1212
# Depth value at 124, 223 pixel: 1212
# Depth value at 124, 223 pixel: 1212
# Depth value at 124, 223 pixel: 1212
# Depth value at 124, 223 pixel: 1212
# Depth value at 124, 223 pixel: 1212
# Depth value at 124, 223 pixel: 1212
# Depth value at 124, 223 pixel: 1212
# Depth value at 124, 223 pixel: 1212
# Depth value at 124, 223 pixel: 1212
# Depth value at 124, 223 pixel: 1212
# Depth value at 124, 223 pixel: 1212
# Depth value at 124, 223 pixel: 1212
# Depth value at 124, 223 pixel: 1212
# Depth value at 124, 223 pixel: 1212
# Depth value at 124, 223 pixel: 1212
# Depth value at 124, 223 pixel: 1212
# Depth value at 124, 223 pixel: 1212
# Depth value at 124, 223 pixel: 1212
# Depth value at 124, 223 pixel: 1212
# Depth value at 124, 223 pixel: 1212
# Depth value at 124, 223 pixel: 1212
# Depth value at 124, 223 pixel: 1212
# Depth value at 124, 223 pixel: 1212
# Depth value at 124, 223 pixel: 1212
# Depth value at 124, 223 pixel: 1212
# Depth value at 124, 223 pixel: 1212
# Depth value at 124, 223 pixel: 1212
# Depth value at 124, 223 pixel: 1212
# Depth value at 124, 223 pixel: 1212
# Depth value at 124, 223 pixel: 1212
# Depth value at 124, 223 pixel: 1212
# Depth value at 124, 223 pixel: 1212
# Depth value at 124, 223 pixel: 1212
# Depth value at 124, 223 pixel: 1212
# Depth value at 124, 223 pixel: 1212
# Depth value at 124, 223 pixel: 1212
# Depth value at 124, 223 pixel: 1212
# Depth value at 124, 223 pixel: 1212
# Depth value at 124, 223 pixel: 1212
# Depth value at 124, 223 pixel: 1212
# Depth value at 124, 223 pixel: 1212
# Depth value at 124, 223 pixel: 1212
# Depth value at 124, 223 pixel: 1212
# Depth value at 124, 223 pixel: 1212
# Depth value at 124, 223 pixel: 1212
# Depth value at 124, 223 pixel: 1212
# Depth value at 124, 223 pixel: 1212
# Depth value at 124, 223 pixel: 1212
# Depth value at 124, 223 pixel: 1212
# Depth value at 124, 223 pixel: 1212
# Depth value at 124, 223 pixel: 1212
# Depth value at 124, 223 pixel: 1212
# Depth value at 124, 223 pixel: 1212
# Depth value at 124, 223 pixel: 1212
# Depth value at 124, 223 pixel: 1212
# Depth value at 124, 223 pixel: 1212
# Depth value at 124, 223 pixel: 1212
# Depth value at 124, 223 pixel: 1212
# Depth value at 124, 223 pixel: 1212
# Depth value at 124, 223 pixel: 1212
# Depth value at 124, 223 pixel: 1212
# Depth value at 124, 223 pixel: 1212
# Depth value at 124, 223 pixel: 1212
# Depth value at 124, 223 pixel: 1212
# Depth value at 124, 223 pixel: 1212
# Depth value at 124, 223 pixel: 1212
# Depth value at 124, 223 pixel: 1212
# Depth value at 124, 223 pixel: 1212
# Depth value at 124, 223 pixel: 1212
# Depth value at 124, 223 pixel: 1212
# Depth value at 124, 223 pixel: 1212
# Depth value at 124, 223 pixel: 1212
# Depth value at 124, 223 pixel: 1212
# Depth value at 124, 223 pixel: 1212
# Depth value at 124, 223 pixel: 1212
# Depth value at 124, 223 pixel: 1212
# Depth value at 124, 223 pixel: 1212
# Depth value at 124, 223 pixel: 1212
# Depth value at 124, 223 pixel: 1212
# Depth value at 124, 223 pixel: 1212
# Depth value at 124, 223 pixel: 1212
# Depth value at 124, 223 pixel: 1212
# Depth value at 124, 223 pixel: 1212
# Depth value at 124, 223 pixel: 1212
# Depth value at 124, 223 pixel: 1212
# Depth value at 124, 223 pixel: 1212
# Depth value at 124, 223 pixel: 1212
# Depth value at 124, 223 pixel: 1212
# Depth value at 124, 223 pixel: 1212
# Depth value at 124, 223 pixel: 1212
# Depth value at 124, 223 pixel: 1212
# Depth value at 124, 223 pixel: 1212
# Depth value at 124, 223 pixel: 1212
# Depth value at 124, 223 pixel: 1212
# Depth value at 124, 223 pixel: 1212
# Depth value at 124, 223 pixel: 1212
# Depth value at 124, 223 pixel: 1212
# Depth value at 124, 223 pixel: 1212
# Depth value at 124, 223 pixel: 1212
# Depth value at 124, 223 pixel: 1212
# Depth value at 124, 223 pixel: 1212
# Depth value at 124, 223 pixel: 1212
# Depth value at 124, 223 pixel: 1212
# Depth value at 124, 223 pixel: 1212
# Depth value at 124, 223 pixel: 1212
# Depth value at 124, 223 pixel: 1212
# Depth value at 124, 223 pixel: 1212
# Depth value at 124, 223 pixel: 1212
# Depth value at 124, 223 pixel: 1212
# Depth value at 124, 223 pixel: 1212
# Depth value at 124, 223 pixel: 1212
# Depth value at 124, 223 pixel: 1212
# Depth value at 124, 223 pixel: 1212
# Depth value at 124, 223 pixel: 1212
# Depth value at 124, 223 pixel: 1212
# Depth value at 124, 223 pixel: 1212
# Depth value at 124, 223 pixel: 1212
# Depth value at 124, 223 pixel: 1212
# Depth value at 124, 223 pixel: 1212
# Depth value at 124, 223 pixel: 1212
# Depth value at 124, 223 pixel: 1212
# Depth value at 124, 223 pixel: 1212
# Depth value at 124, 223 pixel: 1212
# Depth value at 124, 223 pixel: 1212
# Depth value at 124, 223 pixel: 1212
# Depth value at 124, 223 pixel: 1212
# Depth value at 124, 223 pixel: 1212
# Depth value at 124, 223 pixel: 1212
# Depth value at 124, 223 pixel: 1212
# Depth value at 124, 223 pixel: 1212
# Depth value at 124, 223 pixel: 1212
# Depth value at 124, 223 pixel: 1212
# Depth value at 124, 223 pixel: 1212
# Depth value at 124, 223 pixel: 1212
# Depth value at 124, 223 pixel: 1212
# Depth value at 124, 223 pixel: 1212
# Depth value at 124, 223 pixel: 1212
# Depth value at 124, 223 pixel: 1212
# Depth value at 124, 223 pixel: 1212
# Depth value at 124, 223 pixel: 1212
# Depth value at 124, 223 pixel: 1212
# Depth value at 124, 223 pixel: 1212
# Depth value at 124, 223 pixel: 1212
# Depth value at 124, 223 pixel: 1212
# Depth value at 124, 223 pixel: 1212
# Depth value at 124, 223 pixel: 1212
# Depth value at 124, 223 pixel: 1212
# Depth value at 124, 223 pixel: 1212
# Depth value at 124, 223 pixel: 1212
# Depth value at 124, 223 pixel: 1212
# Depth value at 124, 223 pixel: 1212
# Depth value at 124, 223 pixel: 1212
# Depth value at 124, 223 pixel: 1212
# Depth value at 124, 223 pixel: 1212
# Depth value at 124, 223 pixel: 1212
# Depth value at 124, 223 pixel: 1212
# Depth value at 124, 223 pixel: 1212
# Depth value at 124, 223 pixel: 1212
# Depth value at 124, 223 pixel: 1212
# Depth value at 124, 223 pixel: 1212
# Depth value at 124, 223 pixel: 1212
# Depth value at 124, 223 pixel: 1212
# Depth value at 124, 223 pixel: 1212
# Depth value at 124, 223 pixel: 1212
# Depth value at 124, 223 pixel: 1212
# Depth value at 124, 223 pixel: 1212
# Depth value at 124, 223 pixel: 1212
# Depth value at 124, 223 pixel: 1212
# Depth value at 124, 223 pixel: 1212
# Depth value at 124, 223 pixel: 1212
# Depth value at 124, 223 pixel: 1212
# Depth value at 124, 223 pixel: 1212
# Depth value at 58, 411 pixel: 1212
# Depth value at 58, 411 pixel: 1212
# Depth value at 73, 408 pixel: 1314
# Depth value at 74, 397 pixel: 1312
# Depth value at 74, 397 pixel: 1312
# Depth value at 83, 390 pixel: 1184
# Depth value at 83, 390 pixel: 1184
# Depth value at 83, 390 pixel: 1184
# Depth value at 83, 390 pixel: 1184
# Depth value at 116, 392 pixel: 1256
# Depth value at 116, 392 pixel: 1256
# Depth value at 556, 195 pixel: 3010
# Speed: 2.2039999999999997
# Depth value at 556, 195 pixel: 3010
# Speed: 2.2039999999999997
# Depth value at 556, 195 pixel: 2709
# Speed: 2.0835999999999997
# Depth value at 556, 195 pixel: 2685
# Speed: 2.074
# Depth value at 556, 195 pixel: 2745
# Speed: 2.098
# Depth value at 556, 195 pixel: 2745
# Speed: 2.098
# Depth value at 556, 195 pixel: 2757
# Speed: 2.1028000000000002
# Depth value at 556, 195 pixel: 2757
# Speed: 2.1028000000000002
# Depth value at 556, 195 pixel: 2674
# Speed: 2.0696000000000003
# Depth value at 556, 195 pixel: 2674
# Speed: 2.0696000000000003
# Depth value at 556, 195 pixel: 2674
# Speed: 2.0696000000000003
# Depth value at 556, 195 pixel: 2674
# Speed: 2.0696000000000003
# Depth value at 556, 195 pixel: 2674
# Speed: 2.0696000000000003
# Depth value at 556, 195 pixel: 2674
# Speed: 2.0696000000000003
# Depth value at 614, 267 pixel: 2674
# Speed: 2.0696000000000003
# Depth value at 613, 274 pixel: 2674
# Speed: 2.0696000000000003
# Depth value at 629, 282 pixel: 2674
# Speed: 2.0696000000000003
# Depth value at 629, 282 pixel: 2674
# Speed: 2.0696000000000003
# Depth value at 629, 282 pixel: 2674
# Speed: 2.0696000000000003
# Depth value at 629, 282 pixel: 2674
# Speed: 2.0696000000000003
# Depth value at 9, 415 pixel: 2674
# Speed: 2.0696000000000003
# Depth value at 9, 415 pixel: 2674
# Speed: 2.0696000000000003
# Depth value at 9, 415 pixel: 2674
# Speed: 2.0696000000000003
# Depth value at 9, 415 pixel: 2674
# Speed: 2.0696000000000003
# Depth value at 9, 415 pixel: 2674
# Speed: 2.0696000000000003
# Depth value at 9, 415 pixel: 2674
# Speed: 2.0696000000000003
# Depth value at 9, 415 pixel: 2674
# Speed: 2.0696000000000003
# Depth value at 9, 415 pixel: 2674
# Speed: 2.0696000000000003
# Depth value at 9, 415 pixel: 2674
# Speed: 2.0696000000000003
# Depth value at 9, 415 pixel: 2674
# Speed: 2.0696000000000003
# Depth value at 9, 415 pixel: 2674
# Speed: 2.0696000000000003
# Depth value at 9, 415 pixel: 2674
# Speed: 2.0696000000000003
# Depth value at 107, 425 pixel: 2674
# Speed: 2.0696000000000003
# Depth value at 107, 425 pixel: 2819
# Speed: 2.1276
# Depth value at 107, 425 pixel: 2819
# Speed: 2.1276
# Depth value at 107, 425 pixel: 2871
# Speed: 2.1484
# Depth value at 107, 425 pixel: 2871
# Speed: 2.1484
# Depth value at 107, 425 pixel: 2871
# Speed: 2.1484
# Depth value at 107, 425 pixel: 2871
# Speed: 2.1484
# Depth value at 107, 425 pixel: 2871
# Speed: 2.1484
# Depth value at 107, 425 pixel: 2871
# Speed: 2.1484
# Depth value at 107, 425 pixel: 2871
# Speed: 2.1484
# Depth value at 107, 425 pixel: 2871
# Speed: 2.1484
# Depth value at 107, 425 pixel: 2871
# Speed: 2.1484
# Depth value at 107, 425 pixel: 2871
# Speed: 2.1484
# Depth value at 107, 425 pixel: 2871
# Speed: 2.1484
# Depth value at 107, 425 pixel: 2871
# Speed: 2.1484
