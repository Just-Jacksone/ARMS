# %%
import cv2
import json
import trt_pose.coco
import torch
import time
import numpy as np
import pyrealsense2 as rs
from torch2trt import TRTModule
from trt_pose.draw_objects import DrawObjects
from trt_pose.parse_objects import ParseObjects

OPTIMIZED_MODEL = 'pose_detection/resnet18_baseline_att_224x224_A_epoch_249_trt.pth'
HUMAN = 'pose_detection/human_pose.json'

# %%
def preprocess(image):
    mean = torch.Tensor([0.485, 0.456, 0.406]).to(device).view(1, 3, 1, 1)
    std = torch.Tensor([0.229, 0.224, 0.225]).to(device).view(1, 3, 1, 1)
    image = cv2.cvtColor(image, cv2.COLOR_BGR2RGB)
    image = cv2.resize(image, (224, 224))
    image = torch.from_numpy(image).permute(2, 0, 1).unsqueeze(0).float().to(device)
    image = image.div(255.0)
    image = (image - mean) / std
    return image

# Load model and topology
with open(HUMAN, 'r') as f:
    human_pose = json.load(f)
topology = trt_pose.coco.coco_category_to_topology(human_pose)

# Instantiate TensorRT
model_trt = TRTModule()
model_trt.load_state_dict(torch.load(OPTIMIZED_MODEL))

# Doing stuff (tbd)
parse_objects = ParseObjects(topology)
draw_objects = DrawObjects(topology)

device = torch.device('cuda')

# %%
from rover.controls import *
rover = Controls()
# Out:
# Initializing Servos
# Initializing ServoKit
# Done initializing

# %%
from pose_detection.pose_detection import *

WIDTH = 640
HEIGHT = 480
BRAKE_DISTANCE = 1269

# Initialize RealSense camera
pipeline = rs.pipeline()
config = rs.config()
config.enable_stream(rs.stream.color, WIDTH, HEIGHT, rs.format.bgr8, 30)
config.enable_stream(rs.stream.depth, 640, 480, rs.format.z16, 30)
pipeline.start(config)

body = Body()
speed = 0
pose_change = False
prev_pose = "No Pose"
center = [WIDTH/2, HEIGHT/2]
current_angle = 90
started = False

prev_frame_time = time.time()

try:
    while True:
        frames = pipeline.wait_for_frames()
        color_frame = frames.get_color_frame()
        depth_frame = frames.get_depth_frame()

        # Convert depth frame to numpy array
        depth_image = np.asanyarray(depth_frame.get_data())


        if not color_frame or not depth_frame:
            continue

        # Convert images to numpy arrays
        color_image = np.asanyarray(color_frame.get_data())

        # Process the image for pose estimation
        data = preprocess(color_image)
        cmap, paf = model_trt(data)
        cmap, paf = cmap.detach().cpu(), paf.detach().cpu()
        counts, objects, peaks = parse_objects(cmap, paf)
        
        # Classify the pose and display it
        pose_classification, chest_in_frame = classify_pose(peaks, counts, objects, topology, body)
        cv2.putText(color_image, pose_classification, (50, 50), cv2.FONT_HERSHEY_SIMPLEX, 1, (255, 255, 255), 2, cv2.LINE_AA)
        
        if pose_classification == "T-Pose":
            started = True
            speed = 1
            rover.forward(speed)
        elif pose_classification == "S-Pose":
            started = False
            rover.brake()
        
        if started == True:
            # Access depth data (in millimeters)
            depth_value_at_pixel = depth_image[int(body.chest[1]), int(body.chest[0])]  # Example: pixel at center of the frame
            print(f"Depth value at {body.chest[0]}, {body.chest[1]} pixel: {depth_value_at_pixel}")

            if depth_value_at_pixel < BRAKE_DISTANCE:
                rover.brake()
                speed = 1
                continue
            elif chest_in_frame:
                rover.forward(speed)

            x_diff = body.chest[0] - center[0]
            x_diff = (0.28125 * x_diff) + 90
            current_angle = x_diff
            print(current_angle)
            rover.turn(current_angle)

            # TODO: Think about speed being 1 and incrementing by 10
            if pose_classification != prev_pose:
                if pose_classification == "M-Pose" and speed >= 10:
                    speed -= 10
                    rover.forward(speed)
                elif pose_classification == "W-Pose" and speed < MAX_THROTTLE - 10:
                    speed += 10
                    rover.forward(speed)

            prev_chest = body.chest
        
        # Draw poses and display them
        #draw_objects(color_image, counts, objects, peaks)
        draw_keypoints_and_values(color_image, counts, objects, peaks, topology)

        # Calculate FPS and display it
        current_frame_time = time.time()
        fps = (1 / (current_frame_time - prev_frame_time))
        prev_frame_time = current_frame_time
        fps_text = f'FPS: {fps:.0f}'
        cv2.putText(color_image, fps_text, (color_image.shape[1] - 150, color_image.shape[0] - 10), cv2.FONT_HERSHEY_SIMPLEX, 0.5, (255, 255, 255), 2)



        # Display the image
        cv2.imshow('Pose Estimation', color_image)
        if cv2.waitKey(1) & 0xFF == ord('q'):
            break

finally:
    rover.brake()
    pipeline.stop()
    cv2.destroyAllWindows()
# Out:
# Speeding up to 31
#
# Depth value at 337, 277 pixel: 1400
# Speeding up to 31
#
# 94.78125
# Speeding up to 31
#
# Depth value at 339, 277 pixel: 1400
# Speeding up to 31
#
# 95.34375
# Speeding up to 31
#
# Depth value at 339, 277 pixel: 1400
# Speeding up to 31
#
# 95.34375
# Depth value at 340, 278 pixel: 1397
# Speeding up to 31
#
# 95.625
# Depth value at 342, 277 pixel: 1400
# Speeding up to 31
#
# 96.1875
# Depth value at 343, 278 pixel: 1400
# Speeding up to 31
#
# 96.46875
# Depth value at 342, 277 pixel: 1403
# Speeding up to 31
#
# 96.1875
# Depth value at 341, 277 pixel: 1400
# Speeding up to 31
#
# 95.90625
# Depth value at 341, 277 pixel: 1397
# Speeding up to 31
#
# 95.90625
# Depth value at 341, 277 pixel: 1397
# Speeding up to 31
#
# 95.90625
# Depth value at 341, 277 pixel: 1400
# Speeding up to 31
#
# 95.90625
# Depth value at 342, 277 pixel: 1400
# Speeding up to 31
#
# 96.1875
# Depth value at 341, 277 pixel: 1400
# Speeding up to 31
#
# 95.90625
# Depth value at 341, 277 pixel: 1400
# Speeding up to 31
#
# 95.90625
# Depth value at 341, 276 pixel: 1410
# Speeding up to 31
#
# 95.90625
# Depth value at 342, 276 pixel: 1410
# Speeding up to 31
#
# 96.1875
# Depth value at 344, 281 pixel: 1403
# Speeding up to 31
#
# 96.75
# Depth value at 344, 281 pixel: 1413
# 96.75
# Depth value at 341, 284 pixel: 1400
# Speeding up to 31
#
# 95.90625
# Depth value at 341, 284 pixel: 1406
# Speeding up to 31
#
# 95.90625
# Depth value at 341, 285 pixel: 1406
# Speeding up to 31
#
# 95.90625
# Depth value at 340, 285 pixel: 1416
# Speeding up to 31
#
# 95.625
# Depth value at 341, 285 pixel: 1416
# Speeding up to 31
#
# 95.90625
# Depth value at 341, 285 pixel: 1416
# Speeding up to 31
#
# 95.90625
# Depth value at 341, 285 pixel: 1416
# Speeding up to 31
#
# 95.90625
# Depth value at 342, 285 pixel: 1416
# Speeding up to 31
#
# 96.1875
# Depth value at 342, 285 pixel: 1406
# 96.1875
# Depth value at 343, 286 pixel: 1403
# Speeding up to 31
#
# 96.46875
# Depth value at 344, 286 pixel: 1403
# Speeding up to 31
#
# 96.75
# Depth value at 345, 286 pixel: 1403
# Speeding up to 31
#
# 97.03125
# Depth value at 347, 285 pixel: 1400
# Speeding up to 31
#
# 97.59375
# Depth value at 350, 284 pixel: 1400
# Speeding up to 31
#
# 98.4375
# Depth value at 355, 284 pixel: 1400
# Speeding up to 31
#
# 99.84375
# Depth value at 362, 284 pixel: 1391
# Speeding up to 31
#
# 101.8125
# Depth value at 368, 287 pixel: 1388
# Speeding up to 31
#
# 103.5
# Depth value at 376, 291 pixel: 1378
# Speeding up to 31
#
# 105.75
# Depth value at 383, 292 pixel: 1369
# Speeding up to 31
#
# 107.71875
# Depth value at 389, 292 pixel: 1354
# Speeding up to 31
#
# 109.40625
# Depth value at 392, 293 pixel: 1328
# Speeding up to 31
#
# 110.25
# Depth value at 392, 293 pixel: 1328
# 110.25
# Depth value at 392, 293 pixel: 1303
# 110.25
# Depth value at 392, 293 pixel: 1285
# 110.25
# Depth value at 392, 293 pixel: 1256
# Braking
#
# Depth value at 392, 293 pixel: 1256
# Braking
#
# Depth value at 392, 293 pixel: 1214
# Braking
#
# Depth value at 392, 293 pixel: 1214
# Braking
#
# Depth value at 392, 293 pixel: 1171
# Braking
#
# Depth value at 392, 293 pixel: 1119
# Braking
#
# Depth value at 392, 293 pixel: 1119
# Braking
#
# Depth value at 392, 293 pixel: 1061
# Braking
#
# Depth value at 392, 293 pixel: 978
# Braking
#
# Depth value at 392, 293 pixel: 978
# Braking
#
# Depth value at 392, 293 pixel: 951
# Braking
#
# Depth value at 392, 293 pixel: 922
# Braking
#
# Depth value at 392, 293 pixel: 893
# Braking
#
# Depth value at 392, 293 pixel: 855
# Braking
#
# Depth value at 392, 293 pixel: 855
# Braking
#
# Depth value at 392, 293 pixel: 826
# Braking
#
# Depth value at 392, 293 pixel: 802
# Braking
#
# Depth value at 392, 293 pixel: 802
# Braking
#
# Depth value at 392, 293 pixel: 779
# Braking
#
# Depth value at 392, 293 pixel: 766
# Braking
#
# Depth value at 392, 293 pixel: 755
# Braking
#
# Depth value at 392, 293 pixel: 755
# Braking
#
# Depth value at 392, 293 pixel: 747
# Braking
#
# Depth value at 392, 293 pixel: 747
# Braking
#
# Depth value at 392, 293 pixel: 749
# Braking
#
# Depth value at 392, 293 pixel: 749
# Braking
#
# Depth value at 392, 293 pixel: 746
# Braking
#
# Depth value at 392, 293 pixel: 745
# Braking
#
# Depth value at 392, 293 pixel: 747
# Braking
#
# Depth value at 392, 293 pixel: 748
# Braking
#
# Depth value at 392, 293 pixel: 748
# Braking
#
# Depth value at 392, 293 pixel: 749
# Braking
#
# Depth value at 392, 293 pixel: 746
# Braking
#
# Depth value at 392, 293 pixel: 746
# Braking
#
# Depth value at 392, 293 pixel: 746
# Braking
#
# Depth value at 392, 293 pixel: 747
# Braking
#
# Depth value at 392, 293 pixel: 747
# Braking
#
# Depth value at 392, 293 pixel: 745
# Braking
#
# Depth value at 392, 293 pixel: 743
# Braking
#
# Depth value at 392, 293 pixel: 744
# Braking
#
# Depth value at 392, 293 pixel: 744
# Braking
#
# Depth value at 392, 293 pixel: 744
# Braking
#
# Depth value at 392, 293 pixel: 744
# Braking
#
# Depth value at 392, 293 pixel: 744
# Braking
#
# Depth value at 392, 293 pixel: 742
# Braking
#
# Depth value at 392, 293 pixel: 742
# Braking
#
# Depth value at 392, 293 pixel: 741
# Braking
#
# Depth value at 392, 293 pixel: 741
# Braking
#
# Depth value at 392, 293 pixel: 741
# Braking
#
# Depth value at 392, 293 pixel: 743
# Braking
#
# Depth value at 392, 293 pixel: 745
# Braking
#
# Depth value at 392, 293 pixel: 745
# Braking
#
# Depth value at 392, 293 pixel: 744
# Braking
#
# Depth value at 392, 293 pixel: 744
# Braking
#
# Depth value at 392, 293 pixel: 744
# Braking
#
# Depth value at 392, 293 pixel: 745
# Braking
#
# Depth value at 392, 293 pixel: 745
# Braking
#
# Depth value at 392, 293 pixel: 745
# Braking
#
# Depth value at 392, 293 pixel: 744
# Braking
#
# Depth value at 392, 293 pixel: 743
# Braking
#
# Depth value at 392, 293 pixel: 743
# Braking
#
# Depth value at 392, 293 pixel: 744
# Braking
#
# Depth value at 392, 293 pixel: 744
# Braking
#
# Depth value at 392, 293 pixel: 745
# Braking
#
# Depth value at 392, 293 pixel: 744
# Braking
#
# Depth value at 392, 293 pixel: 745
# Braking
#
# Depth value at 392, 293 pixel: 745
# Braking
#
# Depth value at 392, 293 pixel: 746
# Braking
#
# Depth value at 392, 293 pixel: 745
# Braking
#
# Depth value at 392, 293 pixel: 745
# Braking
#
# Depth value at 392, 293 pixel: 743
# Braking
#
# Depth value at 392, 293 pixel: 745
# Braking
#
# Depth value at 392, 293 pixel: 745
# Braking
#
# Depth value at 392, 293 pixel: 743
# Braking
#
# Depth value at 392, 293 pixel: 747
# Braking
#
# Depth value at 392, 293 pixel: 747
# Braking
#
# Depth value at 392, 293 pixel: 746
# Braking
#
# Depth value at 392, 293 pixel: 759
# Braking
#
# Depth value at 392, 293 pixel: 759
# Braking
#
# Depth value at 392, 293 pixel: 776
# Braking
#
# Depth value at 392, 293 pixel: 802
# Braking
#
# Depth value at 392, 293 pixel: 802
# Braking
#
# Depth value at 392, 293 pixel: 823
# Braking
#
# Depth value at 392, 293 pixel: 823
# Braking
#
# Depth value at 392, 293 pixel: 837
# Braking
#
# Depth value at 392, 293 pixel: 861
# Braking
#
# Depth value at 392, 293 pixel: 861
# Braking
#
# Depth value at 392, 293 pixel: 886
# Braking
#
# Depth value at 392, 293 pixel: 918
# Braking
#
# Depth value at 392, 293 pixel: 918
# Braking
#
# Depth value at 392, 293 pixel: 967
# Braking
#
# Depth value at 392, 293 pixel: 1025
# Braking
#
# Depth value at 392, 293 pixel: 1025
# Braking
#
# Depth value at 392, 293 pixel: 1078
# Braking
#
# Depth value at 392, 293 pixel: 1133
# Braking
#
# Depth value at 392, 293 pixel: 1180
# Braking
#
# Depth value at 392, 293 pixel: 1180
# Braking
#
# Depth value at 392, 293 pixel: 1217
# Braking
#
# Depth value at 392, 293 pixel: 1217
# Braking
#
# Depth value at 392, 293 pixel: 1254
# Braking
#
# Depth value at 370, 293 pixel: 1254
# Braking
#
# Depth value at 373, 291 pixel: 1266
# Braking
#
# Depth value at 375, 290 pixel: 1301
# Speeding up to 31
#
# 105.46875
# Depth value at 376, 291 pixel: 1328
# Speeding up to 31
#
# 105.75
# Depth value at 373, 290 pixel: 1357
# Speeding up to 31
#
# 104.90625
# Depth value at 368, 291 pixel: 1372
# Speeding up to 31
#
# 103.5
# Depth value at 363, 291 pixel: 1372
# Speeding up to 31
#
# 102.09375
# Depth value at 363, 291 pixel: 1378
# 102.09375
# Depth value at 346, 288 pixel: 1375
# Speeding up to 31
#
# 97.3125
# Depth value at 343, 292 pixel: 1375
# Speeding up to 31
#
# 96.46875
# Depth value at 340, 290 pixel: 1375
# Speeding up to 31
#
# 95.625
# Depth value at 338, 291 pixel: 1375
# Speeding up to 31
#
# 95.0625
# Depth value at 336, 292 pixel: 1381
# Speeding up to 31
#
# 94.5
# Depth value at 335, 291 pixel: 1388
# Speeding up to 31
#
# 94.21875
# Depth value at 333, 289 pixel: 1397
# Speeding up to 31
#
# 93.65625
# Depth value at 332, 290 pixel: 1394
# Speeding up to 31
#
# 93.375
# Depth value at 330, 290 pixel: 1394
# Speeding up to 31
#
# 92.8125
# Depth value at 327, 289 pixel: 1394
# Speeding up to 31
#
# 91.96875
# Depth value at 326, 290 pixel: 1391
# Speeding up to 31
#
# 91.6875
# Depth value at 325, 291 pixel: 1388
# Speeding up to 31
#
# 91.40625
# Depth value at 324, 290 pixel: 1391
# Speeding up to 31
#
# 91.125
# Depth value at 323, 291 pixel: 1391
# Speeding up to 31
#
# 90.84375
# Depth value at 323, 292 pixel: 1400
# Speeding up to 31
#
# 90.84375
# Depth value at 322, 292 pixel: 1394
# Speeding up to 31
#
# 90.5625
# Depth value at 322, 291 pixel: 1397
# Speeding up to 31
#
# 90.5625
# Depth value at 323, 292 pixel: 1394
# Speeding up to 31
#
# 90.84375
# Depth value at 323, 292 pixel: 1394
# Speeding up to 31
#
# 90.84375
# Depth value at 323, 291 pixel: 1397
# Speeding up to 31
#
# 90.84375
# Depth value at 324, 291 pixel: 1397
# Speeding up to 31
#
# 91.125
# Depth value at 324, 291 pixel: 1394
# Speeding up to 31
#
# 91.125
# Depth value at 325, 291 pixel: 1394
# Speeding up to 31
#
# 91.40625
# Depth value at 326, 289 pixel: 1394
# Speeding up to 31
#
# 91.6875
# Depth value at 328, 289 pixel: 1394
# Speeding up to 31
#
# 92.25
# Depth value at 332, 290 pixel: 1388
# Speeding up to 31
#
# 93.375
# Depth value at 336, 290 pixel: 1381
# Speeding up to 31
#
# 94.5
# Depth value at 341, 290 pixel: 1375
# Speeding up to 31
#
# 95.90625
# Depth value at 347, 293 pixel: 1375
# Speeding up to 31
#
# 97.59375
# Depth value at 350, 293 pixel: 1372
# Speeding up to 31
#
# 98.4375
# Depth value at 358, 292 pixel: 1366
# Speeding up to 31
#
# 100.6875
# Depth value at 361, 290 pixel: 1326
# Speeding up to 31
#
# 101.53125
# Depth value at 364, 292 pixel: 1301
# Speeding up to 31
#
# 102.375
# Depth value at 366, 296 pixel: 1282
# Speeding up to 31
#
# 102.9375
# Depth value at 366, 296 pixel: 1241
# Braking
#
# Depth value at 366, 296 pixel: 1241
# Braking
#
# Depth value at 366, 296 pixel: 1205
# Braking
#
# Depth value at 366, 296 pixel: 1149
# Braking
#
# Depth value at 366, 296 pixel: 1095
# Braking
#
# Depth value at 366, 296 pixel: 1095
# Braking
#
# Depth value at 366, 296 pixel: 1033
# Braking
#
# Depth value at 366, 296 pixel: 969
# Braking
#
# Depth value at 366, 296 pixel: 969
# Braking
#
# Depth value at 366, 296 pixel: 916
# Braking
#
# Depth value at 366, 296 pixel: 877
# Braking
#
# Depth value at 366, 296 pixel: 845
# Braking
#
# Depth value at 366, 296 pixel: 845
# Braking
#
# Depth value at 366, 296 pixel: 832
# Braking
#
# Depth value at 366, 296 pixel: 820
# Braking
#
# Depth value at 366, 296 pixel: 825
# Braking
#
# Depth value at 366, 296 pixel: 825
# Braking
#
# Depth value at 366, 296 pixel: 841
# Braking
#
# Depth value at 366, 296 pixel: 871
# Braking
#
# Depth value at 366, 296 pixel: 907
# Braking
#
# Depth value at 366, 296 pixel: 944
# Braking
#
# Depth value at 366, 296 pixel: 984
# Braking
#
# Depth value at 366, 296 pixel: 1023
# Braking
#
# Depth value at 366, 296 pixel: 1023
# Braking
#
# Depth value at 366, 296 pixel: 1070
# Braking
#
# Depth value at 366, 296 pixel: 1093
# Braking
#
# Depth value at 366, 296 pixel: 1093
# Braking
#
# Depth value at 366, 296 pixel: 1137
# Braking
#
# Depth value at 366, 296 pixel: 1165
# Braking
#
# Depth value at 366, 296 pixel: 1165
# Braking
#
# Depth value at 366, 296 pixel: 1191
# Braking
#
# Depth value at 385, 286 pixel: 1226
# Braking
#
# Depth value at 384, 286 pixel: 1254
# Braking
#
# Depth value at 382, 286 pixel: 1274
# Speeding up to 31
#
# 107.4375
# Depth value at 379, 286 pixel: 1298
# Speeding up to 31
#
# 106.59375
# Depth value at 376, 286 pixel: 1303
# Speeding up to 31
#
# 105.75
# Depth value at 368, 286 pixel: 1331
# Speeding up to 31
#
# 103.5
# Depth value at 366, 287 pixel: 1331
# Speeding up to 31
#
# 102.9375
# Depth value at 358, 286 pixel: 1384
# Speeding up to 31
#
# 100.6875
# Depth value at 350, 288 pixel: 1391
# Speeding up to 31
#
# 98.4375
# Depth value at 350, 288 pixel: 1406
# 98.4375
# Depth value at 342, 287 pixel: 1413
# Speeding up to 31
#
# 96.1875
# Depth value at 342, 287 pixel: 1426
# Speeding up to 31
#
# 96.1875
# Depth value at 342, 288 pixel: 1442
# Speeding up to 31
#
# 96.1875
# Depth value at 344, 286 pixel: 1456
# Speeding up to 31
#
# 96.75
# Depth value at 344, 286 pixel: 1459
# 96.75
# Depth value at 349, 286 pixel: 1462
# Speeding up to 31
#
# 98.15625
# Depth value at 351, 285 pixel: 1473
# Speeding up to 31
#
# 98.71875
# Depth value at 354, 286 pixel: 1476
# Speeding up to 31
#
# 99.5625
# Depth value at 357, 287 pixel: 1466
# Speeding up to 31
#
# 100.40625
# Depth value at 360, 287 pixel: 1466
# Speeding up to 31
#
# 101.25
# Depth value at 362, 288 pixel: 1473
# Speeding up to 31
#
# 101.8125
# Depth value at 364, 288 pixel: 1462
# Speeding up to 31
#
# 102.375
# Depth value at 367, 288 pixel: 1456
# Speeding up to 31
#
# 103.21875
# Depth value at 370, 288 pixel: 1446
# Speeding up to 31
#
# 104.0625
# Depth value at 372, 289 pixel: 1436
# Speeding up to 31
#
# 104.625
# Depth value at 373, 288 pixel: 1442
# Speeding up to 31
#
# 104.90625
# Depth value at 374, 287 pixel: 1422
# Speeding up to 31
#
# 105.1875
# Depth value at 375, 288 pixel: 1406
# Speeding up to 31
#
# 105.46875
# Depth value at 375, 288 pixel: 1397
# Speeding up to 31
#
# 105.46875
# Depth value at 374, 287 pixel: 1403
# Speeding up to 31
#
# 105.1875
# Depth value at 373, 288 pixel: 1400
# Speeding up to 31
#
# 104.90625
# Depth value at 373, 288 pixel: 1384
# Speeding up to 31
#
# 104.90625
# Depth value at 371, 289 pixel: 1378
# Speeding up to 31
#
# 104.34375
# Depth value at 368, 289 pixel: 1363
# Speeding up to 31
#
# 103.5
# Depth value at 367, 289 pixel: 1369
# Speeding up to 31
#
# 103.21875
# Depth value at 364, 288 pixel: 1360
# Speeding up to 31
#
# 102.375
# Depth value at 362, 287 pixel: 1357
# Speeding up to 31
#
# 101.8125
# Depth value at 357, 287 pixel: 1340
# Speeding up to 31
#
# 100.40625
# Depth value at 353, 287 pixel: 1328
# Speeding up to 31
#
# 99.28125
# Depth value at 347, 289 pixel: 1314
# Speeding up to 31
#
# 97.59375
# Depth value at 343, 290 pixel: 1303
# Speeding up to 31
#
# 96.46875
# Depth value at 341, 293 pixel: 1301
# Speeding up to 31
#
# 95.90625
# Depth value at 338, 293 pixel: 1298
# Speeding up to 31
#
# 95.0625
# Depth value at 338, 293 pixel: 1290
# 95.0625
# Depth value at 337, 291 pixel: 1293
# Speeding up to 31
#
# 94.78125
# Depth value at 337, 291 pixel: 1293
# 94.78125
# Depth value at 337, 291 pixel: 1287
# 94.78125
# Depth value at 337, 291 pixel: 1282
# 94.78125
# Depth value at 337, 291 pixel: 1269
# 94.78125
# Depth value at 337, 291 pixel: 1251
# Braking
#
# Depth value at 337, 291 pixel: 1251
# Braking
#
# Depth value at 337, 291 pixel: 1236
# Braking
#
# Depth value at 337, 291 pixel: 1224
# Braking
#
# Depth value at 337, 291 pixel: 1224
# Braking
#
# Depth value at 337, 291 pixel: 1217
# Braking
#
# Depth value at 337, 291 pixel: 1212
# Braking
#
# Depth value at 337, 291 pixel: 1198
# Braking
#
# Depth value at 337, 291 pixel: 1196
# Braking
#
# Depth value at 337, 291 pixel: 1196
# Braking
#
# Depth value at 337, 291 pixel: 1189
# Braking
#
# Depth value at 337, 291 pixel: 1182
# Braking
#
# Depth value at 337, 291 pixel: 1187
# Braking
#
# Depth value at 337, 291 pixel: 1187
# Braking
#
# Depth value at 337, 291 pixel: 1173
# Braking
#
# Depth value at 337, 291 pixel: 1167
# Braking
#
# Depth value at 337, 291 pixel: 1154
# Braking
#
# Depth value at 337, 291 pixel: 1154
# Braking
#
# Depth value at 337, 291 pixel: 1152
# Braking
#
# Depth value at 337, 291 pixel: 1149
# Braking
#
# Depth value at 337, 291 pixel: 1145
# Braking
#
# Depth value at 337, 291 pixel: 1139
# Braking
#
# Depth value at 337, 291 pixel: 1139
# Braking
#
# Depth value at 337, 291 pixel: 1131
# Braking
#
# Depth value at 337, 291 pixel: 1125
# Braking
#
# Depth value at 337, 291 pixel: 1119
# Braking
#
# Depth value at 337, 291 pixel: 1107
# Braking
#
# Depth value at 337, 291 pixel: 1101
# Braking
#
# Depth value at 337, 291 pixel: 1101
# Braking
#
# Depth value at 337, 291 pixel: 1091
# Braking
#
# Depth value at 337, 291 pixel: 1089
# Braking
#
# Depth value at 337, 291 pixel: 1084
# Braking
#
# Depth value at 337, 291 pixel: 1082
# Braking
#
# Depth value at 337, 291 pixel: 1082
# Braking
#
# Depth value at 337, 291 pixel: 1084
# Braking
#
# Depth value at 337, 291 pixel: 1082
# Braking
#
# Depth value at 337, 291 pixel: 1082
# Braking
#
# Depth value at 337, 291 pixel: 1084
# Braking
#
# Depth value at 337, 291 pixel: 1084
# Braking
#
# Depth value at 337, 291 pixel: 1087
# Braking
#
# Depth value at 337, 291 pixel: 1093
# Braking
#
# Depth value at 337, 291 pixel: 1093
# Braking
#
# Depth value at 337, 291 pixel: 1095
# Braking
#
# Depth value at 337, 291 pixel: 1097
# Braking
#
# Depth value at 337, 291 pixel: 1097
# Braking
#
# Depth value at 337, 291 pixel: 1097
# Braking
#
# Depth value at 337, 291 pixel: 1095
# Braking
#
# Depth value at 337, 291 pixel: 1095
# Braking
#
# Depth value at 337, 291 pixel: 1093
# Braking
#
# Depth value at 337, 291 pixel: 1089
# Braking
#
# Depth value at 337, 291 pixel: 1089
# Braking
#
# Depth value at 337, 291 pixel: 1089
# Braking
#
# Depth value at 337, 291 pixel: 1087
# Braking
#
# Depth value at 337, 291 pixel: 1087
# Braking
#
# Depth value at 337, 291 pixel: 1085
# Braking
#
# Depth value at 337, 291 pixel: 1085
# Braking
#
# Depth value at 337, 291 pixel: 1084
# Braking
#
# Depth value at 337, 291 pixel: 1078
# Braking
#
# Depth value at 337, 291 pixel: 1078
# Braking
#
# Depth value at 337, 291 pixel: 1070
# Braking
#
# Depth value at 337, 291 pixel: 1061
# Braking
#
# Depth value at 337, 291 pixel: 1047
# Braking
#
# Depth value at 337, 291 pixel: 1047
# Braking
#
# Depth value at 337, 291 pixel: 1028
# Braking
#
# Depth value at 337, 291 pixel: 1028
# Braking
#
# Depth value at 337, 291 pixel: 1018
# Braking
#
# Depth value at 337, 291 pixel: 1006
# Braking
#
# Depth value at 337, 291 pixel: 1006
# Braking
#
# Depth value at 337, 291 pixel: 990
# Braking
#
# Depth value at 337, 291 pixel: 970
# Braking
#
# Depth value at 337, 291 pixel: 950
# Braking
#
# Depth value at 337, 291 pixel: 950
# Braking
#
# Depth value at 337, 291 pixel: 926
# Braking
#
# Depth value at 337, 291 pixel: 891
# Braking
#
# Depth value at 337, 291 pixel: 858
# Braking
#
# Depth value at 337, 291 pixel: 858
# Braking
#
# Depth value at 337, 291 pixel: 830
# Braking
#
# Depth value at 337, 291 pixel: 807
# Braking
#
# Depth value at 337, 291 pixel: 807
# Braking
#
# Depth value at 337, 291 pixel: 785
# Braking
#
# Depth value at 337, 291 pixel: 766
# Braking
#
# Depth value at 337, 291 pixel: 743
# Braking
#
# Depth value at 337, 291 pixel: 743
# Braking
#
# Depth value at 337, 291 pixel: 723
# Braking
#
# Depth value at 337, 291 pixel: 711
# Braking
#
# Depth value at 337, 291 pixel: 699
# Braking
#
# Depth value at 337, 291 pixel: 699
# Braking
#
# Depth value at 337, 291 pixel: 679
# Braking
#
# Depth value at 337, 291 pixel: 635
# Braking
#
# Depth value at 337, 291 pixel: 635
# Braking
#
# Depth value at 337, 291 pixel: 566
# Braking
#
# Depth value at 337, 291 pixel: 503
# Braking
#
# Depth value at 337, 291 pixel: 490
# Braking
#
# Depth value at 337, 291 pixel: 464
# Braking
#
# Depth value at 337, 291 pixel: 464
# Braking
#
# Depth value at 337, 291 pixel: 441
# Braking
#
# Depth value at 337, 291 pixel: 424
# Braking
#
# Depth value at 337, 291 pixel: 424
# Braking
#
# Depth value at 337, 291 pixel: 414
# Braking
#
# Depth value at 337, 291 pixel: 402
# Braking
#
# Depth value at 337, 291 pixel: 402
# Braking
#
# Depth value at 337, 291 pixel: 391
# Braking
#
# Depth value at 337, 291 pixel: 0
# Braking
#
# Depth value at 337, 291 pixel: 379
# Braking
#
# Depth value at 337, 291 pixel: 379
# Braking
#
# Depth value at 337, 291 pixel: 373
# Braking
#
# Depth value at 337, 291 pixel: 372
# Braking
#
# Depth value at 337, 291 pixel: 372
# Braking
#
# Depth value at 337, 291 pixel: 368
# Braking
#
# Depth value at 337, 291 pixel: 364
# Braking
#
# Depth value at 337, 291 pixel: 364
# Braking
#
# Depth value at 337, 291 pixel: 362
# Braking
#
# Depth value at 337, 291 pixel: 0
# Braking
#
# Depth value at 337, 291 pixel: 0
# Braking
#
# Depth value at 337, 291 pixel: 354
# Braking
#
# Depth value at 337, 291 pixel: 353
# Braking
#
# Depth value at 337, 291 pixel: 353
# Braking
#
# Depth value at 337, 291 pixel: 349
# Braking
#
# Depth value at 337, 291 pixel: 349
# Braking
#
# Depth value at 337, 291 pixel: 347
# Braking
#
# Depth value at 337, 291 pixel: 343
# Braking
#
# Depth value at 337, 291 pixel: 343
# Braking
#
# Depth value at 337, 291 pixel: 341
# Braking
#
# Depth value at 337, 291 pixel: 341
# Braking
#
# Depth value at 337, 291 pixel: 342
# Braking
#
# Depth value at 337, 291 pixel: 339
# Braking
#
# Depth value at 337, 291 pixel: 339
# Braking
#
# Depth value at 337, 291 pixel: 338
# Braking
#
# Depth value at 337, 291 pixel: 338
# Braking
#
# Depth value at 337, 291 pixel: 338
# Braking
#
# Depth value at 337, 291 pixel: 339
# Braking
#
# Depth value at 337, 291 pixel: 0
# Braking
#
# Depth value at 337, 291 pixel: 0
# Braking
#
# Depth value at 337, 291 pixel: 340
# Braking
#
# Depth value at 337, 291 pixel: 341
# Braking
#
# Depth value at 337, 291 pixel: 342
# Braking
#
# Depth value at 337, 291 pixel: 342
# Braking
#
# Depth value at 337, 291 pixel: 343
# Braking
#
# Depth value at 337, 291 pixel: 343
# Braking
#
# Depth value at 337, 291 pixel: 343
# Braking
#
# Depth value at 337, 291 pixel: 343
# Braking
#
# Depth value at 337, 291 pixel: 0
# Braking
#
# Depth value at 337, 291 pixel: 0
# Braking
#
# Depth value at 337, 291 pixel: 0
# Braking
#
# Depth value at 337, 291 pixel: 0
# Braking
#
# Depth value at 337, 291 pixel: 0
# Braking
#
# Depth value at 337, 291 pixel: 0
# Braking
#
# Depth value at 337, 291 pixel: 345
# Braking
#
# Depth value at 337, 291 pixel: 0
# Braking
#
# Depth value at 337, 291 pixel: 0
# Braking
#
# Depth value at 337, 291 pixel: 347
# Braking
#
# Depth value at 337, 291 pixel: 347
# Braking
#
# Depth value at 337, 291 pixel: 347
# Braking
#
# Depth value at 337, 291 pixel: 347
# Braking
#
# Depth value at 337, 291 pixel: 348
# Braking
#
# Depth value at 337, 291 pixel: 348
# Braking
#
# Depth value at 337, 291 pixel: 348
# Braking
#
# Depth value at 337, 291 pixel: 349
# Braking
#
# Depth value at 337, 291 pixel: 349
# Braking
#
# Depth value at 337, 291 pixel: 0
# Braking
#
# Depth value at 337, 291 pixel: 0
# Braking
#
# Depth value at 337, 291 pixel: 0
# Braking
#
# Depth value at 337, 291 pixel: 0
# Braking
#
# Depth value at 337, 291 pixel: 296
# Braking
#
# Depth value at 337, 291 pixel: 298
# Braking
#
# Depth value at 337, 291 pixel: 0
# Braking
#
# Depth value at 337, 291 pixel: 0
# Braking
#
# Depth value at 337, 291 pixel: 0
# Braking
#
# Depth value at 337, 291 pixel: 353
# Braking
#
# Depth value at 337, 291 pixel: 353
# Braking
#
# Depth value at 337, 291 pixel: 354
# Braking
#
# Depth value at 337, 291 pixel: 354
# Braking
#
# Depth value at 337, 291 pixel: 354
# Braking
#
# Depth value at 337, 291 pixel: 354
# Braking
#
# Depth value at 337, 291 pixel: 355
# Braking
#
# Depth value at 337, 291 pixel: 355
# Braking
#
# Depth value at 337, 291 pixel: 0
# Braking
#
# Depth value at 337, 291 pixel: 0
# Braking
#
# Depth value at 337, 291 pixel: 0
# Braking
#
# Depth value at 337, 291 pixel: 0
# Braking
#
# Depth value at 337, 291 pixel: 0
# Braking
#
# Depth value at 337, 291 pixel: 0
# Braking
#
# Depth value at 337, 291 pixel: 0
# Braking
#
# Depth value at 337, 291 pixel: 361
# Braking
#
# Depth value at 337, 291 pixel: 361
# Braking
#
# Depth value at 337, 291 pixel: 369
# Braking
#
# Depth value at 337, 291 pixel: 369
# Braking
#
# Depth value at 337, 291 pixel: 384
# Braking
#
# Depth value at 337, 291 pixel: 384
# Braking
#
# Depth value at 337, 291 pixel: 402
# Braking
#
# Depth value at 337, 291 pixel: 414
# Braking
#
# Depth value at 337, 291 pixel: 414
# Braking
#
# Depth value at 337, 291 pixel: 436
# Braking
#
# Depth value at 337, 291 pixel: 468
# Braking
#
# Depth value at 337, 291 pixel: 468
# Braking
#
# Depth value at 337, 291 pixel: 504
# Braking
#
# Depth value at 337, 291 pixel: 504
# Braking
#
# Depth value at 337, 291 pixel: 561
# Braking
#
# Depth value at 337, 291 pixel: 0
# Braking
#
# Depth value at 337, 291 pixel: 0
# Braking
#
# Depth value at 337, 291 pixel: 511
# Braking
#
# Depth value at 337, 291 pixel: 743
# Braking
#
# Depth value at 337, 291 pixel: 743
# Braking
#
# Depth value at 337, 291 pixel: 831
# Braking
#
# Depth value at 337, 291 pixel: 944
# Braking
#
# Depth value at 337, 291 pixel: 944
# Braking
#
# Depth value at 337, 291 pixel: 1058
# Braking
#
# Depth value at 364, 281 pixel: 1105
# Braking
#
# Depth value at 362, 269 pixel: 1119
# Braking
#
# Depth value at 361, 264 pixel: 1154
# Braking
#
# Depth value at 361, 264 pixel: 1189
# Braking
#
# Depth value at 361, 264 pixel: 1189
# Braking
#
# Depth value at 361, 264 pixel: 1274
# 101.53125
# Depth value at 361, 264 pixel: 1384
# 101.53125
# Depth value at 361, 264 pixel: 1397
# 101.53125
# Depth value at 355, 285 pixel: 1381
# Speeding up to 31
#
# 99.84375
# Depth value at 355, 284 pixel: 1397
# Speeding up to 31
#
# 99.84375
# Depth value at 353, 285 pixel: 1422
# Speeding up to 31
#
# 99.28125
# Depth value at 352, 285 pixel: 1456
# Speeding up to 31
#
# 99.0
# Depth value at 352, 285 pixel: 1473
# Speeding up to 31
#
# 99.0
# Depth value at 352, 284 pixel: 1483
# Speeding up to 31
#
# 99.0
# Depth value at 352, 284 pixel: 1494
# Speeding up to 31
#
# 99.0
# Depth value at 352, 285 pixel: 1498
# Speeding up to 31
#
# 99.0
# Depth value at 352, 285 pixel: 1498
# Speeding up to 31
#
# 99.0
# Depth value at 352, 285 pixel: 1498
# Speeding up to 31
#
# 99.0
# Depth value at 353, 285 pixel: 1498
# Speeding up to 31
#
# 99.28125
# Depth value at 353, 285 pixel: 1501
# Speeding up to 31
#
# 99.28125
# Depth value at 354, 285 pixel: 1501
# Speeding up to 31
#
# 99.5625
# Depth value at 355, 284 pixel: 1501
# Speeding up to 31
#
# 99.84375
# Depth value at 356, 285 pixel: 1498
# Speeding up to 31
#
# 100.125
# Depth value at 357, 285 pixel: 1498
# Speeding up to 31
#
# 100.40625
# Depth value at 357, 285 pixel: 1501
# Speeding up to 31
#
# 100.40625
# Depth value at 357, 285 pixel: 1498
# Speeding up to 31
#
# 100.40625
# Depth value at 357, 285 pixel: 1494
# Speeding up to 31
#
# 100.40625
# Depth value at 358, 285 pixel: 1490
# Speeding up to 31
#
# 100.6875
# Depth value at 358, 286 pixel: 1494
# Speeding up to 31
#
# 100.6875
# Depth value at 358, 285 pixel: 1490
# Speeding up to 31
#
# 100.6875
# Depth value at 359, 285 pixel: 1494
# Speeding up to 31
#
# 100.96875
# Depth value at 359, 285 pixel: 1494
# Speeding up to 31
#
# 100.96875
# Depth value at 359, 286 pixel: 1483
# Speeding up to 31
#
# 100.96875
# Depth value at 359, 286 pixel: 1487
# Speeding up to 31
#
# 100.96875
# Depth value at 359, 285 pixel: 1494
# Speeding up to 31
#
# 100.96875
# Depth value at 359, 286 pixel: 1483
# Speeding up to 31
#
# 100.96875
# Depth value at 360, 286 pixel: 1483
# Speeding up to 31
#
# 101.25
# Depth value at 360, 286 pixel: 1494
# Speeding up to 31
#
# 101.25
# Depth value at 361, 286 pixel: 1490
# Speeding up to 31
#
# 101.53125
# Depth value at 362, 286 pixel: 1494
# Speeding up to 31
#
# 101.8125
# Depth value at 362, 286 pixel: 1490
# Speeding up to 31
#
# 101.8125
# Depth value at 363, 285 pixel: 1505
# Speeding up to 31
#
# 102.09375
# Depth value at 364, 285 pixel: 1494
# Speeding up to 31
#
# 102.375
# Depth value at 363, 285 pixel: 1494
# Speeding up to 31
#
# 102.09375
# Depth value at 363, 285 pixel: 1490
# Speeding up to 31
#
# 102.09375
# Depth value at 364, 282 pixel: 1490
# Speeding up to 31
#
# 102.375
# Depth value at 363, 279 pixel: 1473
# Speeding up to 31
#
# 102.09375
# Depth value at 360, 279 pixel: 1446
# Speeding up to 31
#
# 101.25
# Depth value at 358, 299 pixel: 1391
# Speeding up to 31
#
# 100.6875
# Depth value at 358, 299 pixel: 1378
# 100.6875
# Depth value at 358, 299 pixel: 1400
# 100.6875
# Depth value at 358, 299 pixel: 1406
# 100.6875
# Depth value at 352, 304 pixel: 1378
# Speeding up to 31
#
# 99.0
# Depth value at 352, 304 pixel: 1369
# 99.0
# Depth value at 337, 180 pixel: 1429
# Speeding up to 31
#
# 94.78125
# Depth value at 338, 160 pixel: 1456
# Speeding up to 31
#
# 95.0625
# Depth value at 333, 158 pixel: 1410
# Speeding up to 31
#
# 93.65625
# Depth value at 340, 215 pixel: 1360
# Speeding up to 31
#
# 95.625
# Depth value at 340, 215 pixel: 1388
# 95.625
# Depth value at 340, 215 pixel: 1351
# 95.625
# Depth value at 340, 215 pixel: 1340
# 95.625
# Depth value at 349, 287 pixel: 1309
# Speeding up to 31
#
# 98.15625
# Depth value at 348, 264 pixel: 1317
# Speeding up to 31
#
# 97.875
# Depth value at 346, 256 pixel: 1312
# Speeding up to 31
#
# 97.3125
# Depth value at 345, 266 pixel: 1312
# Speeding up to 31
#
# 97.03125
# Depth value at 346, 287 pixel: 1285
# Speeding up to 31
#
# 97.3125
# Depth value at 341, 283 pixel: 1295
# Speeding up to 31
#
# 95.90625
# Depth value at 342, 279 pixel: 1239
# Braking
#
# Depth value at 342, 279 pixel: 1309
# 96.1875
# Depth value at 342, 279 pixel: 1317
# 96.1875
# Depth value at 342, 279 pixel: 1317
# 96.1875
# Depth value at 342, 279 pixel: 1320
# 96.1875
# Depth value at 348, 276 pixel: 1337
# Speeding up to 31
#
# 97.875
# Depth value at 348, 276 pixel: 1328
# 97.875
# Depth value at 348, 276 pixel: 1340
# 97.875
# Depth value at 351, 279 pixel: 1343
# Speeding up to 31
#
# 98.71875
# Depth value at 351, 278 pixel: 1326
# Speeding up to 31
#
# 98.71875
# Depth value at 351, 279 pixel: 1334
# Speeding up to 31
#
# 98.71875
# Braking
