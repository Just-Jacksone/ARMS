# %%
import cv2
import json
import trt_pose.coco
import torch
import time
import numpy as np
import pyrealsense2 as rs
from torch2trt import TRTModule
from trt_pose.draw_objects import DrawObjects
from trt_pose.parse_objects import ParseObjects

OPTIMIZED_MODEL = 'pose_detection/resnet18_baseline_att_224x224_A_epoch_249_trt.pth'
HUMAN = 'pose_detection/human_pose.json'

# %%
def preprocess(image):
    mean = torch.Tensor([0.485, 0.456, 0.406]).to(device).view(1, 3, 1, 1)
    std = torch.Tensor([0.229, 0.224, 0.225]).to(device).view(1, 3, 1, 1)
    image = cv2.cvtColor(image, cv2.COLOR_BGR2RGB)
    image = cv2.resize(image, (224, 224))
    image = torch.from_numpy(image).permute(2, 0, 1).unsqueeze(0).float().to(device)
    image = image.div(255.0)
    image = (image - mean) / std
    return image

# Load model and topology
with open(HUMAN, 'r') as f:
    human_pose = json.load(f)
topology = trt_pose.coco.coco_category_to_topology(human_pose)

# Instantiate TensorRT
model_trt = TRTModule()
model_trt.load_state_dict(torch.load(OPTIMIZED_MODEL))

# Doing stuff (tbd)
parse_objects = ParseObjects(topology)
draw_objects = DrawObjects(topology)

device = torch.device('cuda')

# %%
from rover.controls import *
rover = Controls()
# Out:
# Initializing Servos
# Initializing ServoKit
# Done initializing

# %%
from pose_detection.pose_detection import *

WIDTH = 640
HEIGHT = 480
BRAKE_DISTANCE = 1269

# Initialize RealSense camera
pipeline = rs.pipeline()
config = rs.config()
config.enable_stream(rs.stream.color, WIDTH, HEIGHT, rs.format.bgr8, 30)
config.enable_stream(rs.stream.depth, 640, 480, rs.format.z16, 30)
pipeline.start(config)

body = Body()
speed = 0
pose_change = False
prev_pose = "No Pose"
center = [WIDTH/2, HEIGHT/2]
current_angle = 90
started = False

prev_frame_time = time.time()

try:
    while True:
        frames = pipeline.wait_for_frames()
        color_frame = frames.get_color_frame()
        depth_frame = frames.get_depth_frame()

        # Convert depth frame to numpy array
        depth_image = np.asanyarray(depth_frame.get_data())


        if not color_frame or not depth_frame:
            continue

        # Convert images to numpy arrays
        color_image = np.asanyarray(color_frame.get_data())

        # Process the image for pose estimation
        data = preprocess(color_image)
        cmap, paf = model_trt(data)
        cmap, paf = cmap.detach().cpu(), paf.detach().cpu()
        counts, objects, peaks = parse_objects(cmap, paf)
        
        # Classify the pose and display it
        pose_classification, chest_in_frame = classify_pose(peaks, counts, objects, topology, body)
        cv2.putText(color_image, pose_classification, (50, 50), cv2.FONT_HERSHEY_SIMPLEX, 1, (255, 255, 255), 2, cv2.LINE_AA)
        
        if pose_classification == "T-Pose":
            started = True
            speed = 1
            rover.forward(speed)
        elif pose_classification == "S-Pose":
            started = False
            rover.brake()
        
        if started == True:
            # Access depth data (in millimeters)
            depth_value_at_pixel = depth_image[int(body.chest[1]), int(body.chest[0])]  # Example: pixel at center of the frame
            print(f"Depth value at {body.chest[0]}, {body.chest[1]} pixel: {depth_value_at_pixel}")

            if depth_value_at_pixel < BRAKE_DISTANCE:
                rover.brake()
                speed = 1
            else:
                if chest_in_frame:
                    rover.forward(speed)

                x_diff = body.chest[0] - center[0]
                x_diff = (0.28125 * x_diff) + 90
                current_angle = x_diff
                print(current_angle)
                rover.turn(current_angle)

                # TODO: Think about speed being 1 and incrementing by 10
                if pose_classification != prev_pose:
                    if pose_classification == "M-Pose" and speed >= 10:
                        speed -= 10
                        rover.forward(speed)
                    elif pose_classification == "W-Pose" and speed < MAX_THROTTLE - 10:
                        speed += 10
                        rover.forward(speed)

                prev_chest = body.chest
        
        # Draw poses and display them
        #draw_objects(color_image, counts, objects, peaks)
        draw_keypoints_and_values(color_image, counts, objects, peaks, topology)

        # Calculate FPS and display it
        current_frame_time = time.time()
        fps = (1 / (current_frame_time - prev_frame_time))
        prev_frame_time = current_frame_time
        fps_text = f'FPS: {fps:.0f}'
        cv2.putText(color_image, fps_text, (color_image.shape[1] - 150, color_image.shape[0] - 10), cv2.FONT_HERSHEY_SIMPLEX, 0.5, (255, 255, 255), 2)



        # Display the image
        cv2.imshow('Pose Estimation', color_image)
        if cv2.waitKey(1) & 0xFF == ord('q'):
            break

finally:
    rover.brake()
    pipeline.stop()
    cv2.destroyAllWindows()
# Out:
# Speeding up to 31
#
# Depth value at 336, 271 pixel: 1303
# Speeding up to 31
#
# 94.5
# Speeding up to 31
#
# Depth value at 341, 273 pixel: 1317
# Speeding up to 31
#
# 95.90625
# Speeding up to 31
#
# Depth value at 349, 274 pixel: 1337
# Speeding up to 31
#
# 98.15625
# Speeding up to 31
#
# Depth value at 356, 274 pixel: 1366
# Speeding up to 31
#
# 100.125
# Speeding up to 31
#
# Depth value at 363, 274 pixel: 1391
# Speeding up to 31
#
# 102.09375
# Speeding up to 31
#
# Depth value at 368, 274 pixel: 1397
# Speeding up to 31
#
# 103.5
# Speeding up to 31
#
# Depth value at 370, 274 pixel: 1397
# Speeding up to 31
#
# 104.0625
# Speeding up to 31
#
# Depth value at 371, 274 pixel: 1413
# Speeding up to 31
#
# 104.34375
# Speeding up to 31
#
# Depth value at 369, 275 pixel: 1442
# Speeding up to 31
#
# 103.78125
# Depth value at 367, 274 pixel: 1429
# Speeding up to 31
#
# 103.21875
# Depth value at 364, 272 pixel: 1442
# Speeding up to 31
#
# 102.375
# Depth value at 359, 275 pixel: 1432
# Speeding up to 31
#
# 100.96875
# Depth value at 357, 276 pixel: 1439
# Speeding up to 31
#
# 100.40625
# Depth value at 357, 280 pixel: 1432
# Speeding up to 31
#
# 100.40625
# Depth value at 355, 282 pixel: 1429
# Speeding up to 31
#
# 99.84375
# Depth value at 355, 279 pixel: 1442
# Speeding up to 31
#
# 99.84375
# Depth value at 354, 278 pixel: 1439
# Speeding up to 31
#
# 99.5625
# Depth value at 354, 281 pixel: 1436
# Speeding up to 31
#
# 99.5625
# Depth value at 354, 281 pixel: 1442
# Speeding up to 31
#
# 99.5625
# Depth value at 356, 281 pixel: 1442
# Speeding up to 31
#
# 100.125
# Depth value at 358, 282 pixel: 1449
# Speeding up to 31
#
# 100.6875
# Depth value at 362, 283 pixel: 1442
# Speeding up to 31
#
# 101.8125
# Depth value at 366, 285 pixel: 1439
# Speeding up to 31
#
# 102.9375
# Depth value at 368, 287 pixel: 1429
# Speeding up to 31
#
# 103.5
# Depth value at 366, 285 pixel: 1426
# Speeding up to 31
#
# 102.9375
# Depth value at 364, 284 pixel: 1413
# Speeding up to 31
#
# 102.375
# Depth value at 358, 286 pixel: 1406
# Speeding up to 31
#
# 100.6875
# Depth value at 358, 286 pixel: 1394
# 100.6875
# Depth value at 344, 288 pixel: 1384
# Speeding up to 31
#
# 96.75
# Depth value at 338, 288 pixel: 1372
# Speeding up to 31
#
# 95.0625
# Depth value at 332, 293 pixel: 1360
# Speeding up to 31
#
# 93.375
# Depth value at 330, 294 pixel: 1349
# Speeding up to 31
#
# 92.8125
# Depth value at 330, 290 pixel: 1354
# Speeding up to 31
#
# 92.8125
# Depth value at 331, 286 pixel: 1340
# Speeding up to 31
#
# 93.09375
# Depth value at 337, 286 pixel: 1340
# Speeding up to 31
#
# 94.78125
# Depth value at 343, 285 pixel: 1337
# Speeding up to 31
#
# 96.46875
# Depth value at 350, 281 pixel: 1326
# Speeding up to 31
#
# 98.4375
# Depth value at 352, 282 pixel: 1317
# Speeding up to 31
#
# 99.0
# Depth value at 358, 283 pixel: 1312
# Speeding up to 31
#
# 100.6875
# Depth value at 358, 283 pixel: 1298
# 100.6875
# Depth value at 358, 283 pixel: 1287
# 100.6875
# Depth value at 364, 286 pixel: 1287
# Speeding up to 31
#
# 102.375
# Depth value at 360, 284 pixel: 1251
# Braking
#
# Depth value at 355, 286 pixel: 1241
# Braking
#
# Depth value at 350, 286 pixel: 1234
# Braking
#
# Depth value at 345, 286 pixel: 1222
# Braking
#
# Depth value at 338, 290 pixel: 1210
# Braking
#
# Depth value at 338, 290 pixel: 1212
# Braking
#
# Depth value at 338, 290 pixel: 1205
# Braking
#
# Depth value at 338, 290 pixel: 1200
# Braking
#
# Depth value at 338, 290 pixel: 1200
# Braking
#
# Depth value at 353, 284 pixel: 1191
# Braking
#
# Depth value at 353, 284 pixel: 1191
# Braking
#
# Depth value at 353, 284 pixel: 1167
# Braking
#
# Depth value at 369, 280 pixel: 1165
# Braking
#
# Depth value at 369, 280 pixel: 1160
# Braking
#
# Depth value at 369, 280 pixel: 1154
# Braking
#
# Depth value at 369, 280 pixel: 1133
# Braking
#
# Depth value at 384, 284 pixel: 1105
# Braking
#
# Depth value at 379, 284 pixel: 1093
# Braking
#
# Depth value at 375, 284 pixel: 1080
# Braking
#
# Depth value at 375, 284 pixel: 1061
# Braking
#
# Depth value at 375, 284 pixel: 1054
# Braking
#
# Depth value at 375, 284 pixel: 1061
# Braking
#
# Depth value at 375, 284 pixel: 1069
# Braking
#
# Depth value at 375, 284 pixel: 1063
# Braking
#
# Depth value at 375, 284 pixel: 1060
# Braking
#
# Depth value at 375, 284 pixel: 1038
# Braking
#
# Depth value at 375, 284 pixel: 1020
# Braking
#
# Depth value at 375, 284 pixel: 1002
# Braking
#
# Depth value at 375, 284 pixel: 986
# Braking
#
# Depth value at 375, 284 pixel: 981
# Braking
#
# Depth value at 375, 284 pixel: 970
# Braking
#
# Depth value at 375, 284 pixel: 970
# Braking
#
# Depth value at 375, 284 pixel: 935
# Braking
#
# Depth value at 375, 284 pixel: 928
# Braking
#
# Depth value at 375, 284 pixel: 928
# Braking
#
# Depth value at 375, 284 pixel: 895
# Braking
#
# Depth value at 375, 284 pixel: 884
# Braking
#
# Depth value at 375, 284 pixel: 886
# Braking
#
# Depth value at 375, 284 pixel: 891
# Braking
#
# Depth value at 375, 284 pixel: 895
# Braking
#
# Depth value at 215, 467 pixel: 831
# Braking
#
# Depth value at 215, 467 pixel: 788
# Braking
#
# Depth value at 215, 467 pixel: 0
# Braking
#
# Depth value at 215, 467 pixel: 0
# Braking
#
# Depth value at 254, 469 pixel: 717
# Braking
#
# Depth value at 254, 469 pixel: 724
# Braking
#
# Depth value at 254, 469 pixel: 747
# Braking
#
# Depth value at 254, 469 pixel: 747
# Braking
#
# Depth value at 254, 469 pixel: 774
# Braking
#
# Depth value at 254, 469 pixel: 800
# Braking
#
# Depth value at 254, 469 pixel: 813
# Braking
#
# Depth value at 254, 469 pixel: 818
# Braking
#
# Depth value at 254, 469 pixel: 830
# Braking
#
# Depth value at 254, 469 pixel: 833
# Braking
#
# Depth value at 254, 469 pixel: 826
# Braking
#
# Depth value at 254, 469 pixel: 805
# Braking
#
# Depth value at 254, 469 pixel: 774
# Braking
#
# Depth value at 254, 469 pixel: 752
# Braking
#
# Depth value at 254, 469 pixel: 737
# Braking
#
# Depth value at 254, 469 pixel: 737
# Braking
#
# Depth value at 254, 469 pixel: 721
# Braking
#
# Depth value at 254, 469 pixel: 673
# Braking
#
# Depth value at 254, 469 pixel: 640
# Braking
#
# Depth value at 254, 469 pixel: 647
# Braking
#
# Depth value at 254, 469 pixel: 661
# Braking
#
# Depth value at 254, 469 pixel: 661
# Braking
#
# Depth value at 254, 469 pixel: 679
# Braking
#
# Depth value at 254, 469 pixel: 703
# Braking
#
# Depth value at 254, 469 pixel: 774
# Braking
#
# Depth value at 254, 469 pixel: 807
# Braking
#
# Depth value at 254, 469 pixel: 807
# Braking
#
# Depth value at 254, 469 pixel: 810
# Braking
#
# Depth value at 254, 469 pixel: 799
# Braking
#
# Depth value at 254, 469 pixel: 718
# Braking
#
# Depth value at 254, 469 pixel: 718
# Braking
#
# Depth value at 254, 469 pixel: 706
# Braking
#
# Depth value at 254, 469 pixel: 695
# Braking
#
# Depth value at 254, 469 pixel: 694
# Braking
#
# Depth value at 254, 469 pixel: 736
# Braking
#
# Depth value at 254, 469 pixel: 775
# Braking
#
# Depth value at 254, 469 pixel: 775
# Braking
#
# Depth value at 254, 469 pixel: 690
# Braking
#
# Depth value at 254, 469 pixel: 724
# Braking
#
# Depth value at 254, 469 pixel: 778
# Braking
#
# Depth value at 254, 469 pixel: 845
# Braking
#
# Depth value at 254, 469 pixel: 910
# Braking
#
# Depth value at 254, 469 pixel: 963
# Braking
#
# Depth value at 254, 469 pixel: 989
# Braking
#
# Depth value at 254, 469 pixel: 984
# Braking
#
# Depth value at 254, 469 pixel: 1021
# Braking
#
# Depth value at 254, 469 pixel: 981
# Braking
#
# Depth value at 254, 469 pixel: 0
# Braking
#
# Depth value at 254, 469 pixel: 0
# Braking
#
# Depth value at 254, 469 pixel: 0
# Braking
#
# Depth value at 254, 469 pixel: 776
# Braking
#
# Depth value at 254, 469 pixel: 777
# Braking
#
# Depth value at 254, 469 pixel: 777
# Braking
#
# Depth value at 254, 469 pixel: 0
# Braking
#
# Depth value at 254, 469 pixel: 0
# Braking
#
# Depth value at 254, 469 pixel: 1661
# 71.4375
# Depth value at 254, 469 pixel: 1712
# 71.4375
# Depth value at 254, 469 pixel: 1698
# 71.4375
# Depth value at 254, 469 pixel: 0
# Braking
#
# Depth value at 254, 469 pixel: 0
# Braking
#
# Depth value at 254, 469 pixel: 1056
# Braking
#
# Depth value at 254, 469 pixel: 1040
# Braking
#
# Depth value at 254, 469 pixel: 1026
# Braking
#
# Depth value at 254, 469 pixel: 1013
# Braking
#
# Depth value at 254, 469 pixel: 0
# Braking
#
# Depth value at 254, 469 pixel: 964
# Braking
#
# Depth value at 254, 469 pixel: 948
# Braking
#
# Depth value at 254, 469 pixel: 954
# Braking
#
# Depth value at 254, 469 pixel: 954
# Braking
#
# Depth value at 254, 469 pixel: 998
# Braking
#
# Depth value at 254, 469 pixel: 1693
# 71.4375
# Depth value at 254, 469 pixel: 1716
# 71.4375
# Depth value at 386, 291 pixel: 1173
# Braking
#
# Depth value at 386, 288 pixel: 1178
# Braking
#
# Depth value at 388, 286 pixel: 1194
# Braking
#
# Depth value at 387, 289 pixel: 1205
# Braking
#
# Depth value at 387, 289 pixel: 1207
# Braking
#
# Depth value at 387, 289 pixel: 1229
# Braking
#
# Depth value at 387, 289 pixel: 1217
# Braking
#
# Depth value at 387, 289 pixel: 1246
# Braking
#
# Depth value at 387, 289 pixel: 2194
# 108.84375
# Depth value at 387, 289 pixel: 2241
# 108.84375
# Depth value at 387, 289 pixel: 2201
# 108.84375
# Depth value at 387, 289 pixel: 2233
# 108.84375
# Depth value at 387, 289 pixel: 2266
# 108.84375
# Depth value at 387, 289 pixel: 2233
# 108.84375
# Depth value at 387, 289 pixel: 2233
# 108.84375
# Depth value at 387, 289 pixel: 2249
# 108.84375
# Depth value at 387, 289 pixel: 2233
# 108.84375
# Depth value at 387, 289 pixel: 2266
# 108.84375
# Depth value at 387, 289 pixel: 2266
# 108.84375
# Depth value at 387, 289 pixel: 2241
# 108.84375
# Depth value at 387, 289 pixel: 2217
# 108.84375
# Depth value at 387, 289 pixel: 2266
# 108.84375
# Depth value at 387, 289 pixel: 2233
# 108.84375
# Depth value at 387, 289 pixel: 2201
# 108.84375
# Depth value at 387, 289 pixel: 2209
# 108.84375
# Depth value at 387, 289 pixel: 2241
# 108.84375
# Depth value at 387, 289 pixel: 2257
# 108.84375
# Depth value at 387, 289 pixel: 2217
# 108.84375
# Depth value at 387, 289 pixel: 2201
# 108.84375
# Depth value at 387, 289 pixel: 2299
# 108.84375
# Depth value at 387, 289 pixel: 2274
# 108.84375
# Depth value at 387, 289 pixel: 2274
# 108.84375
# Depth value at 387, 289 pixel: 2233
# 108.84375
# Depth value at 387, 289 pixel: 2325
# 108.84375
# Depth value at 387, 289 pixel: 2171
# 108.84375
# Depth value at 383, 475 pixel: 365
# Braking
#
# Depth value at 383, 475 pixel: 363
# Braking
#
# Depth value at 383, 475 pixel: 363
# Braking
#
# Depth value at 383, 475 pixel: 364
# Braking
#
# Depth value at 383, 475 pixel: 364
# Braking
#
# Depth value at 383, 475 pixel: 363
# Braking
#
# Depth value at 383, 475 pixel: 363
# Braking
#
# Depth value at 383, 475 pixel: 363
# Braking
#
# Depth value at 383, 475 pixel: 364
# Braking
#
# Depth value at 383, 475 pixel: 364
# Braking
#
# Depth value at 383, 475 pixel: 364
# Braking
#
# Depth value at 383, 475 pixel: 365
# Braking
#
# Depth value at 383, 475 pixel: 363
# Braking
#
# Depth value at 383, 475 pixel: 364
# Braking
#
# Depth value at 383, 475 pixel: 364
# Braking
#
# Depth value at 383, 475 pixel: 365
# Braking
#
# Depth value at 383, 475 pixel: 365
# Braking
#
# Depth value at 383, 475 pixel: 365
# Braking
#
# Depth value at 383, 475 pixel: 365
# Braking
#
# Depth value at 383, 475 pixel: 0
# Braking
#
# Depth value at 383, 475 pixel: 0
# Braking
#
# Depth value at 383, 475 pixel: 0
# Braking
#
# Depth value at 383, 475 pixel: 0
# Braking
#
# Depth value at 383, 475 pixel: 0
# Braking
#
# Depth value at 383, 475 pixel: 367
# Braking
#
# Depth value at 383, 475 pixel: 365
# Braking
#
# Depth value at 383, 475 pixel: 365
# Braking
#
# Depth value at 383, 475 pixel: 365
# Braking
#
# Depth value at 383, 475 pixel: 365
# Braking
#
# Depth value at 383, 475 pixel: 365
# Braking
#
# Depth value at 383, 475 pixel: 365
# Braking
#
# Depth value at 383, 475 pixel: 367
# Braking
#
# Depth value at 383, 475 pixel: 367
# Braking
#
# Depth value at 383, 475 pixel: 368
# Braking
#
# Depth value at 383, 475 pixel: 368
# Braking
#
# Depth value at 383, 475 pixel: 368
# Braking
#
# Depth value at 383, 475 pixel: 366
# Braking
#
# Depth value at 383, 475 pixel: 366
# Braking
#
# Depth value at 383, 475 pixel: 366
# Braking
#
# Depth value at 383, 475 pixel: 365
# Braking
#
# Depth value at 383, 475 pixel: 365
# Braking
#
# Depth value at 383, 475 pixel: 365
# Braking
#
# Depth value at 383, 475 pixel: 365
# Braking
#
# Depth value at 383, 475 pixel: 366
# Braking
#
# Depth value at 383, 475 pixel: 366
# Braking
#
# Depth value at 383, 475 pixel: 366
# Braking
#
# Depth value at 383, 475 pixel: 366
# Braking
#
# Depth value at 383, 475 pixel: 368
# Braking
#
# Depth value at 383, 475 pixel: 367
# Braking
#
# Depth value at 383, 475 pixel: 367
# Braking
#
# Depth value at 383, 475 pixel: 367
# Braking
#
# Depth value at 383, 475 pixel: 367
# Braking
#
# Depth value at 383, 475 pixel: 367
# Braking
#
# Depth value at 383, 475 pixel: 366
# Braking
#
# Depth value at 383, 475 pixel: 366
# Braking
#
# Depth value at 383, 475 pixel: 366
# Braking
#
# Depth value at 383, 475 pixel: 366
# Braking
#
# Depth value at 383, 475 pixel: 366
# Braking
#
# Depth value at 383, 475 pixel: 365
# Braking
#
# Depth value at 383, 475 pixel: 365
# Braking
#
# Depth value at 383, 475 pixel: 365
# Braking
#
# Depth value at 383, 475 pixel: 365
# Braking
#
# Depth value at 383, 475 pixel: 365
# Braking
#
# Depth value at 383, 475 pixel: 365
# Braking
#
# Depth value at 383, 475 pixel: 365
# Braking
#
# Depth value at 383, 475 pixel: 364
# Braking
#
# Depth value at 383, 475 pixel: 365
# Braking
#
# Depth value at 383, 475 pixel: 368
# Braking
#
# Depth value at 383, 475 pixel: 365
# Braking
#
# Depth value at 383, 475 pixel: 0
# Braking
#
# Depth value at 383, 475 pixel: 365
# Braking
#
# Depth value at 383, 475 pixel: 367
# Braking
#
# Depth value at 383, 475 pixel: 0
# Braking
#
# Depth value at 383, 475 pixel: 0
# Braking
#
# Depth value at 383, 475 pixel: 528
# Braking
#
# Depth value at 383, 475 pixel: 365
# Braking
#
# Depth value at 383, 475 pixel: 364
# Braking
#
# Depth value at 383, 475 pixel: 365
# Braking
#
# Depth value at 383, 475 pixel: 365
# Braking
#
# Depth value at 383, 475 pixel: 365
# Braking
#
# Depth value at 383, 475 pixel: 364
# Braking
#
# Depth value at 383, 475 pixel: 364
# Braking
#
# Depth value at 383, 475 pixel: 364
# Braking
#
# Depth value at 383, 475 pixel: 364
# Braking
#
# Depth value at 383, 475 pixel: 364
# Braking
#
# Depth value at 361, 281 pixel: 1129
# Braking
#
# Depth value at 363, 282 pixel: 1152
# Braking
#
# Depth value at 366, 280 pixel: 1154
# Braking
#
# Depth value at 368, 281 pixel: 1207
# Braking
#
# Depth value at 368, 281 pixel: 1306
# 103.5
# Depth value at 376, 289 pixel: 1301
# Speeding up to 31
#
# 105.75
# Depth value at 375, 280 pixel: 1384
# Speeding up to 31
#
# 105.46875
# Depth value at 373, 283 pixel: 1410
# Speeding up to 31
#
# 104.90625
# Depth value at 367, 283 pixel: 1439
# Speeding up to 31
#
# 103.21875
# Depth value at 357, 282 pixel: 1483
# Speeding up to 31
#
# 100.40625
# Depth value at 348, 286 pixel: 1490
# Speeding up to 31
#
# 97.875
# Depth value at 340, 285 pixel: 1498
# Speeding up to 31
#
# 95.625
# Depth value at 335, 285 pixel: 1498
# Speeding up to 31
#
# 94.21875
# Depth value at 334, 285 pixel: 1498
# Speeding up to 31
#
# 93.9375
# Depth value at 330, 286 pixel: 1498
# Speeding up to 31
#
# 92.8125
# Depth value at 330, 285 pixel: 1501
# Speeding up to 31
#
# 92.8125
# Depth value at 332, 285 pixel: 1505
# Speeding up to 31
#
# 93.375
# Depth value at 337, 284 pixel: 1523
# Speeding up to 31
#
# 94.78125
# Depth value at 339, 284 pixel: 1527
# Speeding up to 31
#
# 95.34375
# Depth value at 341, 285 pixel: 1531
# Speeding up to 31
#
# 95.90625
# Depth value at 343, 285 pixel: 1531
# Speeding up to 31
#
# 96.46875
# Depth value at 344, 285 pixel: 1531
# Speeding up to 31
#
# 96.75
# Depth value at 345, 286 pixel: 1531
# Speeding up to 31
#
# 97.03125
# Depth value at 345, 286 pixel: 1531
# Speeding up to 31
#
# 97.03125
# Depth value at 344, 286 pixel: 1527
# Speeding up to 31
#
# 96.75
# Depth value at 344, 286 pixel: 1527
# Speeding up to 31
#
# 96.75
# Depth value at 344, 286 pixel: 1523
# Speeding up to 31
#
# 96.75
# Depth value at 343, 285 pixel: 1523
# Speeding up to 31
#
# 96.46875
# Depth value at 342, 286 pixel: 1527
# Speeding up to 31
#
# 96.1875
# Depth value at 342, 287 pixel: 1520
# Speeding up to 31
#
# 96.1875
# Depth value at 343, 295 pixel: 1490
# Speeding up to 31
#
# 96.46875
# Depth value at 344, 306 pixel: 1487
# Speeding up to 31
#
# 96.75
# Depth value at 344, 305 pixel: 1487
# Speeding up to 31
#
# 96.75
# Depth value at 344, 302 pixel: 1487
# Speeding up to 31
#
# 96.75
# Depth value at 345, 299 pixel: 1473
# Speeding up to 31
#
# 97.03125
# Depth value at 347, 305 pixel: 1473
# Speeding up to 31
#
# 97.59375
# Depth value at 347, 313 pixel: 1462
# Speeding up to 31
#
# 97.59375
# Depth value at 349, 301 pixel: 1480
# Speeding up to 31
#
# 98.15625
# Depth value at 350, 302 pixel: 1476
# Speeding up to 31
#
# 98.4375
# Depth value at 349, 310 pixel: 1462
# Speeding up to 31
#
# 98.15625
# Depth value at 349, 310 pixel: 1483
# 98.15625
# Depth value at 349, 310 pixel: 1466
# 98.15625
# Depth value at 343, 301 pixel: 1473
# Speeding up to 31
#
# 96.46875
# Depth value at 339, 299 pixel: 1473
# Speeding up to 31
#
# 95.34375
# Depth value at 338, 310 pixel: 1459
# Speeding up to 31
#
# 95.0625
# Depth value at 338, 311 pixel: 1462
# Speeding up to 31
#
# 95.0625
# Depth value at 339, 308 pixel: 1469
# Speeding up to 31
#
# 95.34375
# Depth value at 338, 304 pixel: 1469
# Speeding up to 31
#
# 95.0625
# Depth value at 338, 308 pixel: 1466
# Speeding up to 31
#
# 95.0625
# Depth value at 339, 314 pixel: 1469
# Speeding up to 31
#
# 95.34375
# Depth value at 338, 304 pixel: 1487
# Speeding up to 31
#
# 95.0625
# Depth value at 338, 301 pixel: 1487
# Speeding up to 31
#
# 95.0625
# Depth value at 338, 301 pixel: 1498
# 95.0625
# Depth value at 338, 301 pixel: 1494
# 95.0625
# Depth value at 338, 301 pixel: 1498
# 95.0625
# Depth value at 342, 306 pixel: 1498
# Speeding up to 31
#
# 96.1875
# Depth value at 344, 306 pixel: 1487
# Speeding up to 31
#
# 96.75
# Depth value at 347, 313 pixel: 1480
# Speeding up to 31
#
# 97.59375
# Depth value at 345, 312 pixel: 1480
# Speeding up to 31
#
# 97.03125
# Depth value at 342, 311 pixel: 1498
# Speeding up to 31
#
# 96.1875
# Depth value at 342, 311 pixel: 1487
# 96.1875
# Depth value at 341, 321 pixel: 1480
# Speeding up to 31
#
# 95.90625
# Depth value at 341, 321 pixel: 1480
# 95.90625
# Depth value at 341, 321 pixel: 1469
# 95.90625
# Depth value at 343, 313 pixel: 1483
# Speeding up to 31
#
# 96.46875
# Depth value at 344, 315 pixel: 1476
# Speeding up to 31
#
# 96.75
# Depth value at 344, 315 pixel: 1473
# 96.75
# Depth value at 343, 311 pixel: 1480
# Speeding up to 31
#
# 96.46875
# Depth value at 343, 311 pixel: 1480
# 96.46875
# Depth value at 338, 316 pixel: 1466
# Speeding up to 31
#
# 95.0625
# Depth value at 338, 316 pixel: 1462
# 95.0625
# Depth value at 338, 316 pixel: 1476
# 95.0625
# Depth value at 341, 313 pixel: 1469
# Speeding up to 31
#
# 95.90625
# Depth value at 342, 317 pixel: 1469
# Speeding up to 31
#
# 96.1875
# Depth value at 344, 316 pixel: 1473
# Speeding up to 31
#
# 96.75
# Depth value at 341, 313 pixel: 1480
# Speeding up to 31
#
# 95.90625
# Depth value at 338, 307 pixel: 1490
# Speeding up to 31
#
# 95.0625
# Depth value at 338, 307 pixel: 1498
# 95.0625
# Depth value at 338, 307 pixel: 1480
# 95.0625
# Depth value at 338, 307 pixel: 1483
# 95.0625
# Depth value at 342, 305 pixel: 1501
# Speeding up to 31
#
# 96.1875
# Depth value at 344, 306 pixel: 1498
# Speeding up to 31
#
# 96.75
# Depth value at 345, 313 pixel: 1473
# Speeding up to 31
#
# 97.03125
# Depth value at 345, 313 pixel: 1480
# 97.03125
# Depth value at 338, 309 pixel: 1490
# Speeding up to 31
#
# 95.0625
# Braking
